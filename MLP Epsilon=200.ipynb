# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %% [markdown]
# ### Modelo

# %%
class ModelMLP:
    @staticmethod
    def create_model():
        model = tf.keras.models.Sequential(
            [
                tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784,)),
                tf.keras.layers.Dense(10, activation="softmax")
            ]
        )
        model.compile(
            optimizer=tf.keras.optimizers.Adam(),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=['accuracy']
        )
        return model

# %%
# Definição dos parâmetros
NUMBER_OF_ROUNDS = 8
TOTAL_CLIENTS = 100
CLIENTS_PER_ROUND = 3
EPSILON_DELTA = 200.0

# %% [markdown]
# ### Cliente

# %%
class Client():
    def __init__(self, cid):
        self.cid = int(cid)
        self.model = ModelMLP.create_model()
        self.old_weights = None
        (self.x_train, self.y_train), (self.x_test, self.y_test) = self.load_data()


    def load_data(self):
        # path = "../Dataset/Dataset/dataset-mnist/non-iid-0.9-100-rotation-45"
        path = "./dataset-mnist/non-iid-0.9-100-rotation-45"

        train = pd.read_pickle(f"{path}/{self.cid+1}_train.pickle")
        test = pd.read_pickle(f"{path}/{self.cid+1}_test.pickle")

        x_train = train.drop(['label'], axis=1)
        y_train = train['label']

        x_test = test.drop(['label'], axis=1)
        y_test = test['label']

        return (x_train, y_train), (x_test, y_test)


    def fit(self, parameters, config=None):
        self.model.set_weights(parameters)
        history = self.model.fit(self.x_train, self.y_train, epochs=5, batch_size=128,
                                 validation_data=(self.x_test, self.y_test), verbose=False)
        self.current_weights = self.model.get_weights()
        sample_size = len(self.x_train)
        print(f"Acurácia: {history.history['val_accuracy'][-1]} | ", end='')
        if self.old_weights is not None:
            weight_diff = np.mean([
                np.mean(np.abs((w1 - w2) / w2) * 100) 
                for w1, w2 in zip(self.current_weights, self.old_weights)
                if np.sum(np.abs(w2)) > 0  # Evitar divisão por zero
            ])
            print(f"Diferença dos pesos: {weight_diff}")
            self.old_weights = self.current_weights
            if weight_diff < EPSILON_DELTA:
                print("weight_diff < EPSILON_DELTA. O modelo não será transmitido.")
                return None
            else:
                print("ENVIADO!")
                return self.current_weights, sample_size, {"val_accuracy": history.history['val_accuracy'][-1],
                                                               "val_loss": history.history['val_loss'][-1]}
        else:
            print("ENVIANDO PRIMEIRA")
            self.old_weights = self.current_weights
            return self.current_weights, sample_size, {"val_accuracy": history.history['val_accuracy'][-1],
                                                               "val_loss": history.history['val_loss'][-1]}


    def evaluate(self, parameters):
        self.model.set_weights(parameters)
        return self.model.evaluate(self.x_test, self.y_test, verbose=False)

# %% [markdown]
# ### Servidor

# %%
class Server():
    def __init__(self, n_rounds, total_number_clients, min_fit_clients):
        self.n_rounds = n_rounds
        self.total_number_clients = total_number_clients
        self.min_fit_clients = min_fit_clients

        self.server_round = 0
        self.selected_clients = []
        self.model = ModelMLP.create_model()
        self.w_global = self.model.get_weights()

        self.clients_model_list = []
        # Vamos guardar todos os modelos (pesos) anteriores, mas não é necessário
        self.clients_previous_models_list = [ [] for _ in range(total_number_clients) ]
        self.create_models()
        (self.x_train, self.y_train), (self.x_test, self.y_test) = self.load_data()


    def load_data(self):
        # path = "../Dataset/Dataset/dataset-mnist/mnist"
        path = "./dataset-mnist/mnist"

        train = pd.read_pickle(f"{path}/train.pickle")
        test = pd.read_pickle(f"{path}/test.pickle")

        x_train = train.drop(['label'], axis=1)
        y_train = train['label']

        # test = pd.concat([test, train])
        x_test = test.drop(['label'], axis=1)
        y_test = test['label']

        return (x_train, y_train), (x_test, y_test)


    def create_models(self):
        for i in range(self.total_number_clients):
            self.clients_model_list.append(Client(i))


    def aggregate_fit(self, weight_list, sample_sizes):
        self.w_global = []
        for weights in zip(*weight_list):
            weighted_sum = 0
            total_samples = sum(sample_sizes)
            for i in range(len(weights)):
                weighted_sum += weights[i] * sample_sizes[i]
            self.w_global.append(weighted_sum / total_samples)


    def configure_fit(self):
        self.selected_clients = np.random.permutation(list(range(self.total_number_clients)))[:self.min_fit_clients]
        print(f"Clientes selecionados: \033[34;1m{np.array(self.selected_clients) + 1}\033[37;0m")

    
    def get_client_previous_model(self, client_id):
        return self.clients_previous_models_list[client_id][-1]


    def save_client_previous_model(self, client_id, model):
        self.clients_previous_models_list[client_id].append(model)


    def fit(self):
        weight_list, sample_sizes_list, info_list, transmissions_count = [], [], [], 0
        for i, pos in enumerate(self.selected_clients):
            print(f"Cliente #{pos+1} | ", end='')

            # Se o cliente decidir não enviar o modelo, ele retorna um None
            new_model = self.clients_model_list[pos].fit(parameters=self.w_global)

            weights, size, info = new_model if new_model is not None else self.get_client_previous_model(pos)
            weight_list.append(weights)
            sample_sizes_list.append(size)
            info_list.append(info)

            # Se o cliente enviou um novo modelo, salve-o e incremente a contagem de transmissões
            if new_model is not None:
                self.save_client_previous_model(pos, (weights, size, info_list))
                transmissions_count += 1

        return weight_list, sample_sizes_list, {"acc_loss_local":[(pos+1, info_list[i]) for i, pos in enumerate(self.selected_clients)]}, transmissions_count


    def distributed_evaluation(self):
        loss_list, accuracy_list = [], []
        for i in range(self.total_number_clients):
            loss, accuracy = self.clients_model_list[i].evaluate(parameters=self.w_global)
            # print(f"Evaluate - CID: {i+1} - accuracy: {accuracy}")
            loss_list.append(loss)
            accuracy_list.append(accuracy)
        return sum(loss_list) / len(loss_list), sum(accuracy_list) / len(accuracy_list), {"accuracy_list": [(i+1, accuracy) for i, accuracy in enumerate(accuracy_list)]}


    def centralized_evaluation(self):
        self.model.set_weights(self.w_global)
        return self.model.evaluate(self.x_test, self.y_test, verbose=False)

# %% [markdown]
# ### Execução

# %%
def executar(id):
    print('\n' + '='*40)
    print("{:^54}".format('\033[;1m' + 'CARREGAMENTO DE DADOS' + '\033[37;0m'))
    print("{:^40}".format(f'Número total de clientes: {TOTAL_CLIENTS}' + '\n'))
    
    s = Server(n_rounds=NUMBER_OF_ROUNDS,
               total_number_clients=TOTAL_CLIENTS,
               min_fit_clients=CLIENTS_PER_ROUND)
    
    print('\n' + '='*40)
    print("{:^54}".format('\033[;1m' + 'INICIANDO' + '\033[37;0m'))
    print("{:^40}".format(f'Clientes por rodada: {CLIENTS_PER_ROUND} ' + '\n'))
    
    evaluate_list = {"distributed": {"loss":[], "accuracy":[]}, "centralized": {"loss":[], "accuracy":[]}}
    
    transmissions_per_round = []
    
    # Rodadas de comunicação
    for s.server_round in range(s.n_rounds):
        print('\033[;1m' + f'Rodada {s.server_round+1}/{s.n_rounds}' + '\033[37;0m')
    
        # Seleciona os clientes que participarão da próxima rodada de comunicação
        s.configure_fit()
    
        # Treinamento local do dispositivo
        weight_list, sample_sizes, info, transmissions_count = s.fit()
    
        # Salva a quantidade de transmissões ocorridas nesta rodada
        transmissions_per_round.append(transmissions_count)
    
        # Agregação
        s.aggregate_fit(weight_list, sample_sizes)
    
        # Avaliação centralizada
        print('\033[3;1m' + '-'*40 + '\033[37;0m')
        # print(f"Avaliação centralizada")
        evaluate_loss, evaluate_accuracy = s.centralized_evaluation()
        print(f"Execução #{id}")
        print(f"Transmissões nesta rodada: {transmissions_count}")
        print(f"Acurácia: {evaluate_accuracy}")
        evaluate_list["centralized"]["loss"].append(evaluate_loss)
        evaluate_list["centralized"]["accuracy"].append(evaluate_accuracy)
        print('\033[3;1m' + '-'*40 + '\033[37;0m' + '\n')
    
    print('\n\n' + '='*40)
    print("{:^54}".format('\033[;1m' + 'RESULTADOS FINAIS' + '\033[37;0m'))
    print(f"\nCentralized loss: ", end='')
    print(evaluate_list["centralized"]["loss"])
    print(f"Centralized accuracy: ", end='')
    print(evaluate_list["centralized"]["accuracy"])

    return evaluate_list["centralized"]["accuracy"], evaluate_list["centralized"]["loss"], transmissions_per_round

# %%
acc_list, loss_list, transmissions_list = [], [], []

for i in range(3):
    acc, loss, transmissions = executar(i)
    acc_list.append(acc)
    loss_list.append(loss)
    transmissions_list.append(transmissions)
# Out:
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
#
#
# ========================================
#                 INICIANDO
#         Clientes por rodada: 3
#
# Rodada 1/8
# Clientes selecionados: [74 39 44]
# Cliente #74 | Acurácia: 0.913941502571106 | ENVIANDO PRIMEIRA
# Cliente #39 | Acurácia: 0.9008649587631226 | ENVIANDO PRIMEIRA
# Cliente #44 | Acurácia: 0.916214108467102 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6136999726295471
# ----------------------------------------
#
# Rodada 2/8
# Clientes selecionados: [40 95 28]
# Cliente #40 | Acurácia: 0.9138513803482056 | ENVIANDO PRIMEIRA
# Cliente #95 | Acurácia: 0.926217794418335 | ENVIANDO PRIMEIRA
# Cliente #28 | Acurácia: 0.92738276720047 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6654000282287598
# ----------------------------------------
#
# Rodada 3/8
# Clientes selecionados: [84 97 35]
# Cliente #84 | Acurácia: 0.9135135412216187 | ENVIANDO PRIMEIRA
# Cliente #97 | Acurácia: 0.9414364695549011 | ENVIANDO PRIMEIRA
# Cliente #35 | Acurácia: 0.9075297117233276 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6391000151634216
# ----------------------------------------
#
# Rodada 4/8
# Clientes selecionados: [56 16 86]
# Cliente #56 | Acurácia: 0.8761904835700989 | ENVIANDO PRIMEIRA
# Cliente #16 | Acurácia: 0.8980262875556946 | ENVIANDO PRIMEIRA
# Cliente #86 | Acurácia: 0.9108734130859375 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.4512999951839447
# ----------------------------------------
#
# Rodada 5/8
# Clientes selecionados: [67 22 33]
# Cliente #67 | Acurácia: 0.9278688430786133 | ENVIANDO PRIMEIRA
# Cliente #22 | Acurácia: 0.9517286419868469 | ENVIANDO PRIMEIRA
# Cliente #33 | Acurácia: 0.9086499810218811 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.5853999853134155
# ----------------------------------------
#
# Rodada 6/8
# Clientes selecionados: [71 50 12]
# Cliente #71 | Acurácia: 0.9452229142189026 | ENVIANDO PRIMEIRA
# Cliente #50 | Acurácia: 0.9256359934806824 | ENVIANDO PRIMEIRA
# Cliente #12 | Acurácia: 0.9486607313156128 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6717000007629395
# ----------------------------------------
#
# Rodada 7/8
# Clientes selecionados: [ 4 79 12]
# Cliente #4 | Acurácia: 0.9057093262672424 | ENVIANDO PRIMEIRA
# Cliente #79 | Acurácia: 0.9343163371086121 | ENVIANDO PRIMEIRA
# Cliente #12 | Acurácia: 0.9475446343421936 | Diferença dos pesos: 61.71937561035156
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 2
# Acurácia: 0.6474000215530396
# ----------------------------------------
#
# Rodada 8/8
# Clientes selecionados: [95 15 31]
# Cliente #95 | Acurácia: 0.9283667802810669 | Diferença dos pesos: 609.561767578125
# ENVIADO!
# Cliente #15 | Acurácia: 0.9338374137878418 | ENVIANDO PRIMEIRA
# Cliente #31 | Acurácia: 0.9397590160369873 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.7164999842643738
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [14.1819429397583, 4.870824813842773, 2.888587713241577, 3.4017629623413086, 1.6417202949523926, 1.460686206817627, 1.5039513111114502, 1.312530279159546]
# Centralized accuracy: [0.6136999726295471, 0.6654000282287598, 0.6391000151634216, 0.4512999951839447, 0.5853999853134155, 0.6717000007629395, 0.6474000215530396, 0.7164999842643738]
#
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
#
#
# ========================================
#                 INICIANDO
#         Clientes por rodada: 3
#
# Rodada 1/8
# Clientes selecionados: [58 82 16]
# Cliente #58 | Acurácia: 0.9304419159889221 | ENVIANDO PRIMEIRA
# Cliente #82 | Acurácia: 0.9314214587211609 | ENVIANDO PRIMEIRA
# Cliente #16 | Acurácia: 0.8848684430122375 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.6366999745368958
# ----------------------------------------
#
# Rodada 2/8
# Clientes selecionados: [93  4 40]
# Cliente #93 | Acurácia: 0.9060542583465576 | ENVIANDO PRIMEIRA
# Cliente #4 | Acurácia: 0.9299308061599731 | ENVIANDO PRIMEIRA
# Cliente #40 | Acurácia: 0.9222972989082336 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.7008000016212463
# ----------------------------------------
#
# Rodada 3/8
# Clientes selecionados: [ 9 81 44]
# Cliente #9 | Acurácia: 0.9091941118240356 | ENVIANDO PRIMEIRA
# Cliente #81 | Acurácia: 0.9433465003967285 | ENVIANDO PRIMEIRA
# Cliente #44 | Acurácia: 0.9278510212898254 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.7071999907493591
# ----------------------------------------
#
# Rodada 4/8
# Clientes selecionados: [ 3 43 37]
# Cliente #3 | Acurácia: 0.921862006187439 | ENVIANDO PRIMEIRA
# Cliente #43 | Acurácia: 0.9276155829429626 | ENVIANDO PRIMEIRA
# Cliente #37 | Acurácia: 0.9124767184257507 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.5950999855995178
# ----------------------------------------
#
# Rodada 5/8
# Clientes selecionados: [10 11 26]
# Cliente #10 | Acurácia: 0.9404255151748657 | ENVIANDO PRIMEIRA
# Cliente #11 | Acurácia: 0.9180327653884888 | ENVIANDO PRIMEIRA
# Cliente #26 | Acurácia: 0.909221887588501 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.5498999953269958
# ----------------------------------------
#
# Rodada 6/8
# Clientes selecionados: [19 43  3]
# Cliente #19 | Acurácia: 0.9292929172515869 | ENVIANDO PRIMEIRA
# Cliente #43 | Acurácia: 0.9403892755508423 | Diferença dos pesos: 120.02952575683594
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# Cliente #3 | Acurácia: 0.9401496052742004 | Diferença dos pesos: 138.56005859375
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 1
# Acurácia: 0.6211000084877014
# ----------------------------------------
#
# Rodada 7/8
# Clientes selecionados: [80 75 61]
# Cliente #80 | Acurácia: 0.939008891582489 | ENVIANDO PRIMEIRA
# Cliente #75 | Acurácia: 0.9312242269515991 | ENVIANDO PRIMEIRA
# Cliente #61 | Acurácia: 0.953346848487854 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.6047999858856201
# ----------------------------------------
#
# Rodada 8/8
# Clientes selecionados: [92 53  9]
# Cliente #92 | Acurácia: 0.9464997053146362 | ENVIANDO PRIMEIRA
# Cliente #53 | Acurácia: 0.9260337948799133 | ENVIANDO PRIMEIRA
# Cliente #9 | Acurácia: 0.9035187363624573 | Diferença dos pesos: 1008.2711181640625
# ENVIADO!
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.6535999774932861
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [13.138960838317871, 7.072613716125488, 4.023871421813965, 3.3986520767211914, 1.886460781097412, 2.4629130363464355, 1.539923906326294, 1.3389191627502441]
# Centralized accuracy: [0.6366999745368958, 0.7008000016212463, 0.7071999907493591, 0.5950999855995178, 0.5498999953269958, 0.6211000084877014, 0.6047999858856201, 0.6535999774932861]
#
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
#
#
# ========================================
#                 INICIANDO
#         Clientes por rodada: 3
#
# Rodada 1/8
# Clientes selecionados: [11  2  1]
# Cliente #11 | Acurácia: 0.8998178243637085 | ENVIANDO PRIMEIRA
# Cliente #2 | Acurácia: 0.9366438388824463 | ENVIANDO PRIMEIRA
# Cliente #1 | Acurácia: 0.926286518573761 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.4699000120162964
# ----------------------------------------
#
# Rodada 2/8
# Clientes selecionados: [41 72 21]
# Cliente #41 | Acurácia: 0.925000011920929 | ENVIANDO PRIMEIRA
# Cliente #72 | Acurácia: 0.9340835809707642 | ENVIANDO PRIMEIRA
# Cliente #21 | Acurácia: 0.9331574440002441 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6722000241279602
# ----------------------------------------
#
# Rodada 3/8
# Clientes selecionados: [97 53 38]
# Cliente #97 | Acurácia: 0.9381215572357178 | ENVIANDO PRIMEIRA
# Cliente #53 | Acurácia: 0.921374499797821 | ENVIANDO PRIMEIRA
# Cliente #38 | Acurácia: 0.9284890294075012 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.7063000202178955
# ----------------------------------------
#
# Rodada 4/8
# Clientes selecionados: [37  4 52]
# Cliente #37 | Acurácia: 0.9255120754241943 | ENVIANDO PRIMEIRA
# Cliente #4 | Acurácia: 0.9083045125007629 | ENVIANDO PRIMEIRA
# Cliente #52 | Acurácia: 0.9459459185600281 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6491000056266785
# ----------------------------------------
#
# Rodada 5/8
# Clientes selecionados: [31 17  1]
# Cliente #31 | Acurácia: 0.9323447346687317 | ENVIANDO PRIMEIRA
# Cliente #17 | Acurácia: 0.9468334913253784 | ENVIANDO PRIMEIRA
# Cliente #1 | Acurácia: 0.9318497776985168 | Diferença dos pesos: 942.867431640625
# ENVIADO!
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6664999723434448
# ----------------------------------------
#
# Rodada 6/8
# Clientes selecionados: [12 40  1]
# Cliente #12 | Acurácia: 0.9475446343421936 | ENVIANDO PRIMEIRA
# Cliente #40 | Acurácia: 0.9239864945411682 | ENVIANDO PRIMEIRA
# Cliente #1 | Acurácia: 0.9346314072608948 | Diferença dos pesos: 87.02201843261719
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 2
# Acurácia: 0.6244000196456909
# ----------------------------------------
#
# Rodada 7/8
# Clientes selecionados: [95 64 66]
# Cliente #95 | Acurácia: 0.9319484233856201 | ENVIANDO PRIMEIRA
# Cliente #64 | Acurácia: 0.9315155148506165 | ENVIANDO PRIMEIRA
# Cliente #66 | Acurácia: 0.9176245331764221 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6805999875068665
# ----------------------------------------
#
# Rodada 8/8
# Clientes selecionados: [63 76 38]
# Cliente #63 | Acurácia: 0.9195501804351807 | ENVIANDO PRIMEIRA
# Cliente #76 | Acurácia: 0.9224555492401123 | ENVIANDO PRIMEIRA
# Cliente #38 | Acurácia: 0.926182210445404 | Diferença dos pesos: 757.83349609375
# ENVIADO!
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6791999936103821
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [35.27680969238281, 12.285606384277344, 4.297112464904785, 2.9536969661712646, 2.0385756492614746, 1.794171690940857, 1.4567508697509766, 1.3095122575759888]
# Centralized accuracy: [0.4699000120162964, 0.6722000241279602, 0.7063000202178955, 0.6491000056266785, 0.6664999723434448, 0.6244000196456909, 0.6805999875068665, 0.6791999936103821]

# %%
def plotar_grafico_acuracia():
    fig, ax = plt.subplots(figsize=(3, 3))
    
    ax.set_ylabel('Acurácia', color='#000000', fontsize=12)
    ax.set_xlabel('Rodadas', color='#000000', fontsize=12)
    
    ax.set_ylim(auto=True)
    
    x1, y1 = [*range(len(acc_list[0]))], [np.mean(p) for p in zip(*acc_list)]
    ax.plot(x1, y1, linestyle = 'solid', color='#00aaff', linewidth = 1)
    y_min = [np.min(p) for p in zip(*acc_list)]
    y_max = [np.max(p) for p in zip(*acc_list)]
    ax.fill_between(x1, y_min, y_max, color='#00aaff', alpha=0.1)

# %%
def plotar_grafico_perda():
    fig, ax = plt.subplots(figsize=(3, 3))
    
    ax.set_ylabel('Perda', color='#000000', fontsize=12)
    ax.set_xlabel('Rodadas', color='#000000', fontsize=12)
    
    ax.set_ylim(auto=True)
    
    x1, y1 = [*range(len(loss_list[0]))], [np.mean(p) for p in zip(*loss_list)]
    ax.plot(x1, y1, linestyle = 'solid', color='#ff0000', linewidth = 1)
    y_min = [np.min(p) for p in zip(*loss_list)]
    y_max = [np.max(p) for p in zip(*loss_list)]
    ax.fill_between(x1, y_min, y_max, color='#ff0000', alpha=0.1)

# %%
def plotar_grafico_transmissoes():
    fig, ax = plt.subplots(figsize=(3, 3))
    
    ax.set_ylabel('Transmissões', color='#000000', fontsize=12)
    ax.set_xlabel('Rodadas', color='#000000', fontsize=12)
    
    ax.set_ylim(auto=True)
    
    x1, y1 = [*range(len(transmissions_list[0]))], [np.mean(p) for p in zip(*transmissions_list)]
    ax.plot(x1, y1, linestyle = 'solid', color='#44aa44', linewidth = 1)
    y_min = [np.min(p) for p in zip(*transmissions_list)]
    y_max = [np.max(p) for p in zip(*transmissions_list)]
    ax.fill_between(x1, y_min, y_max, color='#44aa44', alpha=0.1)

# %%
def plotar_grafico_transmissoes_acumuladas():
    acc_transmissions_list = [
        [np.sum(transmission_list[0:i]) for i in range(len(transmission_list))] 
        for transmission_list in transmissions_list
    ]
    
    fig, ax = plt.subplots(figsize=(3, 3))
    
    ax.set_ylabel('Transmissões Acumuladas', color='#000000', fontsize=12)
    ax.set_xlabel('Rodadas', color='#000000', fontsize=12)
    
    ax.set_ylim(auto=True)
    
    x1, y1 = [*range(len(acc_transmissions_list[0]))], [np.mean(p) for p in zip(*acc_transmissions_list)]
    ax.plot(x1, y1, linestyle = 'solid', color='#ffa500', linewidth = 1)
    y_min = [np.min(p) for p in zip(*acc_transmissions_list)]
    y_max = [np.max(p) for p in zip(*acc_transmissions_list)]
    ax.fill_between(x1, y_min, y_max, color='#ffa500', alpha=0.1)

# %%
def plotar_graficos():
    plotar_grafico_acuracia()
    plotar_grafico_perda()
    plotar_grafico_transmissoes()
    plotar_grafico_transmissoes_acumuladas()

plotar_graficos()

# %%
EPSILON_DELTA = 250

# %%
acc_list, loss_list, transmissions_list = [], [], []

for i in range(3):
    acc, loss, transmissions = executar(i)
    acc_list.append(acc)
    loss_list.append(loss)
    transmissions_list.append(transmissions)
# Out:
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
#
#
# ========================================
#                 INICIANDO
#         Clientes por rodada: 3
#
# Rodada 1/8
# Clientes selecionados: [98 21 56]
# Cliente #98 | Acurácia: 0.9199066758155823 | ENVIANDO PRIMEIRA
# Cliente #21 | Acurácia: 0.9155672788619995 | ENVIANDO PRIMEIRA
# Cliente #56 | Acurácia: 0.8476190567016602 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.5884000062942505
# ----------------------------------------
#
# Rodada 2/8
# Clientes selecionados: [34 62 38]
# Cliente #34 | Acurácia: 0.9296685457229614 | ENVIANDO PRIMEIRA
# Cliente #62 | Acurácia: 0.9580838084220886 | ENVIANDO PRIMEIRA
# Cliente #38 | Acurácia: 0.9296424388885498 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.7282000184059143
# ----------------------------------------
#
# Rodada 3/8
# Clientes selecionados: [20 68 38]
# Cliente #20 | Acurácia: 0.9225844144821167 | ENVIANDO PRIMEIRA
# Cliente #68 | Acurácia: 0.92946857213974 | ENVIANDO PRIMEIRA
# Cliente #38 | Acurácia: 0.931949257850647 | Diferença dos pesos: 140.54693603515625
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 2
# Acurácia: 0.7124999761581421
# ----------------------------------------
#
# Rodada 4/8
# Clientes selecionados: [99 63  1]
# Cliente #99 | Acurácia: 0.918809175491333 | ENVIANDO PRIMEIRA
# Cliente #63 | Acurácia: 0.9342560768127441 | ENVIANDO PRIMEIRA
# Cliente #1 | Acurácia: 0.9485396146774292 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6972000002861023
# ----------------------------------------
#
# Rodada 5/8
# Clientes selecionados: [14 95 59]
# Cliente #14 | Acurácia: 0.9184624552726746 | ENVIANDO PRIMEIRA
# Cliente #95 | Acurácia: 0.9348137378692627 | ENVIANDO PRIMEIRA
# Cliente #59 | Acurácia: 0.9238095283508301 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6736000180244446
# ----------------------------------------
#
# Rodada 6/8
# Clientes selecionados: [25  4 32]
# Cliente #25 | Acurácia: 0.921818196773529 | ENVIANDO PRIMEIRA
# Cliente #4 | Acurácia: 0.9299308061599731 | ENVIANDO PRIMEIRA
# Cliente #32 | Acurácia: 0.9479866027832031 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6642000079154968
# ----------------------------------------
#
# Rodada 7/8
# Clientes selecionados: [61 57 12]
# Cliente #61 | Acurácia: 0.953346848487854 | ENVIANDO PRIMEIRA
# Cliente #57 | Acurácia: 0.9322210550308228 | ENVIANDO PRIMEIRA
# Cliente #12 | Acurácia: 0.9564732313156128 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6972000002861023
# ----------------------------------------
#
# Rodada 8/8
# Clientes selecionados: [51 56 43]
# Cliente #51 | Acurácia: 0.9470751881599426 | ENVIANDO PRIMEIRA
# Cliente #56 | Acurácia: 0.8342857360839844 | Diferença dos pesos: 6821.82177734375
# ENVIADO!
# Cliente #43 | Acurácia: 0.9276155829429626 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.7193999886512756
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [17.72953987121582, 7.4057936668396, 6.267667293548584, 3.231379747390747, 1.690981388092041, 1.532836675643921, 1.4170385599136353, 1.3217976093292236]
# Centralized accuracy: [0.5884000062942505, 0.7282000184059143, 0.7124999761581421, 0.6972000002861023, 0.6736000180244446, 0.6642000079154968, 0.6972000002861023, 0.7193999886512756]
#
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
#
#
# ========================================
#                 INICIANDO
#         Clientes por rodada: 3
#
# Rodada 1/8
# Clientes selecionados: [12 40 33]
# Cliente #12 | Acurácia: 0.9363839030265808 | ENVIANDO PRIMEIRA
# Cliente #40 | Acurácia: 0.9104729890823364 | ENVIANDO PRIMEIRA
# Cliente #33 | Acurácia: 0.9159256219863892 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.6322000026702881
# ----------------------------------------
#
# Rodada 2/8
# Clientes selecionados: [33 73 18]
# Cliente #33 | Acurácia: 0.9240096807479858 | Diferença dos pesos: 61.04571533203125
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# Cliente #73 | Acurácia: 0.9313487410545349 | ENVIANDO PRIMEIRA
# Cliente #18 | Acurácia: 0.919593334197998 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 2
# Acurácia: 0.6870999932289124
# ----------------------------------------
#
# Rodada 3/8
# Clientes selecionados: [76 18 24]
# Cliente #76 | Acurácia: 0.9046849608421326 | ENVIANDO PRIMEIRA
# Cliente #18 | Acurácia: 0.9343807697296143 | Diferença dos pesos: 100.70824432373047
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# Cliente #24 | Acurácia: 0.9290697574615479 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 2
# Acurácia: 0.6754000186920166
# ----------------------------------------
#
# Rodada 4/8
# Clientes selecionados: [33 41 71]
# Cliente #33 | Acurácia: 0.9256265163421631 | Diferença dos pesos: 387.4481201171875
# ENVIADO!
# Cliente #41 | Acurácia: 0.9142857193946838 | ENVIANDO PRIMEIRA
# Cliente #71 | Acurácia: 0.9458598494529724 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.6628999710083008
# ----------------------------------------
#
# Rodada 5/8
# Clientes selecionados: [90 18 96]
# Cliente #90 | Acurácia: 0.933018147945404 | ENVIANDO PRIMEIRA
# Cliente #18 | Acurácia: 0.9316081404685974 | Diferença dos pesos: 319.1156311035156
# ENVIADO!
# Cliente #96 | Acurácia: 0.9058441519737244 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.5916000008583069
# ----------------------------------------
#
# Rodada 6/8
# Clientes selecionados: [16  4 96]
# Cliente #16 | Acurácia: 0.8947368264198303 | ENVIANDO PRIMEIRA
# Cliente #4 | Acurácia: 0.9186851382255554 | ENVIANDO PRIMEIRA
# Cliente #96 | Acurácia: 0.9034090638160706 | Diferença dos pesos: 55.169273376464844
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 2
# Acurácia: 0.5874000191688538
# ----------------------------------------
#
# Rodada 7/8
# Clientes selecionados: [30 61 55]
# Cliente #30 | Acurácia: 0.931382417678833 | ENVIANDO PRIMEIRA
# Cliente #61 | Acurácia: 0.9432048797607422 | ENVIANDO PRIMEIRA
# Cliente #55 | Acurácia: 0.909967839717865 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.6137999892234802
# ----------------------------------------
#
# Rodada 8/8
# Clientes selecionados: [84 55 13]
# Cliente #84 | Acurácia: 0.9145945906639099 | ENVIANDO PRIMEIRA
# Cliente #55 | Acurácia: 0.9324758648872375 | Diferença dos pesos: 46.58594512939453
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# Cliente #13 | Acurácia: 0.931034505367279 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 2
# Acurácia: 0.6359999775886536
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [14.850506782531738, 7.751108169555664, 4.903213977813721, 2.9576196670532227, 1.808726191520691, 1.5712285041809082, 1.3388742208480835, 1.28550124168396]
# Centralized accuracy: [0.6322000026702881, 0.6870999932289124, 0.6754000186920166, 0.6628999710083008, 0.5916000008583069, 0.5874000191688538, 0.6137999892234802, 0.6359999775886536]
#
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
#
#
# ========================================
#                 INICIANDO
#         Clientes por rodada: 3
#
# Rodada 1/8
# Clientes selecionados: [89 11  6]
# Cliente #89 | Acurácia: 0.8495762944221497 | ENVIANDO PRIMEIRA
# Cliente #11 | Acurácia: 0.9071038365364075 | ENVIANDO PRIMEIRA
# Cliente #6 | Acurácia: 0.8896418213844299 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.5162000060081482
# ----------------------------------------
#
# Rodada 2/8
# Clientes selecionados: [46 84 26]
# Cliente #46 | Acurácia: 0.9338138699531555 | ENVIANDO PRIMEIRA
# Cliente #84 | Acurácia: 0.9124324321746826 | ENVIANDO PRIMEIRA
# Cliente #26 | Acurácia: 0.9193083643913269 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6899999976158142
# ----------------------------------------
#
# Rodada 3/8
# Clientes selecionados: [56  7 52]
# Cliente #56 | Acurácia: 0.9085714221000671 | ENVIANDO PRIMEIRA
# Cliente #7 | Acurácia: 0.9510278105735779 | ENVIANDO PRIMEIRA
# Cliente #52 | Acurácia: 0.9429429173469543 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6947000026702881
# ----------------------------------------
#
# Rodada 4/8
# Clientes selecionados: [19 21 71]
# Cliente #19 | Acurácia: 0.9276094436645508 | ENVIANDO PRIMEIRA
# Cliente #21 | Acurácia: 0.9278804063796997 | ENVIANDO PRIMEIRA
# Cliente #71 | Acurácia: 0.9420382380485535 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.671999990940094
# ----------------------------------------
#
# Rodada 5/8
# Clientes selecionados: [39 49 20]
# Cliente #39 | Acurácia: 0.9434464573860168 | ENVIANDO PRIMEIRA
# Cliente #49 | Acurácia: 0.9061583280563354 | ENVIANDO PRIMEIRA
# Cliente #20 | Acurácia: 0.9173457622528076 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.5928000211715698
# ----------------------------------------
#
# Rodada 6/8
# Clientes selecionados: [34 30 91]
# Cliente #34 | Acurácia: 0.9215844869613647 | ENVIANDO PRIMEIRA
# Cliente #30 | Acurácia: 0.9364278316497803 | ENVIANDO PRIMEIRA
# Cliente #91 | Acurácia: 0.9544287323951721 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6312000155448914
# ----------------------------------------
#
# Rodada 7/8
# Clientes selecionados: [11 59 76]
# Cliente #11 | Acurácia: 0.9125683307647705 | Diferença dos pesos: 679.1279296875
# ENVIADO!
# Cliente #59 | Acurácia: 0.9350649118423462 | ENVIANDO PRIMEIRA
# Cliente #76 | Acurácia: 0.9127625226974487 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.5928000211715698
# ----------------------------------------
#
# Rodada 8/8
# Clientes selecionados: [81 40 71]
# Cliente #81 | Acurácia: 0.9420289993286133 | ENVIANDO PRIMEIRA
# Cliente #40 | Acurácia: 0.9391891956329346 | ENVIANDO PRIMEIRA
# Cliente #71 | Acurácia: 0.9541401267051697 | Diferença dos pesos: 592.35791015625
# ENVIADO!
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.7258999943733215
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [23.720129013061523, 8.251177787780762, 5.335878372192383, 2.2367122173309326, 1.871414303779602, 1.4522345066070557, 1.4812963008880615, 1.506341576576233]
# Centralized accuracy: [0.5162000060081482, 0.6899999976158142, 0.6947000026702881, 0.671999990940094, 0.5928000211715698, 0.6312000155448914, 0.5928000211715698, 0.7258999943733215]

# %%
plotar_graficos()

# %%
EPSILON_DELTA = 150

acc_list, loss_list, transmissions_list = [], [], []

for i in range(3):
    acc, loss, transmissions = executar(i)
    acc_list.append(acc)
    loss_list.append(loss)
    transmissions_list.append(transmissions)
# Out:
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
#
#
# ========================================
#                 INICIANDO
#         Clientes por rodada: 3
#
# Rodada 1/8
# Clientes selecionados: [ 8 47 49]
# Cliente #8 | Acurácia: 0.9116607904434204 | ENVIANDO PRIMEIRA
# Cliente #47 | Acurácia: 0.9196617603302002 | ENVIANDO PRIMEIRA
# Cliente #49 | Acurácia: 0.8944281339645386 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.5823000073432922
# ----------------------------------------
#
# Rodada 2/8
# Clientes selecionados: [19 99 60]
# Cliente #19 | Acurácia: 0.9183501601219177 | ENVIANDO PRIMEIRA
# Cliente #99 | Acurácia: 0.9174560308456421 | ENVIANDO PRIMEIRA
# Cliente #60 | Acurácia: 0.9390401840209961 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6577000021934509
# ----------------------------------------
#
# Rodada 3/8
# Clientes selecionados: [77 86 20]
# Cliente #77 | Acurácia: 0.9443155527114868 | ENVIANDO PRIMEIRA
# Cliente #86 | Acurácia: 0.9197860956192017 | ENVIANDO PRIMEIRA
# Cliente #20 | Acurácia: 0.9313154816627502 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6843000054359436
# ----------------------------------------
#
# Rodada 4/8
# Clientes selecionados: [87 49 48]
# Cliente #87 | Acurácia: 0.9412524104118347 | ENVIANDO PRIMEIRA
# Cliente #49 | Acurácia: 0.9178885817527771 | Diferença dos pesos: 604.421142578125
# ENVIADO!
# Cliente #48 | Acurácia: 0.9239835143089294 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6859999895095825
# ----------------------------------------
#
# Rodada 5/8
# Clientes selecionados: [49  4 95]
# Cliente #49 | Acurácia: 0.9046920537948608 | Diferença dos pesos: 126.00421142578125
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# Cliente #4 | Acurácia: 0.9212802648544312 | ENVIANDO PRIMEIRA
# Cliente #95 | Acurácia: 0.934097409248352 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 2
# Acurácia: 0.6869999766349792
# ----------------------------------------
#
# Rodada 6/8
# Clientes selecionados: [ 8 82 16]
# Cliente #8 | Acurácia: 0.9204946756362915 | Diferença dos pesos: 628.2808227539062
# ENVIADO!
# Cliente #82 | Acurácia: 0.9438902735710144 | ENVIANDO PRIMEIRA
# Cliente #16 | Acurácia: 0.9046052694320679 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.637499988079071
# ----------------------------------------
#
# Rodada 7/8
# Clientes selecionados: [15 74 52]
# Cliente #15 | Acurácia: 0.9376181364059448 | ENVIANDO PRIMEIRA
# Cliente #74 | Acurácia: 0.9219735860824585 | ENVIANDO PRIMEIRA
# Cliente #52 | Acurácia: 0.9369369149208069 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 3
# Acurácia: 0.6832000017166138
# ----------------------------------------
#
# Rodada 8/8
# Clientes selecionados: [16 90 39]
# Cliente #16 | Acurácia: 0.9243420958518982 | Diferença dos pesos: 70.60810089111328
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# Cliente #90 | Acurácia: 0.9282900094985962 | ENVIANDO PRIMEIRA
# Cliente #39 | Acurácia: 0.9328010678291321 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #0
# Transmissões nesta rodada: 2
# Acurácia: 0.6934999823570251
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [22.81158447265625, 12.386082649230957, 6.462207794189453, 2.6002891063690186, 1.6967746019363403, 1.5993194580078125, 1.3720532655715942, 1.2294487953186035]
# Centralized accuracy: [0.5823000073432922, 0.6577000021934509, 0.6843000054359436, 0.6859999895095825, 0.6869999766349792, 0.637499988079071, 0.6832000017166138, 0.6934999823570251]
#
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
#
#
# ========================================
#                 INICIANDO
#         Clientes por rodada: 3
#
# Rodada 1/8
# Clientes selecionados: [ 2 63 93]
# Cliente #2 | Acurácia: 0.9349315166473389 | ENVIANDO PRIMEIRA
# Cliente #63 | Acurácia: 0.9013840556144714 | ENVIANDO PRIMEIRA
# Cliente #93 | Acurácia: 0.8768267035484314 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.5030999779701233
# ----------------------------------------
#
# Rodada 2/8
# Clientes selecionados: [70 99 52]
# Cliente #70 | Acurácia: 0.9243884086608887 | ENVIANDO PRIMEIRA
# Cliente #99 | Acurácia: 0.874154269695282 | ENVIANDO PRIMEIRA
# Cliente #52 | Acurácia: 0.9339339137077332 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.630299985408783
# ----------------------------------------
#
# Rodada 3/8
# Clientes selecionados: [46 17 32]
# Cliente #46 | Acurácia: 0.912188708782196 | ENVIANDO PRIMEIRA
# Cliente #17 | Acurácia: 0.9421423077583313 | ENVIANDO PRIMEIRA
# Cliente #32 | Acurácia: 0.948825478553772 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.6520000100135803
# ----------------------------------------
#
# Rodada 4/8
# Clientes selecionados: [23  2 12]
# Cliente #23 | Acurácia: 0.8778004050254822 | ENVIANDO PRIMEIRA
# Cliente #2 | Acurácia: 0.9520547986030579 | Diferença dos pesos: 197.80905151367188
# ENVIADO!
# Cliente #12 | Acurácia: 0.9296875 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.6269000172615051
# ----------------------------------------
#
# Rodada 5/8
# Clientes selecionados: [44  7 71]
# Cliente #44 | Acurácia: 0.9216446876525879 | ENVIANDO PRIMEIRA
# Cliente #7 | Acurácia: 0.9455864429473877 | ENVIANDO PRIMEIRA
# Cliente #71 | Acurácia: 0.9490445852279663 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.6467000246047974
# ----------------------------------------
#
# Rodada 6/8
# Clientes selecionados: [18 15 16]
# Cliente #18 | Acurácia: 0.9279112815856934 | ENVIANDO PRIMEIRA
# Cliente #15 | Acurácia: 0.9149338603019714 | ENVIANDO PRIMEIRA
# Cliente #16 | Acurácia: 0.9078947305679321 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.6078000068664551
# ----------------------------------------
#
# Rodada 7/8
# Clientes selecionados: [ 2 43 67]
# Cliente #2 | Acurácia: 0.9366438388824463 | Diferença dos pesos: 186.14772033691406
# ENVIADO!
# Cliente #43 | Acurácia: 0.9367396831512451 | ENVIANDO PRIMEIRA
# Cliente #67 | Acurácia: 0.9360655546188354 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.682200014591217
# ----------------------------------------
#
# Rodada 8/8
# Clientes selecionados: [66 14 70]
# Cliente #66 | Acurácia: 0.9176245331764221 | ENVIANDO PRIMEIRA
# Cliente #14 | Acurácia: 0.9347699284553528 | ENVIANDO PRIMEIRA
# Cliente #70 | Acurácia: 0.9318013191223145 | Diferença dos pesos: 878.84130859375
# ENVIADO!
# ----------------------------------------
# Execução #1
# Transmissões nesta rodada: 3
# Acurácia: 0.6772000193595886
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [21.503828048706055, 9.720446586608887, 3.6942298412323, 2.70660138130188, 1.4521819353103638, 1.4072238206863403, 1.2629921436309814, 1.2384096384048462]
# Centralized accuracy: [0.5030999779701233, 0.630299985408783, 0.6520000100135803, 0.6269000172615051, 0.6467000246047974, 0.6078000068664551, 0.682200014591217, 0.6772000193595886]
#
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
#
#
# ========================================
#                 INICIANDO
#         Clientes por rodada: 3
#
# Rodada 1/8
# Clientes selecionados: [93 64 66]
# Cliente #93 | Acurácia: 0.8643006086349487 | ENVIANDO PRIMEIRA
# Cliente #64 | Acurácia: 0.9105897545814514 | ENVIANDO PRIMEIRA
# Cliente #66 | Acurácia: 0.9118773937225342 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.60589998960495
# ----------------------------------------
#
# Rodada 2/8
# Clientes selecionados: [29 25 68]
# Cliente #29 | Acurácia: 0.8852459192276001 | ENVIANDO PRIMEIRA
# Cliente #25 | Acurácia: 0.8945454359054565 | ENVIANDO PRIMEIRA
# Cliente #68 | Acurácia: 0.9342995285987854 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6445000171661377
# ----------------------------------------
#
# Rodada 3/8
# Clientes selecionados: [24 87 89]
# Cliente #24 | Acurácia: 0.9279069900512695 | ENVIANDO PRIMEIRA
# Cliente #87 | Acurácia: 0.9347966313362122 | ENVIANDO PRIMEIRA
# Cliente #89 | Acurácia: 0.9046609997749329 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6183000206947327
# ----------------------------------------
#
# Rodada 4/8
# Clientes selecionados: [24  6 74]
# Cliente #24 | Acurácia: 0.9209302067756653 | Diferença dos pesos: 77.41188049316406
# weight_diff < EPSILON_DELTA. O modelo não será transmitido.
# Cliente #6 | Acurácia: 0.907066822052002 | ENVIANDO PRIMEIRA
# Cliente #74 | Acurácia: 0.9328743815422058 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 2
# Acurácia: 0.5493999719619751
# ----------------------------------------
#
# Rodada 5/8
# Clientes selecionados: [ 5 73 44]
# Cliente #5 | Acurácia: 0.93359375 | ENVIANDO PRIMEIRA
# Cliente #73 | Acurácia: 0.9277034997940063 | ENVIANDO PRIMEIRA
# Cliente #44 | Acurácia: 0.9286268353462219 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6340000033378601
# ----------------------------------------
#
# Rodada 6/8
# Clientes selecionados: [ 9 69 42]
# Cliente #9 | Acurácia: 0.9137343764305115 | ENVIANDO PRIMEIRA
# Cliente #69 | Acurácia: 0.9204188585281372 | ENVIANDO PRIMEIRA
# Cliente #42 | Acurácia: 0.9522203207015991 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.6324999928474426
# ----------------------------------------
#
# Rodada 7/8
# Clientes selecionados: [27 86 21]
# Cliente #27 | Acurácia: 0.947169840335846 | ENVIANDO PRIMEIRA
# Cliente #86 | Acurácia: 0.9233511686325073 | ENVIANDO PRIMEIRA
# Cliente #21 | Acurácia: 0.9384344816207886 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.7199000120162964
# ----------------------------------------
#
# Rodada 8/8
# Clientes selecionados: [22 39 43]
# Cliente #22 | Acurácia: 0.9641226530075073 | ENVIANDO PRIMEIRA
# Cliente #39 | Acurácia: 0.946773111820221 | ENVIANDO PRIMEIRA
# Cliente #43 | Acurácia: 0.937347948551178 | ENVIANDO PRIMEIRA
# ----------------------------------------
# Execução #2
# Transmissões nesta rodada: 3
# Acurácia: 0.7418000102043152
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [11.598140716552734, 5.705543041229248, 2.2823946475982666, 2.1477746963500977, 1.3964343070983887, 1.423547625541687, 1.2156230211257935, 1.1364428997039795]
# Centralized accuracy: [0.60589998960495, 0.6445000171661377, 0.6183000206947327, 0.5493999719619751, 0.6340000033378601, 0.6324999928474426, 0.7199000120162964, 0.7418000102043152]

# %%
plotar_graficos()
