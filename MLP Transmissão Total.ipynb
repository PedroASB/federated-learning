# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ### Modelo

# %%
class ModelMLP:
    @staticmethod
    def create_model():
        model = tf.keras.models.Sequential(
            [
                tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784,)),
                tf.keras.layers.Dense(10, activation="softmax")
            ]
        )
        model.compile(
            optimizer=tf.keras.optimizers.Adam(),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=['accuracy']
        )
        return model

# %%
# Definição dos parâmetros
NUMBER_OF_ROUNDS = 100
TOTAL_CLIENTS = 100
CLIENTS_PER_ROUND = 10

# %% [markdown]
# ### Cliente

# %%
class Client():
    def __init__(self, cid):
        self.cid = int(cid)
        self.model = ModelMLP.create_model()
        self.old_weights = None
        (self.x_train, self.y_train), (self.x_test, self.y_test) = self.load_data()


    def load_data(self):
        path = "./dataset-mnist/non-iid-0.9-100-rotation-45"

        train = pd.read_pickle(f"{path}/{self.cid+1}_train.pickle")
        test = pd.read_pickle(f"{path}/{self.cid+1}_test.pickle")

        x_train = train.drop(['label'], axis=1)
        y_train = train['label']

        x_test = test.drop(['label'], axis=1)
        y_test = test['label']

        return (x_train, y_train), (x_test, y_test)


    def fit(self, parameters, config=None):
        self.model.set_weights(parameters)
        history = self.model.fit(self.x_train, self.y_train, epochs=5, batch_size=128, validation_data=(self.x_test, self.y_test), verbose=False)
        sample_size = len(self.x_train)
        print(f"Acurácia: {history.history['val_accuracy'][-1]} | ")
        return self.model.get_weights(), sample_size, {"val_accuracy": history.history['val_accuracy'][-1], 
                                                       "val_loss": history.history['val_loss'][-1]}


    def evaluate(self, parameters):
        self.model.set_weights(parameters)
        return self.model.evaluate(self.x_test, self.y_test, verbose=False)

# %% [markdown]
# ### Servidor

# %%
class Server():
    def __init__(self, n_rounds, total_number_clients, min_fit_clients):
        self.n_rounds = n_rounds
        self.total_number_clients = total_number_clients
        self.min_fit_clients = min_fit_clients

        self.server_round = 0
        self.selected_clients = []
        self.model = ModelMLP.create_model()
        self.w_global = self.model.get_weights()

        self.clients_model_list = []
        # Vamos guardar todos os modelos (pesos) anteriores, mas não é necessário
        self.clients_previous_models_list = [ [] for _ in range(total_number_clients) ]
        self.create_models()
        (self.x_train, self.y_train), (self.x_test, self.y_test) = self.load_data()


    def load_data(self):
        path = "./dataset-mnist/mnist"

        train = pd.read_pickle(f"{path}/train.pickle")
        test = pd.read_pickle(f"{path}/test.pickle")

        x_train = train.drop(['label'], axis=1)
        y_train = train['label']

        # test = pd.concat([test, train])
        x_test = test.drop(['label'], axis=1)
        y_test = test['label']

        return (x_train, y_train), (x_test, y_test)


    def create_models(self):
        for i in range(self.total_number_clients):
            self.clients_model_list.append(Client(i))


    def aggregate_fit(self, weight_list, sample_sizes):
        self.w_global = []
        for weights in zip(*weight_list):
            weighted_sum = 0
            total_samples = sum(sample_sizes)
            for i in range(len(weights)):
                weighted_sum += weights[i] * sample_sizes[i]
            self.w_global.append(weighted_sum / total_samples)


    def configure_fit(self):
        self.selected_clients = np.random.permutation(list(range(self.total_number_clients)))[:self.min_fit_clients]
        print(f"Clientes selecionados: \033[34;1m{np.array(self.selected_clients) + 1}\033[37;0m")

    
    def get_client_previous_model(self, client_id):
        return self.clients_previous_models_list[client_id][-1]


    def save_client_previous_model(self, client_id, model):
        self.clients_previous_models_list[client_id].append(model)


    def fit(self):
        weight_list, sample_sizes_list, info_list, transmissions_count = [], [], [], 0
        for i, pos in enumerate(self.selected_clients):
            print(f"Cliente #{pos+1} | ", end='')

            # Se o cliente decidir não enviar o modelo, ele retorna um None
            new_model = self.clients_model_list[pos].fit(parameters=self.w_global)

            weights, size, info = new_model if new_model is not None else self.get_client_previous_model(pos)
            weight_list.append(weights)
            sample_sizes_list.append(size)
            info_list.append(info)

            # Se o cliente enviou um novo modelo, salve-o e incremente a contagem de transmissões
            if new_model is not None:
                self.save_client_previous_model(pos, (weights, size, info_list))
                transmissions_count += 1

        return weight_list, sample_sizes_list, {"acc_loss_local":[(pos+1, info_list[i]) for i, pos in enumerate(self.selected_clients)]}, transmissions_count


    def distributed_evaluation(self):
        loss_list, accuracy_list = [], []
        for i in range(self.total_number_clients):
            loss, accuracy = self.clients_model_list[i].evaluate(parameters=self.w_global)
            # print(f"Evaluate - CID: {i+1} - accuracy: {accuracy}")
            loss_list.append(loss)
            accuracy_list.append(accuracy)
        return sum(loss_list) / len(loss_list), sum(accuracy_list) / len(accuracy_list), {"accuracy_list": [(i+1, accuracy) for i, accuracy in enumerate(accuracy_list)]}


    def centralized_evaluation(self):
        self.model.set_weights(self.w_global)
        return self.model.evaluate(self.x_test, self.y_test, verbose=False)

# %% [markdown]
# ### Exemplo de Execução

# %%
def executar(id):
    print(f"EXECUÇÃO {id}")

    print('\n' + '='*40)
    print("{:^54}".format('\033[;1m' + 'CARREGAMENTO DE DADOS' + '\033[37;0m'))
    print("{:^40}".format(f'Número total de clientes: {TOTAL_CLIENTS}' + '\n'))
    
    s = Server(n_rounds=NUMBER_OF_ROUNDS,
               total_number_clients=TOTAL_CLIENTS,
               min_fit_clients=CLIENTS_PER_ROUND)
    
    print('\n' + '='*40)
    print("{:^54}".format('\033[;1m' + 'INICIANDO' + '\033[37;0m'))
    print("{:^40}".format(f'Clientes por rodada: {CLIENTS_PER_ROUND} ' + '\n'))
    
    evaluate_list = {"distributed": {"loss":[], "accuracy":[]}, "centralized": {"loss":[], "accuracy":[]}}
    
    transmissions_per_round = []
    
    # Rodadas de comunicação
    for s.server_round in range(s.n_rounds):
        print('\033[;1m' + f'Rodada {s.server_round+1}/{s.n_rounds}' + '\033[37;0m')
    
        # Seleciona os clientes que participarão da próxima rodada de comunicação
        s.configure_fit()
    
        # Treinamento local do dispositivo
        weight_list, sample_sizes, info, transmissions_count = s.fit()
    
        # Salva a quantidade de transmissões ocorridas nesta rodada
        transmissions_per_round.append(transmissions_count)
    
        # Agregação
        s.aggregate_fit(weight_list, sample_sizes)
    
        # Avaliação centralizada
        print('\033[3;1m' + '-'*40 + '\033[37;0m')
        # print(f"Avaliação centralizada")
        evaluate_loss, evaluate_accuracy = s.centralized_evaluation()
        print(f"[#{id}] Transmissões nesta rodada: {transmissions_count}")
        print(f"Acurácia: {evaluate_accuracy}")
        evaluate_list["centralized"]["loss"].append(evaluate_loss)
        evaluate_list["centralized"]["accuracy"].append(evaluate_accuracy)
        print('\033[3;1m' + '-'*40 + '\033[37;0m' + '\n')
    
    print('\n\n' + '='*40)
    print("{:^54}".format('\033[;1m' + 'RESULTADOS FINAIS' + '\033[37;0m'))
    print(f"\nCentralized loss: ", end='')
    print(evaluate_list["centralized"]["loss"])
    print(f"Centralized accuracy: ", end='')
    print(evaluate_list["centralized"]["accuracy"])

    return evaluate_accuracy, evaluate_loss, transmissions_per_round
# Out:
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ========================================
#                 INICIANDO
#        Clientes por rodada: 10
#
# Rodada 1/100
# Clientes selecionados: [50 93 44 87 28 27 29 79 14 39]
# Cliente #50 | Acurácia: 0.8816046714782715 |
# Cliente #93 | Acurácia: 0.8643006086349487 |
# Cliente #44 | Acurácia: 0.9123351573944092 |
# Cliente #87 | Acurácia: 0.9380245208740234 |
# Cliente #28 | Acurácia: 0.9167927503585815 |
# Cliente #27 | Acurácia: 0.9320755004882812 |
# Cliente #29 | Acurácia: 0.87613844871521 |
# Cliente #79 | Acurácia: 0.9061661958694458 |
# Cliente #14 | Acurácia: 0.9021549224853516 |
# Cliente #39 | Acurácia: 0.9068529605865479 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.5656999945640564
# ----------------------------------------
#
# Rodada 2/100
# Clientes selecionados: [56 37  4 92 68 16 27 48 98 79]
# Cliente #56 | Acurácia: 0.8895238041877747 |
# Cliente #37 | Acurácia: 0.9255120754241943 |
# Cliente #4 | Acurácia: 0.9290657639503479 |
# Cliente #92 | Acurácia: 0.9652817249298096 |
# Cliente #68 | Acurácia: 0.9323671460151672 |
# Cliente #16 | Acurácia: 0.8963815569877625 |
# Cliente #27 | Acurácia: 0.9292452931404114 |
# Cliente #48 | Acurácia: 0.931644082069397 |
# Cliente #98 | Acurácia: 0.9362363815307617 |
# Cliente #79 | Acurácia: 0.9128686189651489 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.6812999844551086
# ----------------------------------------
#
# Rodada 3/100
# Clientes selecionados: [53 12 85 83 34 55 60 86 16  4]
# Cliente #53 | Acurácia: 0.9190448522567749 |
# Cliente #12 | Acurácia: 0.9520089030265808 |
# Cliente #85 | Acurácia: 0.9256756901741028 |
# Cliente #83 | Acurácia: 0.9221556782722473 |
# Cliente #34 | Acurácia: 0.9151172041893005 |
# Cliente #55 | Acurácia: 0.923901379108429 |
# Cliente #60 | Acurácia: 0.9118028283119202 |
# Cliente #86 | Acurácia: 0.916221022605896 |
# Cliente #16 | Acurácia: 0.8898026347160339 |
# Cliente #4 | Acurácia: 0.9264705777168274 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.6359999775886536
# ----------------------------------------
#
# Rodada 4/100
# Clientes selecionados: [61 64 11 44 97 63 78 75 67 50]
# Cliente #61 | Acurácia: 0.9411764740943909 |
# Cliente #64 | Acurácia: 0.9213696718215942 |
# Cliente #11 | Acurácia: 0.9107468128204346 |
# Cliente #44 | Acurácia: 0.9231962561607361 |
# Cliente #97 | Acurácia: 0.9447513818740845 |
# Cliente #63 | Acurácia: 0.9221453070640564 |
# Cliente #78 | Acurácia: 0.9358490705490112 |
# Cliente #75 | Acurácia: 0.9257221221923828 |
# Cliente #67 | Acurácia: 0.9393442869186401 |
# Cliente #50 | Acurácia: 0.9021526575088501 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.5823000073432922
# ----------------------------------------
#
# Rodada 5/100
# Clientes selecionados: [81 68 75  2 30 40 86 23 69 72]
# Cliente #81 | Acurácia: 0.9328063130378723 |
# Cliente #68 | Acurácia: 0.9323671460151672 |
# Cliente #75 | Acurácia: 0.9229711294174194 |
# Cliente #2 | Acurácia: 0.9417808055877686 |
# Cliente #30 | Acurácia: 0.9273461103439331 |
# Cliente #40 | Acurácia: 0.9087837934494019 |
# Cliente #86 | Acurácia: 0.9126559495925903 |
# Cliente #23 | Acurácia: 0.8818737268447876 |
# Cliente #69 | Acurácia: 0.9172775149345398 |
# Cliente #72 | Acurácia: 0.9340835809707642 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.5533999800682068
# ----------------------------------------
#
# Rodada 6/100
# Clientes selecionados: [46 81 93 54 11 63 17  4 20 55]
# Cliente #46 | Acurácia: 0.9252948760986328 |
# Cliente #81 | Acurácia: 0.9407114386558533 |
# Cliente #93 | Acurácia: 0.887265145778656 |
# Cliente #54 | Acurácia: 0.9248737096786499 |
# Cliente #11 | Acurácia: 0.9107468128204346 |
# Cliente #63 | Acurácia: 0.9230104088783264 |
# Cliente #17 | Acurácia: 0.945269763469696 |
# Cliente #4 | Acurácia: 0.9282007217407227 |
# Cliente #20 | Acurácia: 0.9185099005699158 |
# Cliente #55 | Acurácia: 0.9281886219978333 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.6049000024795532
# ----------------------------------------
#
# Rodada 7/100
# Clientes selecionados: [98 20 15 85 94  1 61  3 37 84]
# Cliente #98 | Acurácia: 0.926127552986145 |
# Cliente #20 | Acurácia: 0.9231664538383484 |
# Cliente #15 | Acurácia: 0.9281663298606873 |
# Cliente #85 | Acurácia: 0.9418919086456299 |
# Cliente #94 | Acurácia: 0.9434239268302917 |
# Cliente #1 | Acurácia: 0.9360222816467285 |
# Cliente #61 | Acurácia: 0.9269776940345764 |
# Cliente #3 | Acurácia: 0.9318370819091797 |
# Cliente #37 | Acurácia: 0.9292364716529846 |
# Cliente #84 | Acurácia: 0.9340540766716003 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.6825000047683716
# ----------------------------------------
#
# Rodada 8/100
# Clientes selecionados: [85 97 61 40 71 41 39 68 65 24]
# Cliente #85 | Acurácia: 0.9439189434051514 |
# Cliente #97 | Acurácia: 0.9524862170219421 |
# Cliente #61 | Acurácia: 0.9492900371551514 |
# Cliente #40 | Acurácia: 0.9391891956329346 |
# Cliente #71 | Acurácia: 0.9471337795257568 |
# Cliente #41 | Acurácia: 0.9321428537368774 |
# Cliente #39 | Acurácia: 0.9328010678291321 |
# Cliente #68 | Acurácia: 0.9342995285987854 |
# Cliente #65 | Acurácia: 0.9444043040275574 |
# Cliente #24 | Acurácia: 0.9441860318183899 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.7350999712944031
# ----------------------------------------
#
# Rodada 9/100
# Clientes selecionados: [84 63 94 49  5 86 73 28 24 40]
# Cliente #84 | Acurácia: 0.9362162351608276 |
# Cliente #63 | Acurácia: 0.9368512034416199 |
# Cliente #94 | Acurácia: 0.9507715106010437 |
# Cliente #49 | Acurácia: 0.9222874045372009 |
# Cliente #5 | Acurácia: 0.946093738079071 |
# Cliente #86 | Acurácia: 0.9108734130859375 |
# Cliente #73 | Acurácia: 0.9319562315940857 |
# Cliente #28 | Acurácia: 0.925869882106781 |
# Cliente #24 | Acurácia: 0.9383720755577087 |
# Cliente #40 | Acurácia: 0.9324324131011963 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.7027999758720398
# ----------------------------------------
#
# Rodada 10/100
# Clientes selecionados: [ 5 53 90 95 23 73 85 62 41 34]
# Cliente #5 | Acurácia: 0.9437500238418579 |
# Cliente #53 | Acurácia: 0.9365171790122986 |
# Cliente #90 | Acurácia: 0.9385342597961426 |
# Cliente #95 | Acurácia: 0.9441260695457458 |
# Cliente #23 | Acurácia: 0.9083502888679504 |
# Cliente #73 | Acurácia: 0.942284345626831 |
# Cliente #85 | Acurácia: 0.9459459185600281 |
# Cliente #62 | Acurácia: 0.958832323551178 |
# Cliente #41 | Acurácia: 0.9446428418159485 |
# Cliente #34 | Acurácia: 0.9288601279258728 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.777400016784668
# ----------------------------------------
#
# Rodada 11/100
# Clientes selecionados: [ 1 24 31 15 75 48 96 80  9  2]
# Cliente #1 | Acurácia: 0.9457579851150513 |
# Cliente #24 | Acurácia: 0.9418604373931885 |
# Cliente #31 | Acurácia: 0.9499536752700806 |
# Cliente #15 | Acurácia: 0.9470699429512024 |
# Cliente #75 | Acurácia: 0.935350775718689 |
# Cliente #48 | Acurácia: 0.9534472823143005 |
# Cliente #96 | Acurácia: 0.9334415793418884 |
# Cliente #80 | Acurácia: 0.9415501952171326 |
# Cliente #9 | Acurácia: 0.9330306649208069 |
# Cliente #2 | Acurácia: 0.9554794430732727 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.7677000164985657
# ----------------------------------------
#
# Rodada 12/100
# Clientes selecionados: [ 10  20  80  21   4  91  12  83  56 100]
# Cliente #10 | Acurácia: 0.9503546357154846 |
# Cliente #20 | Acurácia: 0.9336437582969666 |
# Cliente #80 | Acurácia: 0.9459974765777588 |
# Cliente #21 | Acurácia: 0.9454705119132996 |
# Cliente #4 | Acurácia: 0.9385812878608704 |
# Cliente #91 | Acurácia: 0.973042368888855 |
# Cliente #12 | Acurácia: 0.9520089030265808 |
# Cliente #83 | Acurácia: 0.9413173794746399 |
# Cliente #56 | Acurácia: 0.9257143139839172 |
# Cliente #100 | Acurácia: 0.9496855139732361 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.7541000247001648
# ----------------------------------------
#
# Rodada 13/100
# Clientes selecionados: [74 61 22 98 31 37 79 70 59 82]
# Cliente #74 | Acurácia: 0.9523809552192688 |
# Cliente #61 | Acurácia: 0.9634888172149658 |
# Cliente #22 | Acurácia: 0.9641226530075073 |
# Cliente #98 | Acurácia: 0.9424572587013245 |
# Cliente #31 | Acurácia: 0.9499536752700806 |
# Cliente #37 | Acurácia: 0.942271888256073 |
# Cliente #79 | Acurácia: 0.9356568455696106 |
# Cliente #70 | Acurácia: 0.9518161416053772 |
# Cliente #59 | Acurácia: 0.9437229633331299 |
# Cliente #82 | Acurácia: 0.9682044982910156 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.791100025177002
# ----------------------------------------
#
# Rodada 14/100
# Clientes selecionados: [26 34 15 66 87  5 80 67 32 25]
# Cliente #26 | Acurácia: 0.9351584911346436 |
# Cliente #34 | Acurácia: 0.9369442462921143 |
# Cliente #15 | Acurácia: 0.9584121108055115 |
# Cliente #66 | Acurácia: 0.9444444179534912 |
# Cliente #87 | Acurácia: 0.9535183906555176 |
# Cliente #5 | Acurácia: 0.9437500238418579 |
# Cliente #80 | Acurácia: 0.9498094320297241 |
# Cliente #67 | Acurácia: 0.9508196711540222 |
# Cliente #32 | Acurácia: 0.9563758373260498 |
# Cliente #25 | Acurácia: 0.9490908980369568 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.7874000072479248
# ----------------------------------------
#
# Rodada 15/100
# Clientes selecionados: [42 31 53 83 89 81 51 88 41 29]
# Cliente #42 | Acurácia: 0.9685216546058655 |
# Cliente #31 | Acurácia: 0.953660786151886 |
# Cliente #53 | Acurácia: 0.9452533721923828 |
# Cliente #83 | Acurácia: 0.940119743347168 |
# Cliente #89 | Acurácia: 0.9279661178588867 |
# Cliente #81 | Acurácia: 0.9525691866874695 |
# Cliente #51 | Acurácia: 0.9470751881599426 |
# Cliente #88 | Acurácia: 0.9545454382896423 |
# Cliente #41 | Acurácia: 0.9410714507102966 |
# Cliente #29 | Acurácia: 0.9344262480735779 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.8183000087738037
# ----------------------------------------
#
# Rodada 16/100
# Clientes selecionados: [10 67 72 28 16 75  1 66 29 65]
# Cliente #10 | Acurácia: 0.9546099305152893 |
# Cliente #67 | Acurácia: 0.9573770761489868 |
# Cliente #72 | Acurácia: 0.9533762335777283 |
# Cliente #28 | Acurácia: 0.9409984946250916 |
# Cliente #16 | Acurácia: 0.9375 |
# Cliente #75 | Acurácia: 0.9408528208732605 |
# Cliente #1 | Acurácia: 0.9680111408233643 |
# Cliente #66 | Acurácia: 0.9454023241996765 |
# Cliente #29 | Acurácia: 0.9253187775611877 |
# Cliente #65 | Acurácia: 0.9480144381523132 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.7889999747276306
# ----------------------------------------
#
# Rodada 17/100
# Clientes selecionados: [67 66 60 58 24 75 56 50 78 19]
# Cliente #67 | Acurácia: 0.9573770761489868 |
# Cliente #66 | Acurácia: 0.9434865713119507 |
# Cliente #60 | Acurácia: 0.9520103931427002 |
# Cliente #58 | Acurácia: 0.9558101296424866 |
# Cliente #24 | Acurácia: 0.9523255825042725 |
# Cliente #75 | Acurácia: 0.9408528208732605 |
# Cliente #56 | Acurácia: 0.9200000166893005 |
# Cliente #50 | Acurácia: 0.9491193890571594 |
# Cliente #78 | Acurácia: 0.9528301954269409 |
# Cliente #19 | Acurácia: 0.9494949579238892 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.8062000274658203
# ...
# Cliente #72 | Acurácia: 0.9630225300788879 |
# Cliente #27 | Acurácia: 0.9783018827438354 |
# Cliente #69 | Acurácia: 0.9654450416564941 |
# Cliente #88 | Acurácia: 0.9659090638160706 |
# Cliente #4 | Acurácia: 0.9506920576095581 |
# Cliente #75 | Acurácia: 0.9628610610961914 |
# Cliente #51 | Acurácia: 0.9679665565490723 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9039000272750854
# ----------------------------------------
#
# Rodada 84/100
# Clientes selecionados: [ 5 73 66 25 74 82 72 54 68 42]
# Cliente #5 | Acurácia: 0.9593750238418579 |
# Cliente #73 | Acurácia: 0.9611178636550903 |
# Cliente #66 | Acurácia: 0.9588122367858887 |
# Cliente #25 | Acurácia: 0.9636363387107849 |
# Cliente #74 | Acurácia: 0.9655765891075134 |
# Cliente #82 | Acurácia: 0.9738154411315918 |
# Cliente #72 | Acurácia: 0.9598070979118347 |
# Cliente #54 | Acurácia: 0.9690656661987305 |
# Cliente #68 | Acurácia: 0.9768115878105164 |
# Cliente #42 | Acurácia: 0.9808881282806396 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.8973000049591064
# ----------------------------------------
#
# Rodada 85/100
# Clientes selecionados: [17 94 75 13 88 86 98  4 35 69]
# Cliente #17 | Acurácia: 0.976544201374054 |
# Cliente #94 | Acurácia: 0.969140350818634 |
# Cliente #75 | Acurácia: 0.9711141586303711 |
# Cliente #13 | Acurácia: 0.9642857313156128 |
# Cliente #88 | Acurácia: 0.9628099203109741 |
# Cliente #86 | Acurácia: 0.9376114010810852 |
# Cliente #98 | Acurácia: 0.9696733951568604 |
# Cliente #4 | Acurácia: 0.9472318291664124 |
# Cliente #35 | Acurácia: 0.9564068913459778 |
# Cliente #69 | Acurácia: 0.9696335196495056 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9035000205039978
# ----------------------------------------
#
# Rodada 86/100
# Clientes selecionados: [83 82 41 64 21 73 96 80 38  5]
# Cliente #83 | Acurácia: 0.9580838084220886 |
# Cliente #82 | Acurácia: 0.9756857752799988 |
# Cliente #41 | Acurácia: 0.9571428298950195 |
# Cliente #64 | Acurácia: 0.9606848359107971 |
# Cliente #21 | Acurácia: 0.9665787220001221 |
# Cliente #73 | Acurácia: 0.9605103135108948 |
# Cliente #96 | Acurácia: 0.9659090638160706 |
# Cliente #80 | Acurácia: 0.968869149684906 |
# Cliente #38 | Acurácia: 0.9596309065818787 |
# Cliente #5 | Acurácia: 0.9632812738418579 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9046000242233276
# ----------------------------------------
#
# Rodada 87/100
# Clientes selecionados: [54  3 18 75 80 93 44 81 62 48]
# Cliente #54 | Acurácia: 0.9627525210380554 |
# Cliente #3 | Acurácia: 0.9634247422218323 |
# Cliente #18 | Acurácia: 0.9648798704147339 |
# Cliente #75 | Acurácia: 0.9697386622428894 |
# Cliente #80 | Acurácia: 0.9720457196235657 |
# Cliente #93 | Acurácia: 0.9582463502883911 |
# Cliente #44 | Acurácia: 0.9635376334190369 |
# Cliente #81 | Acurácia: 0.9696969985961914 |
# Cliente #62 | Acurácia: 0.9708083868026733 |
# Cliente #48 | Acurácia: 0.9705362319946289 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9057000279426575
# ----------------------------------------
#
# Rodada 88/100
# Clientes selecionados: [11 98 68 97 19 28 92 39 13 80]
# Cliente #11 | Acurácia: 0.9635701179504395 |
# Cliente #98 | Acurácia: 0.9696733951568604 |
# Cliente #68 | Acurácia: 0.9710144996643066 |
# Cliente #97 | Acurácia: 0.9745856523513794 |
# Cliente #19 | Acurácia: 0.9696969985961914 |
# Cliente #28 | Acurácia: 0.9591528177261353 |
# Cliente #92 | Acurácia: 0.974957287311554 |
# Cliente #39 | Acurácia: 0.970059871673584 |
# Cliente #13 | Acurácia: 0.9661329984664917 |
# Cliente #80 | Acurácia: 0.9726810455322266 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9046000242233276
# ----------------------------------------
#
# Rodada 89/100
# Clientes selecionados: [85 71 76 28 17 22 81 66 34 93]
# Cliente #85 | Acurácia: 0.966891884803772 |
# Cliente #71 | Acurácia: 0.96878981590271 |
# Cliente #76 | Acurácia: 0.959612250328064 |
# Cliente #28 | Acurácia: 0.9644477963447571 |
# Cliente #17 | Acurácia: 0.976544201374054 |
# Cliente #22 | Acurácia: 0.9797782301902771 |
# Cliente #81 | Acurácia: 0.9683794379234314 |
# Cliente #66 | Acurácia: 0.959770143032074 |
# Cliente #34 | Acurácia: 0.9620048403739929 |
# Cliente #93 | Acurácia: 0.9540709853172302 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9021000266075134
# ----------------------------------------
#
# Rodada 90/100
# Clientes selecionados: [66 14 74 45 78 67 91 89 62 12]
# Cliente #66 | Acurácia: 0.9636015295982361 |
# Cliente #14 | Acurácia: 0.9603960514068604 |
# Cliente #74 | Acurácia: 0.9644291400909424 |
# Cliente #45 | Acurácia: 0.9712679386138916 |
# Cliente #78 | Acurácia: 0.9716981053352356 |
# Cliente #67 | Acurácia: 0.9770491719245911 |
# Cliente #91 | Acurácia: 0.9813863635063171 |
# Cliente #89 | Acurácia: 0.9576271176338196 |
# Cliente #62 | Acurácia: 0.9745509028434753 |
# Cliente #12 | Acurácia: 0.9799107313156128 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9151999950408936
# ----------------------------------------
#
# Rodada 91/100
# Clientes selecionados: [42 44 61 73 63 17  3 66 22 76]
# Cliente #42 | Acurácia: 0.9831365942955017 |
# Cliente #44 | Acurácia: 0.9635376334190369 |
# Cliente #61 | Acurácia: 0.9858012199401855 |
# Cliente #73 | Acurácia: 0.9629404544830322 |
# Cliente #63 | Acurácia: 0.9671280384063721 |
# Cliente #17 | Acurácia: 0.9804534912109375 |
# Cliente #3 | Acurácia: 0.9517871737480164 |
# Cliente #66 | Acurácia: 0.9559386968612671 |
# Cliente #22 | Acurácia: 0.9797782301902771 |
# Cliente #76 | Acurácia: 0.959612250328064 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9056000113487244
# ----------------------------------------
#
# Rodada 92/100
# Clientes selecionados: [31  1 18 67 58 68  3 85  6 93]
# Cliente #31 | Acurácia: 0.9694161415100098 |
# Cliente #1 | Acurácia: 0.9735743999481201 |
# Cliente #18 | Acurácia: 0.9621071815490723 |
# Cliente #67 | Acurácia: 0.9754098653793335 |
# Cliente #58 | Acurácia: 0.9680851101875305 |
# Cliente #68 | Acurácia: 0.9768115878105164 |
# Cliente #3 | Acurácia: 0.9592685103416443 |
# Cliente #85 | Acurácia: 0.9662162065505981 |
# Cliente #6 | Acurácia: 0.9574056267738342 |
# Cliente #93 | Acurácia: 0.9603340029716492 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9101999998092651
# ----------------------------------------
#
# Rodada 93/100
# Clientes selecionados: [88 92 81  1 84 63 61 87 86 99]
# Cliente #88 | Acurácia: 0.9659090638160706 |
# Cliente #92 | Acurácia: 0.9766647815704346 |
# Cliente #81 | Acurácia: 0.9776021242141724 |
# Cliente #1 | Acurácia: 0.9721835851669312 |
# Cliente #84 | Acurácia: 0.954594612121582 |
# Cliente #63 | Acurácia: 0.9688581228256226 |
# Cliente #61 | Acurácia: 0.9817444086074829 |
# Cliente #87 | Acurácia: 0.9677211046218872 |
# Cliente #86 | Acurácia: 0.9465240836143494 |
# Cliente #99 | Acurácia: 0.9634641408920288 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9060999751091003
# ----------------------------------------
#
# Rodada 94/100
# Clientes selecionados: [68 92 56 78 30 40 63 42 54 46]
# Cliente #68 | Acurácia: 0.9787439703941345 |
# Cliente #92 | Acurácia: 0.9778030514717102 |
# Cliente #56 | Acurácia: 0.9276190400123596 |
# Cliente #78 | Acurácia: 0.9716981053352356 |
# Cliente #30 | Acurácia: 0.9747729301452637 |
# Cliente #40 | Acurácia: 0.9577702879905701 |
# Cliente #63 | Acurácia: 0.9679930806159973 |
# Cliente #42 | Acurácia: 0.9820123910903931 |
# Cliente #54 | Acurácia: 0.9678030014038086 |
# Cliente #46 | Acurácia: 0.960026204586029 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.916700005531311
# ----------------------------------------
#
# Rodada 95/100
# Clientes selecionados: [ 64 100  83   8  52  56  97  24   1  10]
# Cliente #64 | Acurácia: 0.9606848359107971 |
# Cliente #100 | Acurácia: 0.9706498980522156 |
# Cliente #83 | Acurácia: 0.9616766571998596 |
# Cliente #8 | Acurácia: 0.9593639373779297 |
# Cliente #52 | Acurácia: 0.9699699878692627 |
# Cliente #56 | Acurácia: 0.939047634601593 |
# Cliente #97 | Acurácia: 0.9756906032562256 |
# Cliente #24 | Acurácia: 0.9593023061752319 |
# Cliente #1 | Acurácia: 0.976356029510498 |
# Cliente #10 | Acurácia: 0.9617021083831787 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9077000021934509
# ----------------------------------------
#
# Rodada 96/100
# Clientes selecionados: [60 64 39 25 96 40 10 58 36  2]
# Cliente #60 | Acurácia: 0.9688715934753418 |
# Cliente #64 | Acurácia: 0.9638554453849792 |
# Cliente #39 | Acurácia: 0.9693945646286011 |
# Cliente #25 | Acurácia: 0.9654545187950134 |
# Cliente #96 | Acurácia: 0.9659090638160706 |
# Cliente #40 | Acurácia: 0.9679054021835327 |
# Cliente #10 | Acurácia: 0.9631205797195435 |
# Cliente #58 | Acurácia: 0.9689034223556519 |
# Cliente #36 | Acurácia: 0.9494097828865051 |
# Cliente #2 | Acurácia: 0.9743150472640991 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9067000150680542
# ----------------------------------------
#
# Rodada 97/100
# Clientes selecionados: [43 14 72  4  5 45 55 19 83 63]
# Cliente #43 | Acurácia: 0.9647201895713806 |
# Cliente #14 | Acurácia: 0.9644728899002075 |
# Cliente #72 | Acurácia: 0.9598070979118347 |
# Cliente #4 | Acurácia: 0.9550173282623291 |
# Cliente #5 | Acurácia: 0.961718738079071 |
# Cliente #45 | Acurácia: 0.9631480574607849 |
# Cliente #55 | Acurácia: 0.9517685174942017 |
# Cliente #19 | Acurácia: 0.9663299918174744 |
# Cliente #83 | Acurácia: 0.9604790210723877 |
# Cliente #63 | Acurácia: 0.9688581228256226 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.8877000212669373
# ----------------------------------------
#
# Rodada 98/100
# Clientes selecionados: [79 58 53 30 93 16 78 46 86 91]
# Cliente #79 | Acurácia: 0.9584450125694275 |
# Cliente #58 | Acurácia: 0.9664484262466431 |
# Cliente #53 | Acurácia: 0.9691321849822998 |
# Cliente #30 | Acurácia: 0.9687184691429138 |
# Cliente #93 | Acurácia: 0.9561586380004883 |
# Cliente #16 | Acurácia: 0.9555920958518982 |
# Cliente #78 | Acurácia: 0.9729560017585754 |
# Cliente #46 | Acurácia: 0.9626474380493164 |
# Cliente #86 | Acurácia: 0.9447415471076965 |
# Cliente #91 | Acurácia: 0.9756097793579102 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.9070000052452087
# ----------------------------------------
#
# Rodada 99/100
# Clientes selecionados: [11 80 72 65 29 55 71 70 67 32]
# Cliente #11 | Acurácia: 0.9726775884628296 |
# Cliente #80 | Acurácia: 0.9682338237762451 |
# Cliente #72 | Acurácia: 0.9598070979118347 |
# Cliente #65 | Acurácia: 0.9667869806289673 |
# Cliente #29 | Acurácia: 0.9690346121788025 |
# Cliente #55 | Acurácia: 0.9496248364448547 |
# Cliente #71 | Acurácia: 0.9656050801277161 |
# Cliente #70 | Acurácia: 0.9659006595611572 |
# Cliente #67 | Acurácia: 0.9704918265342712 |
# Cliente #32 | Acurácia: 0.968120813369751 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.8996999859809875
# ----------------------------------------
#
# Rodada 100/100
# Clientes selecionados: [89 61 70 52 97 29  3 81 83 53]
# Cliente #89 | Acurácia: 0.9639830589294434 |
# Cliente #61 | Acurácia: 0.9797160029411316 |
# Cliente #70 | Acurácia: 0.9666419625282288 |
# Cliente #52 | Acurácia: 0.9684684872627258 |
# Cliente #97 | Acurácia: 0.9779005646705627 |
# Cliente #29 | Acurácia: 0.9599271416664124 |
# Cliente #3 | Acurácia: 0.9634247422218323 |
# Cliente #81 | Acurácia: 0.9710144996643066 |
# Cliente #83 | Acurácia: 0.9580838084220886 |
# Cliente #53 | Acurácia: 0.9726266860961914 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.8934000134468079
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [16.04295539855957, 6.281219959259033, 2.499999523162842, 1.5774630308151245, 1.4632251262664795, 1.2763727903366089, 1.054266333580017, 0.9673665761947632, 0.9678083658218384, 0.8208444714546204, 0.8024863004684448, 0.8153542280197144, 0.7645950317382812, 0.7973348498344421, 0.7095118761062622, 0.7718083262443542, 0.7355963587760925, 0.7557840347290039, 0.6567704677581787, 0.661138653755188, 0.6864632964134216, 0.6974133849143982, 0.7314622402191162, 0.7262494564056396, 0.613598644733429, 0.6193439364433289, 0.5774928331375122, 0.5804807543754578, 0.5945025682449341, 0.614775538444519, 0.6208049654960632, 0.550929844379425, 0.5657762289047241, 0.5188953280448914, 0.5421535968780518, 0.6039662957191467, 0.5451433062553406, 0.5215986967086792, 0.5381171107292175, 0.5058320760726929, 0.541589617729187, 0.5366910099983215, 0.5621347427368164, 0.5667892098426819, 0.5059576630592346, 0.5177818536758423, 0.5440579652786255, 0.49811097979545593, 0.47150400280952454, 0.5158213973045349, 0.5696575045585632, 0.5032947063446045, 0.5194588303565979, 0.48815640807151794, 0.5139959454536438, 0.472999632358551, 0.46526601910591125, 0.48536795377731323, 0.49276310205459595, 0.5121020078659058, 0.49836209416389465, 0.4960050880908966, 0.5016756653785706, 0.4968728721141815, 0.4797836244106293, 0.4660126268863678, 0.4671366512775421, 0.4981445074081421, 0.48131710290908813, 0.47458139061927795, 0.45632633566856384, 0.5055255889892578, 0.4580649435520172, 0.4442608654499054, 0.4764980971813202, 0.4159146547317505, 0.45810896158218384, 0.4944675862789154, 0.44320496916770935, 0.5309064388275146, 0.4588448405265808, 0.4586310386657715, 0.44507303833961487, 0.48664042353630066, 0.45574983954429626, 0.4506783187389374, 0.4244444668292999, 0.4298504590988159, 0.4499356150627136, 0.401632696390152, 0.4606033265590668, 0.4320819675922394, 0.42599916458129883, 0.4070340692996979, 0.4205194115638733, 0.40829139947891235, 0.5085800886154175, 0.42216530442237854, 0.45526450872421265, 0.48952770233154297]
# Centralized accuracy: [0.5656999945640564, 0.6812999844551086, 0.6359999775886536, 0.5823000073432922, 0.5533999800682068, 0.6049000024795532, 0.6825000047683716, 0.7350999712944031, 0.7027999758720398, 0.777400016784668, 0.7677000164985657, 0.7541000247001648, 0.791100025177002, 0.7874000072479248, 0.8183000087738037, 0.7889999747276306, 0.8062000274658203, 0.7712000012397766, 0.8292999863624573, 0.8341000080108643, 0.8325999975204468, 0.7996000051498413, 0.8027999997138977, 0.7968999743461609, 0.8452000021934509, 0.8343999981880188, 0.8442000150680542, 0.8561000227928162, 0.8531000018119812, 0.84579998254776, 0.8291000127792358, 0.8532999753952026, 0.8521999716758728, 0.8669000267982483, 0.8575999736785889, 0.8440999984741211, 0.8526999950408936, 0.8726000189781189, 0.8733000159263611, 0.8883000016212463, 0.8766000270843506, 0.8766000270843506, 0.8694999814033508, 0.8766999840736389, 0.8745999932289124, 0.8684999942779541, 0.8763999938964844, 0.880299985408783, 0.891700029373169, 0.8729000091552734, 0.8657000064849854, 0.8787999749183655, 0.8833000063896179, 0.8851000070571899, 0.8859999775886536, 0.892799973487854, 0.8949999809265137, 0.8894000053405762, 0.8956999778747559, 0.8881999850273132, 0.8866999745368958, 0.8992999792098999, 0.8855000138282776, 0.8851000070571899, 0.8884999752044678, 0.8942999839782715, 0.8971999883651733, 0.8913999795913696, 0.8876000046730042, 0.8942999839782715, 0.8953999876976013, 0.8855999708175659, 0.9018999934196472, 0.9041000008583069, 0.9036999940872192, 0.906000018119812, 0.8996999859809875, 0.8848999738693237, 0.9014999866485596, 0.8881000280380249, 0.8888000249862671, 0.8985999822616577, 0.9039000272750854, 0.8973000049591064, 0.9035000205039978, 0.9046000242233276, 0.9057000279426575, 0.9046000242233276, 0.9021000266075134, 0.9151999950408936, 0.9056000113487244, 0.9101999998092651, 0.9060999751091003, 0.916700005531311, 0.9077000021934509, 0.9067000150680542, 0.8877000212669373, 0.9070000052452087, 0.8996999859809875, 0.8934000134468079]

# %%
for i in range(NUMERO_DE_EXECUCOES):

# %%
plt.title('Evolução da Acurácia')
plt.plot(evaluate_list["centralized"]["accuracy"])
plt.ylabel('Acurácia', fontsize=13)
plt.xlabel('Rodadas de Treinamento', fontsize=13)
# plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.title('Evolução da Função de Perda')
plt.plot(evaluate_list["centralized"]["loss"], color='red')
plt.ylabel('Função de Perda', fontsize=13)
plt.xlabel('Rodadas de Treinamento', fontsize=13)
# plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.title('Transmissões da Rodada')
plt.plot(transmissions_per_round, color='green',)
plt.ylabel('Quantidade de Transmissões', fontsize=13)
plt.xlabel('Rodadas de Treinamento', fontsize=13)
# plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.title('Transmissões Acumuladas por Rodada')
plt.plot([sum(transmissions_per_round[0:i]) for i in range(len(transmissions_per_round))], color='orange')
plt.ylabel('Quantidade de Transmissões Acumuladas', fontsize=13)
plt.xlabel('Rodadas de Treinamento', fontsize=13)
# plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
sum(transmissions_per_round)
# Out:
# 1000

# %%
evaluate_list["centralized"]["accuracy"][-1]
# Out:
# 0.8934000134468079
