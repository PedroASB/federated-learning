# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %% [markdown]
# ### Modelo

# %%
class ModelMLP:
    @staticmethod
    def create_model():
        model = tf.keras.models.Sequential(
            [
                tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784,)),
                tf.keras.layers.Dense(10, activation="softmax")
            ]
        )
        model.compile(
            optimizer=tf.keras.optimizers.Adam(),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=['accuracy']
        )
        return model

# %%
# Definição dos parâmetros
NUMBER_OF_ROUNDS = 100
TOTAL_CLIENTS = 100
CLIENTS_PER_ROUND = 10
EPSILON = 200.0

# %% [markdown]
# ### Cliente

# %%
class Client():
    def __init__(self, cid):
        self.cid = int(cid)
        self.model = ModelMLP.create_model()
        self.old_weights = None
        (self.x_train, self.y_train), (self.x_test, self.y_test) = self.load_data()


    def load_data(self):
        path = "./dataset-mnist/non-iid-0.9-100-rotation-45"

        train = pd.read_pickle(f"{path}/{self.cid+1}_train.pickle")
        test = pd.read_pickle(f"{path}/{self.cid+1}_test.pickle")

        x_train = train.drop(['label'], axis=1)
        y_train = train['label']

        x_test = test.drop(['label'], axis=1)
        y_test = test['label']

        return (x_train, y_train), (x_test, y_test)


    def fit(self, parameters, config=None):
        self.model.set_weights(parameters)
        history = self.model.fit(self.x_train, self.y_train, epochs=5, batch_size=128,
                                 validation_data=(self.x_test, self.y_test), verbose=False)
        self.current_weights = self.model.get_weights()
        sample_size = len(self.x_train)
        print(f"Acurácia: {history.history['val_accuracy'][-1]} | ", end='')
        if self.old_weights is not None:
            weight_diff = np.sum([np.sum(np.abs(w1 - w2)) for w1, w2 in zip(self.current_weights, self.old_weights)])
            print(f"Diferença dos pesos: {weight_diff}")
            self.old_weights = self.current_weights
            if weight_diff < EPSILON:
                print("weight_diff < EPSILON. O modelo não será transmitido.")
                return None
            else:
                return self.current_weights, sample_size, {"val_accuracy": history.history['val_accuracy'][-1],
                                                               "val_loss": history.history['val_loss'][-1]}
        else:
            print()
            self.old_weights = self.current_weights
            return self.current_weights, sample_size, {"val_accuracy": history.history['val_accuracy'][-1],
                                                               "val_loss": history.history['val_loss'][-1]}


    def evaluate(self, parameters):
        self.model.set_weights(parameters)
        return self.model.evaluate(self.x_test, self.y_test, verbose=False)

# %% [markdown]
# ### Servidor

# %%
class Server():
    def __init__(self, n_rounds, total_number_clients, min_fit_clients):
        self.n_rounds = n_rounds
        self.total_number_clients = total_number_clients
        self.min_fit_clients = min_fit_clients

        self.server_round = 0
        self.selected_clients = []
        self.model = ModelMLP.create_model()
        self.w_global = self.model.get_weights()

        self.clients_model_list = []
        # Vamos guardar todos os modelos (pesos) anteriores, mas não é necessário
        self.clients_previous_models_list = [ [] for _ in range(total_number_clients) ]
        self.create_models()
        (self.x_train, self.y_train), (self.x_test, self.y_test) = self.load_data()


    def load_data(self):
        path = "./dataset-mnist/mnist"

        train = pd.read_pickle(f"{path}/train.pickle")
        test = pd.read_pickle(f"{path}/test.pickle")

        x_train = train.drop(['label'], axis=1)
        y_train = train['label']

        # test = pd.concat([test, train])
        x_test = test.drop(['label'], axis=1)
        y_test = test['label']

        return (x_train, y_train), (x_test, y_test)


    def create_models(self):
        for i in range(self.total_number_clients):
            self.clients_model_list.append(Client(i))


    def aggregate_fit(self, weight_list, sample_sizes):
        self.w_global = []
        for weights in zip(*weight_list):
            weighted_sum = 0
            total_samples = sum(sample_sizes)
            for i in range(len(weights)):
                weighted_sum += weights[i] * sample_sizes[i]
            self.w_global.append(weighted_sum / total_samples)


    def configure_fit(self):
        self.selected_clients = np.random.permutation(list(range(self.total_number_clients)))[:self.min_fit_clients]
        print(f"Clientes selecionados: \033[34;1m{np.array(self.selected_clients) + 1}\033[37;0m")

    
    def get_client_previous_model(self, client_id):
        return self.clients_previous_models_list[client_id][-1]


    def save_client_previous_model(self, client_id, model):
        self.clients_previous_models_list[client_id].append(model)


    def fit(self):
        weight_list, sample_sizes_list, info_list, transmissions_count = [], [], [], 0
        for i, pos in enumerate(self.selected_clients):
            print(f"Cliente #{pos+1} | ", end='')

            # Se o cliente decidir não enviar o modelo, ele retorna um None
            new_model = self.clients_model_list[pos].fit(parameters=self.w_global)

            weights, size, info = new_model if new_model is not None else self.get_client_previous_model(pos)
            weight_list.append(weights)
            sample_sizes_list.append(size)
            info_list.append(info)

            # Se o cliente enviou um novo modelo, salve-o e incremente a contagem de transmissões
            if new_model is not None:
                self.save_client_previous_model(pos, (weights, size, info_list))
                transmissions_count += 1

        return weight_list, sample_sizes_list, {"acc_loss_local":[(pos+1, info_list[i]) for i, pos in enumerate(self.selected_clients)]}, transmissions_count


    def distributed_evaluation(self):
        loss_list, accuracy_list = [], []
        for i in range(self.total_number_clients):
            loss, accuracy = self.clients_model_list[i].evaluate(parameters=self.w_global)
            # print(f"Evaluate - CID: {i+1} - accuracy: {accuracy}")
            loss_list.append(loss)
            accuracy_list.append(accuracy)
        return sum(loss_list) / len(loss_list), sum(accuracy_list) / len(accuracy_list), {"accuracy_list": [(i+1, accuracy) for i, accuracy in enumerate(accuracy_list)]}


    def centralized_evaluation(self):
        self.model.set_weights(self.w_global)
        return self.model.evaluate(self.x_test, self.y_test, verbose=False)

# %% [markdown]
# ### Exemplo de Execução

# %%
print('\n' + '='*40)
print("{:^54}".format('\033[;1m' + 'CARREGAMENTO DE DADOS' + '\033[37;0m'))
print("{:^40}".format(f'Número total de clientes: {TOTAL_CLIENTS}' + '\n'))

s = Server(n_rounds=NUMBER_OF_ROUNDS,
           total_number_clients=TOTAL_CLIENTS,
           min_fit_clients=CLIENTS_PER_ROUND)

print('\n' + '='*40)
print("{:^54}".format('\033[;1m' + 'INICIANDO' + '\033[37;0m'))
print("{:^40}".format(f'Clientes por rodada: {CLIENTS_PER_ROUND} ' + '\n'))

evaluate_list = {"distributed": {"loss":[], "accuracy":[]}, "centralized": {"loss":[], "accuracy":[]}}

transmissions_per_round = []

# Rodadas de comunicação
for s.server_round in range(s.n_rounds):
    print('\033[;1m' + f'Rodada {s.server_round+1}/{s.n_rounds}' + '\033[37;0m')

    # Seleciona os clientes que participarão da próxima rodada de comunicação
    s.configure_fit()

    # Treinamento local do dispositivo
    weight_list, sample_sizes, info, transmissions_count = s.fit()

    # Salva a quantidade de transmissões ocorridas nesta rodada
    transmissions_per_round.append(transmissions_count)

    # Agregação
    s.aggregate_fit(weight_list, sample_sizes)

    # Avaliação centralizada
    print('\033[3;1m' + '-'*40 + '\033[37;0m')
    # print(f"Avaliação centralizada")
    evaluate_loss, evaluate_accuracy = s.centralized_evaluation()
    print(f"Transmissões nesta rodada: {transmissions_count}")
    print(f"Acurácia: {evaluate_accuracy}")
    evaluate_list["centralized"]["loss"].append(evaluate_loss)
    evaluate_list["centralized"]["accuracy"].append(evaluate_accuracy)
    print('\033[3;1m' + '-'*40 + '\033[37;0m' + '\n')

print('\n\n' + '='*40)
print("{:^54}".format('\033[;1m' + 'RESULTADOS FINAIS' + '\033[37;0m'))
print(f"\nCentralized loss: ", end='')
print(evaluate_list["centralized"]["loss"])
print(f"Centralized accuracy: ", end='')
print(evaluate_list["centralized"]["accuracy"])
# Out:
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\Pedro\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ========================================
#                 INICIANDO
#        Clientes por rodada: 10
#
# Rodada 1/100
# Clientes selecionados: [41 57 45 42 34 64 33  4 63 46]
# Cliente #41 | Acurácia: 0.8999999761581421 |
# Cliente #57 | Acurácia: 0.9197080135345459 |
# Cliente #45 | Acurácia: 0.9188007712364197 |
# Cliente #42 | Acurácia: 0.9437886476516724 |
# Cliente #34 | Acurácia: 0.9054163098335266 |
# Cliente #64 | Acurácia: 0.9156626462936401 |
# Cliente #33 | Acurácia: 0.9005658626556396 |
# Cliente #4 | Acurácia: 0.9031141996383667 |
# Cliente #63 | Acurácia: 0.9117646813392639 |
# Cliente #46 | Acurácia: 0.9141546487808228 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.6402999758720398
# ----------------------------------------
#
# Rodada 2/100
# Clientes selecionados: [82 19 92 86 83 18 89 74 59 51]
# Cliente #82 | Acurácia: 0.9463840126991272 |
# Cliente #19 | Acurácia: 0.9318181872367859 |
# Cliente #92 | Acurácia: 0.9538986682891846 |
# Cliente #86 | Acurácia: 0.903743326663971 |
# Cliente #83 | Acurácia: 0.9341317415237427 |
# Cliente #18 | Acurácia: 0.9205175638198853 |
# Cliente #89 | Acurácia: 0.883474588394165 |
# Cliente #74 | Acurácia: 0.93459552526474 |
# Cliente #59 | Acurácia: 0.9134199023246765 |
# Cliente #51 | Acurácia: 0.9303621053695679 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.6934999823570251
# ----------------------------------------
#
# Rodada 3/100
# Clientes selecionados: [57  9 89 90 31 56 22 14 67 44]
# Cliente #57 | Acurácia: 0.9311783313751221 | Diferença dos pesos: 524.8629760742188
# Cliente #9 | Acurácia: 0.9080590009689331 |
# Cliente #89 | Acurácia: 0.8961864113807678 | Diferença dos pesos: 340.4977111816406
# Cliente #90 | Acurácia: 0.9164696335792542 |
# Cliente #31 | Acurácia: 0.94439297914505 |
# Cliente #56 | Acurácia: 0.8933333158493042 |
# Cliente #22 | Acurácia: 0.9478147625923157 |
# Cliente #14 | Acurácia: 0.9207921028137207 |
# Cliente #67 | Acurácia: 0.9491803050041199 |
# Cliente #44 | Acurácia: 0.9200931191444397 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.6559000015258789
# ----------------------------------------
#
# Rodada 4/100
# Clientes selecionados: [  2  94  89  53  98  54   3 100  55  28]
# Cliente #2 | Acurácia: 0.9469178318977356 |
# Cliente #94 | Acurácia: 0.9353416562080383 |
# Cliente #89 | Acurácia: 0.8771186470985413 | Diferença dos pesos: 287.1357421875
# Cliente #53 | Acurácia: 0.9167152047157288 |
# Cliente #98 | Acurácia: 0.9315707683563232 |
# Cliente #54 | Acurácia: 0.9223484992980957 |
# Cliente #3 | Acurácia: 0.9143807291984558 |
# Cliente #100 | Acurácia: 0.9259259104728699 |
# Cliente #55 | Acurácia: 0.9217577576637268 |
# Cliente #28 | Acurácia: 0.9296520352363586 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.5950000286102295
# ----------------------------------------
#
# Rodada 5/100
# Clientes selecionados: [81 78 98 69 38 34 18 21  9 58]
# Cliente #81 | Acurácia: 0.9512516260147095 |
# Cliente #78 | Acurácia: 0.9402515888214111 |
# Cliente #98 | Acurácia: 0.9276827573776245 | Diferença dos pesos: 397.07293701171875
# Cliente #69 | Acurácia: 0.926701545715332 |
# Cliente #38 | Acurácia: 0.931949257850647 |
# Cliente #34 | Acurácia: 0.9151172041893005 | Diferença dos pesos: 637.822998046875
# Cliente #18 | Acurácia: 0.9362292289733887 | Diferença dos pesos: 510.2930908203125
# Cliente #21 | Acurácia: 0.9199647903442383 |
# Cliente #9 | Acurácia: 0.9160045385360718 | Diferença dos pesos: 426.8880920410156
# Cliente #58 | Acurácia: 0.9394435286521912 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.5841000080108643
# ----------------------------------------
#
# Rodada 6/100
# Clientes selecionados: [80 34 11 50 70 90 64 68 69 49]
# Cliente #80 | Acurácia: 0.9383735656738281 |
# Cliente #34 | Acurácia: 0.9240096807479858 | Diferença dos pesos: 150.95819091796875
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #11 | Acurácia: 0.9216758012771606 |
# Cliente #50 | Acurácia: 0.931506872177124 |
# Cliente #70 | Acurácia: 0.9288361668586731 |
# Cliente #90 | Acurácia: 0.921197772026062 | Diferença dos pesos: 465.93524169921875
# Cliente #64 | Acurácia: 0.9194673299789429 | Diferença dos pesos: 698.5003051757812
# Cliente #68 | Acurácia: 0.9410628080368042 |
# Cliente #69 | Acurácia: 0.9298429489135742 | Diferença dos pesos: 319.58203125
# Cliente #49 | Acurácia: 0.9149560332298279 |
# ----------------------------------------
# Transmissões nesta rodada: 9
# Acurácia: 0.6241000294685364
# ----------------------------------------
#
# Rodada 7/100
# Clientes selecionados: [30  2 10 11 85 39 75  8 87 95]
# Cliente #30 | Acurácia: 0.9374369382858276 |
# Cliente #2 | Acurácia: 0.9452054500579834 | Diferença dos pesos: 354.5578918457031
# Cliente #10 | Acurácia: 0.9347517490386963 |
# Cliente #11 | Acurácia: 0.9198542833328247 | Diferença dos pesos: 204.5024871826172
# Cliente #85 | Acurácia: 0.9317567348480225 |
# Cliente #39 | Acurácia: 0.9414504170417786 |
# Cliente #75 | Acurácia: 0.9229711294174194 |
# Cliente #8 | Acurácia: 0.9293286204338074 |
# Cliente #87 | Acurácia: 0.9360877871513367 |
# Cliente #95 | Acurácia: 0.936246395111084 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.6639000177383423
# ----------------------------------------
#
# Rodada 8/100
# Clientes selecionados: [79 38 96 67 76  2 14 21 80 31]
# Cliente #79 | Acurácia: 0.9343163371086121 |
# Cliente #38 | Acurácia: 0.931949257850647 | Diferença dos pesos: 377.8968811035156
# Cliente #96 | Acurácia: 0.9285714030265808 |
# Cliente #67 | Acurácia: 0.9524590373039246 | Diferença dos pesos: 490.5855407714844
# Cliente #76 | Acurácia: 0.9127625226974487 |
# Cliente #2 | Acurácia: 0.9589040875434875 | Diferença dos pesos: 198.61781311035156
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #14 | Acurácia: 0.9353523850440979 | Diferença dos pesos: 557.3483276367188
# Cliente #21 | Acurácia: 0.943711519241333 | Diferença dos pesos: 383.84161376953125
# Cliente #80 | Acurácia: 0.9428208470344543 | Diferença dos pesos: 396.17474365234375
# Cliente #31 | Acurácia: 0.9481000900268555 | Diferença dos pesos: 524.8148803710938
# ----------------------------------------
# Transmissões nesta rodada: 9
# Acurácia: 0.6952000260353088
# ----------------------------------------
#
# Rodada 9/100
# Clientes selecionados: [17 15 64 36  9 57  3 39 13 20]
# Cliente #17 | Acurácia: 0.9515246152877808 |
# Cliente #15 | Acurácia: 0.9338374137878418 |
# Cliente #64 | Acurácia: 0.922637939453125 | Diferença dos pesos: 257.2399597167969
# Cliente #36 | Acurácia: 0.9156829714775085 |
# Cliente #9 | Acurácia: 0.9330306649208069 | Diferença dos pesos: 369.792236328125
# Cliente #57 | Acurácia: 0.9436913728713989 | Diferença dos pesos: 512.080322265625
# Cliente #3 | Acurácia: 0.9110556840896606 | Diferença dos pesos: 501.6117858886719
# Cliente #39 | Acurácia: 0.9474384784698486 | Diferença dos pesos: 377.2188415527344
# Cliente #13 | Acurácia: 0.9451970458030701 |
# Cliente #20 | Acurácia: 0.9330617189407349 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.6970000267028809
# ----------------------------------------
#
# Rodada 10/100
# Clientes selecionados: [94 48 47 52  9 69 79 43 89 38]
# Cliente #94 | Acurácia: 0.9470977187156677 | Diferença dos pesos: 566.0603637695312
# Cliente #48 | Acurácia: 0.9351797103881836 |
# Cliente #47 | Acurácia: 0.9513742327690125 |
# Cliente #52 | Acurácia: 0.9459459185600281 |
# Cliente #9 | Acurácia: 0.9307605028152466 | Diferença dos pesos: 169.85348510742188
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #69 | Acurácia: 0.9350785613059998 | Diferença dos pesos: 400.319580078125
# Cliente #79 | Acurácia: 0.9343163371086121 | Diferença dos pesos: 271.3559265136719
# Cliente #43 | Acurácia: 0.9324817657470703 |
# Cliente #89 | Acurácia: 0.9110169410705566 | Diferença dos pesos: 460.2132263183594
# Cliente #38 | Acurácia: 0.9342560768127441 | Diferença dos pesos: 300.91265869140625
# ----------------------------------------
# Transmissões nesta rodada: 9
# Acurácia: 0.7325000166893005
# ----------------------------------------
#
# Rodada 11/100
# Clientes selecionados: [23  2 38 96 99 63 12 75 35 16]
# Cliente #23 | Acurácia: 0.9022403359413147 |
# Cliente #2 | Acurácia: 0.9554794430732727 | Diferença dos pesos: 272.3005065917969
# Cliente #38 | Acurácia: 0.9365628361701965 | Diferença dos pesos: 240.80191040039062
# Cliente #96 | Acurácia: 0.9285714030265808 | Diferença dos pesos: 386.1712341308594
# Cliente #99 | Acurácia: 0.9282814860343933 |
# Cliente #63 | Acurácia: 0.9290657639503479 | Diferença dos pesos: 875.77783203125
# Cliente #12 | Acurácia: 0.9553571343421936 |
# Cliente #75 | Acurácia: 0.9270976781845093 | Diferença dos pesos: 365.9323425292969
# Cliente #35 | Acurácia: 0.927344799041748 |
# Cliente #16 | Acurácia: 0.9276315569877625 |
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.742900013923645
# ----------------------------------------
#
# Rodada 12/100
# Clientes selecionados: [86 37  7  1 55 53 33 90 17 41]
# Cliente #86 | Acurácia: 0.9304812550544739 | Diferença dos pesos: 733.7318115234375
# Cliente #37 | Acurácia: 0.9441340565681458 |
# Cliente #7 | Acurácia: 0.9576783776283264 |
# Cliente #1 | Acurácia: 0.9582753777503967 |
# Cliente #55 | Acurácia: 0.9303322434425354 | Diferença dos pesos: 585.0729370117188
# Cliente #53 | Acurácia: 0.9388468265533447 | Diferença dos pesos: 592.149169921875
# Cliente #33 | Acurácia: 0.9264349341392517 | Diferença dos pesos: 897.1412963867188
# Cliente #90 | Acurácia: 0.9369582533836365 | Diferença dos pesos: 420.4281005859375
# Cliente #17 | Acurácia: 0.9554339051246643 | Diferença dos pesos: 335.3184814453125
# Cliente #41 | Acurácia: 0.9321428537368774 | Diferença dos pesos: 903.1747436523438
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.7773000001907349
# ----------------------------------------
#
# Rodada 13/100
# Clientes selecionados: [75  7 10 29  8 55 80 68 97 49]
# Cliente #75 | Acurácia: 0.9367262721061707 | Diferença dos pesos: 259.0852966308594
# Cliente #7 | Acurácia: 0.9582829475402832 | Diferença dos pesos: 303.6123352050781
# Cliente #10 | Acurácia: 0.9262411594390869 | Diferença dos pesos: 408.13262939453125
# Cliente #29 | Acurácia: 0.9326047301292419 |
# Cliente #8 | Acurácia: 0.9381625652313232 | Diferença dos pesos: 406.47186279296875
# Cliente #55 | Acurácia: 0.9421221613883972 | Diferença dos pesos: 213.7362518310547
# Cliente #80 | Acurácia: 0.944726824760437 | Diferença dos pesos: 448.2483215332031
# Cliente #68 | Acurácia: 0.9545893669128418 | Diferença dos pesos: 484.7283935546875
# Cliente #97 | Acurácia: 0.9569060802459717 |
# Cliente #49 | Acurácia: 0.9398826956748962 | Diferença dos pesos: 447.5534362792969
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.7699000239372253
# ----------------------------------------
#
# Rodada 14/100
# Clientes selecionados: [ 57  98  53 100  18   9  54  21   6  96]
# Cliente #57 | Acurácia: 0.9541188478469849 | Diferença dos pesos: 276.72503662109375
# Cliente #98 | Acurácia: 0.9502332806587219 | Diferença dos pesos: 578.5932006835938
# Cliente #53 | Acurácia: 0.9411764740943909 | Diferença dos pesos: 294.4756164550781
# Cliente #100 | Acurácia: 0.945492684841156 | Diferença dos pesos: 663.9932250976562
# Cliente #18 | Acurácia: 0.9445471167564392 | Diferença dos pesos: 506.456787109375
# ...
# ----------------------------------------
# Transmissões nesta rodada: 7
# Acurácia: 0.86080002784729
# ----------------------------------------
#
# Rodada 91/100
# Clientes selecionados: [ 19  53  70  27  85  23  72  74 100  20]
# Cliente #19 | Acurácia: 0.9671717286109924 | Diferença dos pesos: 180.2766876220703
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #53 | Acurácia: 0.9534071087837219 | Diferença dos pesos: 327.10272216796875
# Cliente #70 | Acurácia: 0.9510748982429504 | Diferença dos pesos: 246.7574920654297
# Cliente #27 | Acurácia: 0.9754716753959656 | Diferença dos pesos: 217.2112274169922
# Cliente #85 | Acurácia: 0.9587838053703308 | Diferença dos pesos: 287.8237609863281
# Cliente #23 | Acurácia: 0.914460301399231 | Diferença dos pesos: 203.9614715576172
# Cliente #72 | Acurácia: 0.9598070979118347 | Diferença dos pesos: 193.2650146484375
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #74 | Acurácia: 0.9563969969749451 | Diferença dos pesos: 235.36207580566406
# Cliente #100 | Acurácia: 0.9552760124206543 | Diferença dos pesos: 218.04641723632812
# Cliente #20 | Acurácia: 0.9499418139457703 | Diferença dos pesos: 259.86419677734375
# ----------------------------------------
# Transmissões nesta rodada: 8
# Acurácia: 0.8687999844551086
# ----------------------------------------
#
# Rodada 92/100
# Clientes selecionados: [26 61 14 73 40 87  6 34 70  7]
# Cliente #26 | Acurácia: 0.940922200679779 | Diferença dos pesos: 267.0014343261719
# Cliente #61 | Acurácia: 0.9756592512130737 | Diferença dos pesos: 223.4609375
# Cliente #14 | Acurácia: 0.9516598582267761 | Diferença dos pesos: 270.4073486328125
# Cliente #73 | Acurácia: 0.9641555547714233 | Diferença dos pesos: 296.0952453613281
# Cliente #40 | Acurácia: 0.9611486196517944 | Diferença dos pesos: 192.2900848388672
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #87 | Acurácia: 0.9632020592689514 | Diferença dos pesos: 312.44775390625
# Cliente #6 | Acurácia: 0.938044548034668 | Diferença dos pesos: 333.50439453125
# Cliente #34 | Acurácia: 0.9514955282211304 | Diferença dos pesos: 177.2019805908203
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #70 | Acurácia: 0.9577465057373047 | Diferença dos pesos: 183.39453125
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #7 | Acurácia: 0.9727932214736938 | Diferença dos pesos: 348.5699768066406
# ----------------------------------------
# Transmissões nesta rodada: 7
# Acurácia: 0.8673999905586243
# ----------------------------------------
#
# Rodada 93/100
# Clientes selecionados: [73 49 98 87 33 60 24 27 23 93]
# Cliente #73 | Acurácia: 0.9611178636550903 | Diferença dos pesos: 219.47259521484375
# Cliente #49 | Acurácia: 0.9589442610740662 | Diferença dos pesos: 217.88226318359375
# Cliente #98 | Acurácia: 0.9618973731994629 | Diferença dos pesos: 281.1281433105469
# Cliente #87 | Acurácia: 0.9638476371765137 | Diferença dos pesos: 237.0888671875
# Cliente #33 | Acurácia: 0.9531123638153076 | Diferença dos pesos: 184.34719848632812
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #60 | Acurácia: 0.9546043872833252 | Diferença dos pesos: 223.40623474121094
# Cliente #24 | Acurácia: 0.949999988079071 | Diferença dos pesos: 240.71124267578125
# Cliente #27 | Acurácia: 0.9764150977134705 | Diferença dos pesos: 201.85968017578125
# Cliente #23 | Acurácia: 0.9348269104957581 | Diferença dos pesos: 176.61761474609375
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #93 | Acurácia: 0.9478079080581665 | Diferença dos pesos: 209.44683837890625
# ----------------------------------------
# Transmissões nesta rodada: 8
# Acurácia: 0.8759999871253967
# ----------------------------------------
#
# Rodada 94/100
# Clientes selecionados: [48 86 65  6  5 21 10 25 62 79]
# Cliente #48 | Acurácia: 0.9622864127159119 | Diferença dos pesos: 326.6636962890625
# Cliente #86 | Acurácia: 0.9376114010810852 | Diferença dos pesos: 188.61880493164062
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #65 | Acurácia: 0.9638988971710205 | Diferença dos pesos: 307.2171936035156
# Cliente #6 | Acurácia: 0.938044548034668 | Diferença dos pesos: 277.7740173339844
# Cliente #5 | Acurácia: 0.9585937261581421 | Diferença dos pesos: 285.504638671875
# Cliente #21 | Acurácia: 0.9656991958618164 | Diferença dos pesos: 226.8870849609375
# Cliente #10 | Acurácia: 0.958865225315094 | Diferença dos pesos: 224.05201721191406
# Cliente #25 | Acurácia: 0.9527272582054138 | Diferença dos pesos: 211.09918212890625
# Cliente #62 | Acurácia: 0.976047933101654 | Diferença dos pesos: 264.3291015625
# Cliente #79 | Acurácia: 0.9490616917610168 | Diferença dos pesos: 253.53338623046875
# ----------------------------------------
# Transmissões nesta rodada: 9
# Acurácia: 0.8737999796867371
# ----------------------------------------
#
# Rodada 95/100
# Clientes selecionados: [22 87 30 78 54 14  2 76 69 99]
# Cliente #22 | Acurácia: 0.9719504117965698 | Diferença dos pesos: 246.63873291015625
# Cliente #87 | Acurácia: 0.9580374360084534 | Diferença dos pesos: 235.05824279785156
# Cliente #30 | Acurácia: 0.9576185941696167 | Diferença dos pesos: 229.05006408691406
# Cliente #78 | Acurácia: 0.9628930687904358 | Diferença dos pesos: 349.52520751953125
# Cliente #54 | Acurácia: 0.9577020406723022 | Diferença dos pesos: 303.5207214355469
# Cliente #14 | Acurácia: 0.9522422552108765 | Diferença dos pesos: 240.16680908203125
# Cliente #2 | Acurácia: 0.9691780805587769 | Diferença dos pesos: 223.8442840576172
# Cliente #76 | Acurácia: 0.9369951486587524 | Diferença dos pesos: 279.13104248046875
# Cliente #69 | Acurácia: 0.9581151604652405 | Diferença dos pesos: 258.1790771484375
# Cliente #99 | Acurácia: 0.9431664347648621 | Diferença dos pesos: 247.10055541992188
# ----------------------------------------
# Transmissões nesta rodada: 10
# Acurácia: 0.8693000078201294
# ----------------------------------------
#
# Rodada 96/100
# Clientes selecionados: [95 40 71  3 18  6 81 69 91 62]
# Cliente #95 | Acurácia: 0.9598853588104248 | Diferença dos pesos: 322.5544738769531
# Cliente #40 | Acurácia: 0.9459459185600281 | Diferença dos pesos: 195.0242462158203
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #71 | Acurácia: 0.9707006216049194 | Diferença dos pesos: 319.5535888671875
# Cliente #3 | Acurácia: 0.9542809724807739 | Diferença dos pesos: 308.29547119140625
# Cliente #18 | Acurácia: 0.9574861526489258 | Diferença dos pesos: 259.10479736328125
# Cliente #6 | Acurácia: 0.9448208808898926 | Diferença dos pesos: 257.0697937011719
# Cliente #81 | Acurácia: 0.9749670624732971 | Diferença dos pesos: 246.7386474609375
# Cliente #69 | Acurácia: 0.9581151604652405 | Diferença dos pesos: 152.7681427001953
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #91 | Acurácia: 0.9743260741233826 | Diferença dos pesos: 382.6244812011719
# Cliente #62 | Acurácia: 0.9730538725852966 | Diferença dos pesos: 227.1784210205078
# ----------------------------------------
# Transmissões nesta rodada: 8
# Acurácia: 0.8730999827384949
# ----------------------------------------
#
# Rodada 97/100
# Clientes selecionados: [28 74 30 41 35 19 86 80 36 52]
# Cliente #28 | Acurácia: 0.9531013369560242 | Diferença dos pesos: 290.1241760253906
# Cliente #74 | Acurácia: 0.9638554453849792 | Diferença dos pesos: 267.2898864746094
# Cliente #30 | Acurácia: 0.9545913338661194 | Diferença dos pesos: 153.96658325195312
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #41 | Acurácia: 0.9607142806053162 | Diferença dos pesos: 222.6934356689453
# Cliente #35 | Acurácia: 0.9550858736038208 | Diferença dos pesos: 265.0832824707031
# Cliente #19 | Acurácia: 0.9705387353897095 | Diferença dos pesos: 201.55148315429688
# Cliente #86 | Acurácia: 0.9340463280677795 | Diferença dos pesos: 162.54052734375
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #80 | Acurácia: 0.9612452387809753 | Diferença dos pesos: 336.6459655761719
# Cliente #36 | Acurácia: 0.9392917156219482 | Diferença dos pesos: 276.8070983886719
# Cliente #52 | Acurácia: 0.9579579830169678 | Diferença dos pesos: 243.93588256835938
# ----------------------------------------
# Transmissões nesta rodada: 8
# Acurácia: 0.8828999996185303
# ----------------------------------------
#
# Rodada 98/100
# Clientes selecionados: [77 48 63 88 40 61 49 18  4 68]
# Cliente #77 | Acurácia: 0.9628770351409912 | Diferença dos pesos: 262.26239013671875
# Cliente #48 | Acurácia: 0.9634649157524109 | Diferença dos pesos: 275.89788818359375
# Cliente #63 | Acurácia: 0.9619377255439758 | Diferença dos pesos: 222.1779327392578
# Cliente #88 | Acurácia: 0.9628099203109741 | Diferença dos pesos: 346.9117126464844
# Cliente #40 | Acurácia: 0.9543918967247009 | Diferença dos pesos: 153.02822875976562
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #61 | Acurácia: 0.9736308455467224 | Diferença dos pesos: 232.1108856201172
# Cliente #49 | Acurácia: 0.9560117125511169 | Diferença dos pesos: 192.8164825439453
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #18 | Acurácia: 0.9611830115318298 | Diferença dos pesos: 148.68209838867188
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #4 | Acurácia: 0.9489619135856628 | Diferença dos pesos: 231.14662170410156
# Cliente #68 | Acurácia: 0.9613526463508606 | Diferença dos pesos: 296.3150939941406
# ----------------------------------------
# Transmissões nesta rodada: 7
# Acurácia: 0.8478999733924866
# ----------------------------------------
#
# Rodada 99/100
# Clientes selecionados: [88 20 27 44 92 59 77 62 29  2]
# Cliente #88 | Acurácia: 0.9659090638160706 | Diferença dos pesos: 184.0930938720703
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #20 | Acurácia: 0.9522700905799866 | Diferença dos pesos: 338.1025085449219
# Cliente #27 | Acurácia: 0.9707547426223755 | Diferença dos pesos: 248.2886505126953
# Cliente #44 | Acurácia: 0.9503490924835205 | Diferença dos pesos: 292.9522705078125
# Cliente #92 | Acurácia: 0.9715424180030823 | Diferença dos pesos: 266.5606384277344
# Cliente #59 | Acurácia: 0.9515151381492615 | Diferença dos pesos: 234.95950317382812
# Cliente #77 | Acurácia: 0.9675173759460449 | Diferença dos pesos: 112.36509704589844
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #62 | Acurácia: 0.976047933101654 | Diferença dos pesos: 214.68186950683594
# Cliente #29 | Acurácia: 0.9526411890983582 | Diferença dos pesos: 250.45407104492188
# Cliente #2 | Acurácia: 0.965753436088562 | Diferença dos pesos: 164.61602783203125
# weight_diff < EPSILON. O modelo não será transmitido.
# ----------------------------------------
# Transmissões nesta rodada: 7
# Acurácia: 0.875
# ----------------------------------------
#
# Rodada 100/100
# Clientes selecionados: [65 99 93 86 18  6 49 94 29 46]
# Cliente #65 | Acurácia: 0.9646209478378296 | Diferença dos pesos: 278.36053466796875
# Cliente #99 | Acurácia: 0.9553450345993042 | Diferença dos pesos: 201.73793029785156
# Cliente #93 | Acurácia: 0.9373695254325867 | Diferença dos pesos: 213.30418395996094
# Cliente #86 | Acurácia: 0.9322637915611267 | Diferença dos pesos: 147.15530395507812
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #18 | Acurácia: 0.9602587819099426 | Diferença dos pesos: 152.77484130859375
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #6 | Acurácia: 0.9419167637825012 | Diferença dos pesos: 268.00726318359375
# Cliente #49 | Acurácia: 0.9589442610740662 | Diferença dos pesos: 144.04244995117188
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #94 | Acurácia: 0.9617928266525269 | Diferença dos pesos: 317.0082702636719
# Cliente #29 | Acurácia: 0.9562841653823853 | Diferença dos pesos: 131.25344848632812
# weight_diff < EPSILON. O modelo não será transmitido.
# Cliente #46 | Acurácia: 0.9560943841934204 | Diferença dos pesos: 275.2605895996094
# ----------------------------------------
# Transmissões nesta rodada: 6
# Acurácia: 0.8700000047683716
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [10.394805908203125, 5.674093723297119, 2.7403745651245117, 1.5749913454055786, 1.5771492719650269, 1.4484666585922241, 1.2453460693359375, 1.1119025945663452, 1.036155343055725, 0.9764999747276306, 0.9751747846603394, 0.9059986472129822, 0.9615399837493896, 0.8826887011528015, 0.7705216407775879, 0.781787633895874, 0.7519547939300537, 0.7481458187103271, 0.7249385118484497, 0.724135160446167, 0.7053384780883789, 0.6820270419120789, 0.6629157066345215, 0.6679360866546631, 0.7146454453468323, 0.6936391592025757, 0.6598684191703796, 0.7478054165840149, 0.6695164442062378, 0.7280536890029907, 0.7239857912063599, 0.7370339632034302, 0.6691358089447021, 0.6400591731071472, 0.6173455715179443, 0.6149443984031677, 0.6274482607841492, 0.6035215854644775, 0.5716123580932617, 0.6043692231178284, 0.5560582280158997, 0.5827341079711914, 0.5879374146461487, 0.5952906012535095, 0.5555444955825806, 0.5789932608604431, 0.5972090363502502, 0.582004725933075, 0.605596125125885, 0.597172737121582, 0.5808600783348083, 0.5952280163764954, 0.6078325510025024, 0.5924458503723145, 0.5753250122070312, 0.5682861804962158, 0.5416582822799683, 0.6181360483169556, 0.6259648203849792, 0.5975378155708313, 0.5874477028846741, 0.5911085605621338, 0.58477783203125, 0.5543419122695923, 0.5869097709655762, 0.569395124912262, 0.5464335680007935, 0.5468443036079407, 0.5645469427108765, 0.5494482517242432, 0.577362596988678, 0.6037019491195679, 0.5670983791351318, 0.5609480142593384, 0.5670669674873352, 0.6101074814796448, 0.5791903138160706, 0.6043987274169922, 0.6067113876342773, 0.575424075126648, 0.6324299573898315, 0.5555493831634521, 0.5958221554756165, 0.5448242425918579, 0.5447332859039307, 0.5643077492713928, 0.6088284850120544, 0.5657395720481873, 0.5752430558204651, 0.5617496371269226, 0.5621961951255798, 0.5423057675361633, 0.524876594543457, 0.5552150011062622, 0.5472766757011414, 0.5538113117218018, 0.4958638548851013, 0.619799017906189, 0.5409417748451233, 0.5258409976959229]
# Centralized accuracy: [0.6402999758720398, 0.6934999823570251, 0.6559000015258789, 0.5950000286102295, 0.5841000080108643, 0.6241000294685364, 0.6639000177383423, 0.6952000260353088, 0.6970000267028809, 0.7325000166893005, 0.742900013923645, 0.7773000001907349, 0.7699000239372253, 0.7572000026702881, 0.8149999976158142, 0.8176000118255615, 0.8224999904632568, 0.819100022315979, 0.8198999762535095, 0.8094000220298767, 0.809499979019165, 0.8403000235557556, 0.8371000289916992, 0.833899974822998, 0.8170999884605408, 0.8154000043869019, 0.8312000036239624, 0.8136000037193298, 0.8312000036239624, 0.8173999786376953, 0.8314999938011169, 0.8083999752998352, 0.8270000219345093, 0.8388000130653381, 0.8481000065803528, 0.8568000197410583, 0.8399999737739563, 0.8640000224113464, 0.849399983882904, 0.8493000268936157, 0.8669000267982483, 0.862500011920929, 0.8634999990463257, 0.863099992275238, 0.8712000250816345, 0.8683000206947327, 0.8608999848365784, 0.8533999919891357, 0.8553000092506409, 0.8690000176429749, 0.8532000184059143, 0.8647000193595886, 0.8528000116348267, 0.8651000261306763, 0.8621000051498413, 0.8693000078201294, 0.8673999905586243, 0.8554999828338623, 0.8531000018119812, 0.8598999977111816, 0.8611000180244446, 0.8580999970436096, 0.8672000169754028, 0.869700014591217, 0.8664000034332275, 0.8661999702453613, 0.8669999837875366, 0.8629999756813049, 0.864799976348877, 0.8593999743461609, 0.8700000047683716, 0.8619999885559082, 0.8572999835014343, 0.8644999861717224, 0.8694000244140625, 0.8511000275611877, 0.8543999791145325, 0.8590999841690063, 0.8569999933242798, 0.8718000054359436, 0.8453999757766724, 0.8672000169754028, 0.8623999953269958, 0.8705000281333923, 0.8708000183105469, 0.8705999851226807, 0.8604999780654907, 0.8694000244140625, 0.8647000193595886, 0.86080002784729, 0.8687999844551086, 0.8673999905586243, 0.8759999871253967, 0.8737999796867371, 0.8693000078201294, 0.8730999827384949, 0.8828999996185303, 0.8478999733924866, 0.875, 0.8700000047683716]

# %%
plt.title('Evolução da Acurácia')
plt.plot(evaluate_list["centralized"]["accuracy"])
plt.ylabel('Acurácia', fontsize=13)
plt.xlabel('Rodadas de Treinamento', fontsize=13)
# plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.title('Evolução da Função de Perda')
plt.plot(evaluate_list["centralized"]["loss"], color='red')
plt.ylabel('Função de Perda', fontsize=13)
plt.xlabel('Rodadas de Treinamento', fontsize=13)
# plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.title('Transmissões da Rodada')
plt.plot(transmissions_per_round, color='green',)
plt.ylabel('Quantidade de Transmissões', fontsize=13)
plt.xlabel('Rodadas de Treinamento', fontsize=13)
# plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.title('Transmissões Acumuladas por Rodada')
plt.plot([sum(transmissions_per_round[0:i]) for i in range(len(transmissions_per_round))], color='orange')
plt.ylabel('Quantidade de Transmissões Acumuladas', fontsize=13)
plt.xlabel('Rodadas de Treinamento', fontsize=13)
# plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
sum(transmissions_per_round)
# Out:
# 688

# %%
evaluate_list["centralized"]["accuracy"][-1]
# Out:
# 0.8700000047683716
