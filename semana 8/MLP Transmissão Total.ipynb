# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ### Modelo

# %%
class ModelMLP:
    @staticmethod
    def create_model():
        model = tf.keras.models.Sequential(
            [
                tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784,)),
                tf.keras.layers.Dense(10, activation="softmax")
            ]
        )
        model.compile(
            optimizer=tf.keras.optimizers.Adam(),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=['accuracy']
        )
        return model

# %%
# Definição dos parâmetros
NUMBER_OF_ROUNDS = 100
TOTAL_CLIENTS = 100
CLIENTS_PER_ROUND = 10

# %% [markdown]
# ### Cliente

# %%
class Client():
    def __init__(self, cid):
        self.cid = int(cid)
        self.model = ModelMLP.create_model()
        self.old_weights = None
        (self.x_train, self.y_train), (self.x_test, self.y_test) = self.load_data()


    def load_data(self):
        path = r"C:\Users\Nickolas\Documents\TARSF[1]\Dataset\Dataset\dataset-mnist\non-iid-0.9-100-rotation-45"

        train = pd.read_pickle(f"{path}/{self.cid+1}_train.pickle")
        test = pd.read_pickle(f"{path}/{self.cid+1}_test.pickle")

        x_train = train.drop(['label'], axis=1)
        y_train = train['label']

        x_test = test.drop(['label'], axis=1)
        y_test = test['label']

        return (x_train, y_train), (x_test, y_test)


    def fit(self, parameters, config=None):
        self.model.set_weights(parameters)
        history = self.model.fit(self.x_train, self.y_train, epochs=5, batch_size=128, validation_data=(self.x_test, self.y_test), verbose=False)
        sample_size = len(self.x_train)
        print(f"Acurácia: {history.history['val_accuracy'][-1]} | ")
        return self.model.get_weights(), sample_size, {"val_accuracy": history.history['val_accuracy'][-1], 
                                                       "val_loss": history.history['val_loss'][-1]}


    def evaluate(self, parameters):
        self.model.set_weights(parameters)
        return self.model.evaluate(self.x_test, self.y_test, verbose=False)

# %% [markdown]
# ### Servidor

# %%
class Server():
    def __init__(self, n_rounds, total_number_clients, min_fit_clients):
        self.n_rounds = n_rounds
        self.total_number_clients = total_number_clients
        self.min_fit_clients = min_fit_clients

        self.server_round = 0
        self.selected_clients = []
        self.model = ModelMLP.create_model()
        self.w_global = self.model.get_weights()

        self.clients_model_list = []
        # Vamos guardar todos os modelos (pesos) anteriores, mas não é necessário
        self.clients_previous_models_list = [ [] for _ in range(total_number_clients) ]
        self.create_models()
        (self.x_train, self.y_train), (self.x_test, self.y_test) = self.load_data()


    def load_data(self):
        path = r"C:\Users\Nickolas\Documents\TARSF[1]\Dataset\Dataset\dataset-mnist\mnist"

        train = pd.read_pickle(f"{path}/train.pickle")
        test = pd.read_pickle(f"{path}/test.pickle")

        x_train = train.drop(['label'], axis=1)
        y_train = train['label']

        # test = pd.concat([test, train])
        x_test = test.drop(['label'], axis=1)
        y_test = test['label']

        return (x_train, y_train), (x_test, y_test)


    def create_models(self):
        for i in range(self.total_number_clients):
            self.clients_model_list.append(Client(i))


    def aggregate_fit(self, weight_list, sample_sizes):
        self.w_global = []
        for weights in zip(*weight_list):
            weighted_sum = 0
            total_samples = sum(sample_sizes)
            for i in range(len(weights)):
                weighted_sum += weights[i] * sample_sizes[i]
            self.w_global.append(weighted_sum / total_samples)


    def configure_fit(self):
        self.selected_clients = np.random.permutation(list(range(self.total_number_clients)))[:self.min_fit_clients]
        print(f"Clientes selecionados: \033[34;1m{np.array(self.selected_clients) + 1}\033[37;0m")

    
    def get_client_previous_model(self, client_id):
        return self.clients_previous_models_list[client_id][-1]


    def save_client_previous_model(self, client_id, model):
        self.clients_previous_models_list[client_id].append(model)


    def fit(self):
        weight_list, sample_sizes_list, info_list, transmissions_count = [], [], [], 0
        for i, pos in enumerate(self.selected_clients):
            print(f"Cliente #{pos+1} | ", end='')

            # Se o cliente decidir não enviar o modelo, ele retorna um None
            new_model = self.clients_model_list[pos].fit(parameters=self.w_global)

            weights, size, info = new_model if new_model is not None else self.get_client_previous_model(pos)
            weight_list.append(weights)
            sample_sizes_list.append(size)
            info_list.append(info)

            # Se o cliente enviou um novo modelo, salve-o e incremente a contagem de transmissões
            if new_model is not None:
                self.save_client_previous_model(pos, (weights, size, info_list))
                transmissions_count += 1

        return weight_list, sample_sizes_list, {"acc_loss_local":[(pos+1, info_list[i]) for i, pos in enumerate(self.selected_clients)]}, transmissions_count


    def distributed_evaluation(self):
        loss_list, accuracy_list = [], []
        for i in range(self.total_number_clients):
            loss, accuracy = self.clients_model_list[i].evaluate(parameters=self.w_global)
            # print(f"Evaluate - CID: {i+1} - accuracy: {accuracy}")
            loss_list.append(loss)
            accuracy_list.append(accuracy)
        return sum(loss_list) / len(loss_list), sum(accuracy_list) / len(accuracy_list), {"accuracy_list": [(i+1, accuracy) for i, accuracy in enumerate(accuracy_list)]}


    def centralized_evaluation(self):
        self.model.set_weights(self.w_global)
        return self.model.evaluate(self.x_test, self.y_test, verbose=False)

# %% [markdown]
# ### Exemplo de Execução

# %%
def executar(id):
    print(f"EXECUÇÃO {id}")

    print('\n' + '='*40)
    print("{:^54}".format('\033[;1m' + 'CARREGAMENTO DE DADOS' + '\033[37;0m'))
    print("{:^40}".format(f'Número total de clientes: {TOTAL_CLIENTS}' + '\n'))
    
    s = Server(n_rounds=NUMBER_OF_ROUNDS,
               total_number_clients=TOTAL_CLIENTS,
               min_fit_clients=CLIENTS_PER_ROUND)
    
    print('\n' + '='*40)
    print("{:^54}".format('\033[;1m' + 'INICIANDO' + '\033[37;0m'))
    print("{:^40}".format(f'Clientes por rodada: {CLIENTS_PER_ROUND} ' + '\n'))
    
    evaluate_list = {"distributed": {"loss":[], "accuracy":[]}, "centralized": {"loss":[], "accuracy":[]}}
    
    transmissions_per_round = []
    
    # Rodadas de comunicação
    for s.server_round in range(s.n_rounds):
        print('\033[;1m' + f'Rodada {s.server_round+1}/{s.n_rounds}' + '\033[37;0m')
    
        # Seleciona os clientes que participarão da próxima rodada de comunicação
        s.configure_fit()
    
        # Treinamento local do dispositivo
        weight_list, sample_sizes, info, transmissions_count = s.fit()
    
        # Salva a quantidade de transmissões ocorridas nesta rodada
        transmissions_per_round.append(transmissions_count)
    
        # Agregação
        s.aggregate_fit(weight_list, sample_sizes)
    
        # Avaliação centralizada
        print('\033[3;1m' + '-'*40 + '\033[37;0m')
        # print(f"Avaliação centralizada")
        evaluate_loss, evaluate_accuracy = s.centralized_evaluation()
        print(f"[#{id}] Transmissões nesta rodada: {transmissions_count}")
        print(f"Acurácia: {evaluate_accuracy}")
        evaluate_list["centralized"]["loss"].append(evaluate_loss)
        evaluate_list["centralized"]["accuracy"].append(evaluate_accuracy)
        print('\033[3;1m' + '-'*40 + '\033[37;0m' + '\n')
    
    print('\n\n' + '='*40)
    print("{:^54}".format('\033[;1m' + 'RESULTADOS FINAIS' + '\033[37;0m'))
    print(f"\nCentralized loss: ", end='')
    print(evaluate_list["centralized"]["loss"])
    print(f"Centralized accuracy: ", end='')
    print(evaluate_list["centralized"]["accuracy"])

    return evaluate_list["centralized"]["accuracy"], evaluate_list["centralized"]["loss"], transmissions_per_round

# %%
acc_list, loss_list, transmissions_list = [], [], []

for i in range(3):
    acc, loss, transmissions = executar(i)
    acc_list.append(acc)
    loss_list.append(loss)
    transmissions_list.append(transmissions)
# Out:
# EXECUÇÃO 0
#
# ========================================
#           CARREGAMENTO DE DADOS
#      Número total de clientes: 100
#
#
# ========================================
#                 INICIANDO
#        Clientes por rodada: 10
#
# Rodada 1/100
# Clientes selecionados: [38 77 49 66 47  5 44 35 64 33]
# Cliente #38 | Acurácia: 0.9192618131637573 |
# Cliente #77 | Acurácia: 0.9211136698722839 |
# Cliente #49 | Acurácia: 0.8782991170883179 |
# Cliente #66 | Acurácia: 0.9032567143440247 |
# Cliente #47 | Acurácia: 0.9048625826835632 |
# Cliente #5 | Acurácia: 0.9117187261581421 |
# Cliente #44 | Acurácia: 0.9076803922653198 |
# Cliente #35 | Acurácia: 0.8890356421470642 |
# Cliente #64 | Acurácia: 0.9213696718215942 |
# Cliente #33 | Acurácia: 0.9029911160469055 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.5805000066757202
# ----------------------------------------
#
# Rodada 2/100
# Clientes selecionados: [62 74 50 43 21 11 48 14 82 72]
# Cliente #62 | Acurácia: 0.964820384979248 |
# Cliente #74 | Acurácia: 0.9374641180038452 |
# Cliente #50 | Acurácia: 0.9197651743888855 |
# Cliente #43 | Acurácia: 0.9343065619468689 |
# Cliente #21 | Acurácia: 0.9305189251899719 |
# Cliente #11 | Acurácia: 0.9107468128204346 |
# Cliente #48 | Acurácia: 0.9328226447105408 |
# Cliente #14 | Acurácia: 0.9283634424209595 |
# Cliente #82 | Acurácia: 0.9544887542724609 |
# Cliente #72 | Acurácia: 0.9228295683860779 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.7026000022888184
# ----------------------------------------
#
# Rodada 3/100
# Clientes selecionados: [25 32  8  7 50 93 99 91 53 44]
# Cliente #25 | Acurácia: 0.9254545569419861 |
# Cliente #32 | Acurácia: 0.9479866027832031 |
# Cliente #8 | Acurácia: 0.9381625652313232 |
# Cliente #7 | Acurácia: 0.9413542747497559 |
# Cliente #50 | Acurácia: 0.9158512949943542 |
# Cliente #93 | Acurácia: 0.9102296233177185 |
# Cliente #99 | Acurácia: 0.9012178778648376 |
# Cliente #91 | Acurácia: 0.9531450867652893 |
# Cliente #53 | Acurácia: 0.921374499797821 |
# Cliente #44 | Acurácia: 0.9138867259025574 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.6816999912261963
# ----------------------------------------
#
# Rodada 4/100
# Clientes selecionados: [94  3 74 97 99 16 93 39 47 79]
# Cliente #94 | Acurácia: 0.9346069097518921 |
# Cliente #3 | Acurácia: 0.9193682670593262 |
# Cliente #74 | Acurácia: 0.9386115670204163 |
# Cliente #97 | Acurácia: 0.9535911679267883 |
# Cliente #99 | Acurácia: 0.9052774310112 |
# Cliente #16 | Acurácia: 0.8963815569877625 |
# Cliente #93 | Acurácia: 0.9018788933753967 |
# Cliente #39 | Acurácia: 0.9308050274848938 |
# Cliente #47 | Acurácia: 0.9281184077262878 |
# Cliente #79 | Acurácia: 0.9168900847434998 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.6362000107765198
# ----------------------------------------
#
# Rodada 5/100
# Clientes selecionados: [95 12 39 67 86 69 89 48 88 56]
# Cliente #95 | Acurácia: 0.9326647520065308 |
# Cliente #12 | Acurácia: 0.9419642686843872 |
# Cliente #39 | Acurácia: 0.9314703941345215 |
# Cliente #67 | Acurácia: 0.9426229596138 |
# Cliente #86 | Acurácia: 0.9090909361839294 |
# Cliente #69 | Acurácia: 0.9319371581077576 |
# Cliente #89 | Acurácia: 0.9004237055778503 |
# Cliente #48 | Acurácia: 0.9328226447105408 |
# Cliente #88 | Acurácia: 0.9307851195335388 |
# Cliente #56 | Acurácia: 0.8876190185546875 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.6585999727249146
# ----------------------------------------
#
# Rodada 6/100
# Clientes selecionados: [55 67 35 94 84 87 20 34 53 30]
# Cliente #55 | Acurácia: 0.9324758648872375 |
# Cliente #67 | Acurácia: 0.9442622661590576 |
# Cliente #35 | Acurácia: 0.918097734451294 |
# Cliente #94 | Acurácia: 0.9441587328910828 |
# Cliente #84 | Acurácia: 0.930810809135437 |
# Cliente #87 | Acurácia: 0.9431891441345215 |
# Cliente #20 | Acurácia: 0.9231664538383484 |
# Cliente #34 | Acurácia: 0.9167340397834778 |
# Cliente #53 | Acurácia: 0.9283634424209595 |
# Cliente #30 | Acurácia: 0.9364278316497803 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.66839998960495
# ----------------------------------------
#
# Rodada 7/100
# Clientes selecionados: [ 3 39 50 66 97 43 82 15 11  5]
# Cliente #3 | Acurácia: 0.9293432831764221 |
# Cliente #39 | Acurácia: 0.9367930889129639 |
# Cliente #50 | Acurácia: 0.9285714030265808 |
# Cliente #66 | Acurácia: 0.9090038537979126 |
# Cliente #97 | Acurácia: 0.9480662941932678 |
# Cliente #43 | Acurácia: 0.9276155829429626 |
# Cliente #82 | Acurácia: 0.9501246809959412 |
# Cliente #15 | Acurácia: 0.9319470524787903 |
# Cliente #11 | Acurácia: 0.9180327653884888 |
# Cliente #5 | Acurácia: 0.93359375 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.7281000018119812
# ----------------------------------------
#
# Rodada 8/100
# Clientes selecionados: [21 61 91 48 43 69 29 81  7 72]
# Cliente #21 | Acurácia: 0.936675488948822 |
# Cliente #61 | Acurácia: 0.9513184428215027 |
# Cliente #91 | Acurácia: 0.9557124376296997 |
# Cliente #48 | Acurácia: 0.946965217590332 |
# Cliente #43 | Acurácia: 0.9312652349472046 |
# Cliente #69 | Acurácia: 0.9403141140937805 |
# Cliente #29 | Acurácia: 0.9198542833328247 |
# Cliente #81 | Acurácia: 0.9446640610694885 |
# Cliente #7 | Acurácia: 0.9455864429473877 |
# Cliente #72 | Acurácia: 0.9340835809707642 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.7616999745368958
# ----------------------------------------
#
# Rodada 9/100
# Clientes selecionados: [82 20 61 98 13 75  4 53 95 45]
# Cliente #82 | Acurácia: 0.9544887542724609 |
# Cliente #20 | Acurácia: 0.9301513433456421 |
# Cliente #61 | Acurácia: 0.9574036598205566 |
# Cliente #98 | Acurácia: 0.9471228718757629 |
# Cliente #13 | Acurácia: 0.9415024518966675 |
# Cliente #75 | Acurácia: 0.9408528208732605 |
# Cliente #4 | Acurácia: 0.9230104088783264 |
# Cliente #53 | Acurácia: 0.9365171790122986 |
# Cliente #95 | Acurácia: 0.936246395111084 |
# Cliente #45 | Acurácia: 0.9394128918647766 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.7723000049591064
# ----------------------------------------
#
# Rodada 10/100
# Clientes selecionados: [78 74 76 12 68 38 40 49 97 31]
# Cliente #78 | Acurácia: 0.9459119439125061 |
# Cliente #74 | Acurácia: 0.9432013630867004 |
# Cliente #76 | Acurácia: 0.9143780469894409 |
# Cliente #12 | Acurácia: 0.9598214030265808 |
# Cliente #68 | Acurácia: 0.9536231756210327 |
# Cliente #38 | Acurácia: 0.9377162456512451 |
# Cliente #40 | Acurácia: 0.9324324131011963 |
# Cliente #49 | Acurácia: 0.929618775844574 |
# Cliente #97 | Acurácia: 0.950276255607605 |
# Cliente #31 | Acurácia: 0.949026882648468 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.7842000126838684
# ----------------------------------------
#
# Rodada 11/100
# Clientes selecionados: [ 22  49  80  93  87  72  20  68  67 100]
# Cliente #22 | Acurácia: 0.9615134000778198 |
# Cliente #49 | Acurácia: 0.936950147151947 |
# Cliente #80 | Acurácia: 0.9434561729431152 |
# Cliente #93 | Acurácia: 0.9164927005767822 |
# Cliente #87 | Acurácia: 0.9522272348403931 |
# Cliente #72 | Acurácia: 0.9485530257225037 |
# Cliente #20 | Acurácia: 0.9348078966140747 |
# Cliente #68 | Acurácia: 0.9487922787666321 |
# Cliente #67 | Acurácia: 0.9426229596138 |
# Cliente #100 | Acurácia: 0.9489867091178894 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.756600022315979
# ----------------------------------------
#
# Rodada 12/100
# Clientes selecionados: [ 5 46 52 11 49 57 17 47 66 72]
# Cliente #5 | Acurácia: 0.940625011920929 |
# Cliente #46 | Acurácia: 0.9279161095619202 |
# Cliente #52 | Acurácia: 0.9504504799842834 |
# Cliente #11 | Acurácia: 0.9471766948699951 |
# Cliente #49 | Acurácia: 0.9325513243675232 |
# Cliente #57 | Acurácia: 0.9635036587715149 |
# Cliente #17 | Acurácia: 0.9632525444030762 |
# Cliente #47 | Acurácia: 0.9365750551223755 |
# Cliente #66 | Acurácia: 0.9262452125549316 |
# Cliente #72 | Acurácia: 0.9485530257225037 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.7990000247955322
# ----------------------------------------
#
# Rodada 13/100
# Clientes selecionados: [ 3 68 45 90 81 64  2 96 95 27]
# Cliente #3 | Acurácia: 0.9418121576309204 |
# Cliente #68 | Acurácia: 0.95652174949646 |
# Cliente #45 | Acurácia: 0.9375390410423279 |
# Cliente #90 | Acurácia: 0.9440504312515259 |
# Cliente #81 | Acurácia: 0.9512516260147095 |
# Cliente #64 | Acurácia: 0.9397590160369873 |
# Cliente #2 | Acurácia: 0.965753436088562 |
# Cliente #96 | Acurácia: 0.9431818127632141 |
# Cliente #95 | Acurácia: 0.9491404294967651 |
# Cliente #27 | Acurácia: 0.9650943279266357 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8180999755859375
# ----------------------------------------
#
# Rodada 14/100
# Clientes selecionados: [76 17 95 34 66 33 77 15 19 56]
# Cliente #76 | Acurácia: 0.9240710735321045 |
# Cliente #17 | Acurácia: 0.9593432545661926 |
# Cliente #95 | Acurácia: 0.9462750554084778 |
# Cliente #34 | Acurácia: 0.9377526044845581 |
# Cliente #66 | Acurácia: 0.9367815852165222 |
# Cliente #33 | Acurácia: 0.935327410697937 |
# Cliente #77 | Acurácia: 0.9373549818992615 |
# Cliente #15 | Acurácia: 0.9508506655693054 |
# Cliente #19 | Acurácia: 0.9402356743812561 |
# Cliente #56 | Acurácia: 0.9314285516738892 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8167999982833862
# ----------------------------------------
#
# Rodada 15/100
# Clientes selecionados: [56 35  6 75 58 77 51 31 26 87]
# Cliente #56 | Acurácia: 0.9047619104385376 |
# Cliente #35 | Acurácia: 0.9352707862854004 |
# Cliente #6 | Acurácia: 0.936108410358429 |
# Cliente #75 | Acurácia: 0.9339752197265625 |
# Cliente #58 | Acurácia: 0.9582651257514954 |
# Cliente #77 | Acurácia: 0.953596293926239 |
# Cliente #51 | Acurácia: 0.9442896842956543 |
# Cliente #31 | Acurácia: 0.9527339935302734 |
# Cliente #26 | Acurácia: 0.9495677351951599 |
# Cliente #87 | Acurácia: 0.9561007022857666 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8320000171661377
# ----------------------------------------
#
# Rodada 16/100
# Clientes selecionados: [93 70 37  7 44 45 96 83 55 22]
# Cliente #93 | Acurácia: 0.9144049882888794 |
# Cliente #70 | Acurácia: 0.9444032907485962 |
# Cliente #37 | Acurácia: 0.9571694731712341 |
# Cliente #7 | Acurácia: 0.9673518538475037 |
# Cliente #44 | Acurácia: 0.9410395622253418 |
# Cliente #45 | Acurácia: 0.9487820267677307 |
# Cliente #96 | Acurácia: 0.9391233921051025 |
# Cliente #83 | Acurácia: 0.9365269541740417 |
# Cliente #55 | Acurácia: 0.9453375935554504 |
# Cliente #22 | Acurácia: 0.9641226530075073 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8253999948501587
# ----------------------------------------
#
# Rodada 17/100
# Clientes selecionados: [72  3 58 74 46 47 95 68 77 61]
# Cliente #72 | Acurácia: 0.9405144453048706 |
# Cliente #3 | Acurácia: 0.9492934346199036 |
# Cliente #58 | Acurácia: 0.9500818252563477 |
# Cliente #74 | Acurácia: 0.9546758532524109 |
# Cliente #46 | Acurácia: 0.9370904564857483 |
# Cliente #47 | Acurácia: 0.9598308801651001 |
# Cliente #95 | Acurácia: 0.953438401222229 |
# Cliente #68 | Acurácia: 0.9536231756210327 |
# Cliente #77 | Acurácia: 0.9582366347312927 |
# Cliente #61 | Acurácia: 0.9553752541542053 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8306000232696533
# ----------------------------------------
#
# Rodada 18/100
# Clientes selecionados: [ 8 13 67 60 50  4 19 72 23 54]
# Cliente #8 | Acurácia: 0.9328621625900269 |
# Cliente #13 | Acurácia: 0.9445812702178955 |
# Cliente #67 | Acurácia: 0.9508196711540222 |
# Cliente #60 | Acurácia: 0.9429312348365784 |
# Cliente #50 | Acurácia: 0.9540117383003235 |
# Cliente #4 | Acurácia: 0.9282007217407227 |
# Cliente #19 | Acurácia: 0.9511784315109253 |
# Cliente #72 | Acurácia: 0.9421221613883972 |
# Cliente #23 | Acurácia: 0.9307535886764526 |
# Cliente #54 | Acurácia: 0.9494949579238892 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8104000091552734
# ----------------------------------------
#
# Rodada 19/100
# Clientes selecionados: [25 49 79  8 74  9 14 36 23 62]
# Cliente #25 | Acurácia: 0.9509090781211853 |
# Cliente #49 | Acurácia: 0.9428152441978455 |
# Cliente #79 | Acurácia: 0.9490616917610168 |
# Cliente #8 | Acurácia: 0.9310954213142395 |
# Cliente #74 | Acurácia: 0.9523809552192688 |
# Cliente #9 | Acurácia: 0.9455164670944214 |
# Cliente #14 | Acurácia: 0.9464181661605835 |
# Cliente #36 | Acurácia: 0.9325463771820068 |
# Cliente #23 | Acurácia: 0.932790219783783 |
# Cliente #62 | Acurácia: 0.9603293538093567 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8220000267028809
# ----------------------------------------
#
# Rodada 20/100
# Clientes selecionados: [66 13 65 31 50 39 41 77 82 95]
# Cliente #66 | Acurácia: 0.9444444179534912 |
# Cliente #13 | Acurácia: 0.947044312953949 |
# Cliente #65 | Acurácia: 0.9646209478378296 |
# Cliente #31 | Acurácia: 0.953660786151886 |
# Cliente #50 | Acurácia: 0.9549902081489563 |
# Cliente #39 | Acurácia: 0.9454424381256104 |
# Cliente #41 | Acurácia: 0.949999988079071 |
# Cliente #77 | Acurácia: 0.9466357231140137 |
# Cliente #82 | Acurácia: 0.967581033706665 |
# Cliente #95 | Acurácia: 0.9498567581176758 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8465999960899353
# ----------------------------------------
#
# Rodada 21/100
# Clientes selecionados: [65 39 12 86 52 47  6 38 44 23]
# Cliente #65 | Acurácia: 0.9610108137130737 |
# Cliente #39 | Acurácia: 0.9607451558113098 |
# Cliente #12 | Acurácia: 0.96875 |
# Cliente #86 | Acurácia: 0.9465240836143494 |
# Cliente #52 | Acurácia: 0.9534534811973572 |
# Cliente #47 | Acurácia: 0.9556025266647339 |
# Cliente #6 | Acurácia: 0.9399806261062622 |
# Cliente #38 | Acurácia: 0.946943461894989 |
# Cliente #44 | Acurácia: 0.9495733380317688 |
# Cliente #23 | Acurácia: 0.9205702543258667 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8410999774932861
# ----------------------------------------
#
# Rodada 22/100
# Clientes selecionados: [58 22 40 51 67  2 57 36 47 90]
# Cliente #58 | Acurácia: 0.950900137424469 |
# Cliente #22 | Acurácia: 0.9673842191696167 |
# Cliente #40 | Acurácia: 0.9510135054588318 |
# Cliente #51 | Acurácia: 0.9442896842956543 |
# Cliente #67 | Acurácia: 0.9557377099990845 |
# Cliente #2 | Acurácia: 0.9743150472640991 |
# Cliente #57 | Acurácia: 0.9582898616790771 |
# Cliente #36 | Acurácia: 0.9527824521064758 |
# Cliente #47 | Acurácia: 0.9534883499145508 |
# Cliente #90 | Acurácia: 0.9495666027069092 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8331000208854675
# ----------------------------------------
#
# Rodada 23/100
# Clientes selecionados: [95 36 27 66 70 16 15  8 79  4]
# Cliente #95 | Acurácia: 0.9541547298431396 |
# Cliente #36 | Acurácia: 0.9291737079620361 |
# Cliente #27 | Acurácia: 0.9603773355484009 |
# Cliente #66 | Acurácia: 0.938697338104248 |
# Cliente #70 | Acurácia: 0.9503335952758789 |
# Cliente #16 | Acurácia: 0.9440789222717285 |
# Cliente #15 | Acurácia: 0.95652174949646 |
# Cliente #8 | Acurácia: 0.9434629082679749 |
# Cliente #79 | Acurácia: 0.9436997175216675 |
# Cliente #4 | Acurácia: 0.9325259327888489 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8319000005722046
# ----------------------------------------
#
# Rodada 24/100
# Clientes selecionados: [94 75 60 10 33 82  7 47 85 93]
# Cliente #94 | Acurácia: 0.9537104964256287 |
# Cliente #75 | Acurácia: 0.9587345123291016 |
# Cliente #60 | Acurácia: 0.9559014439582825 |
# Cliente #10 | Acurácia: 0.9560283422470093 |
# Cliente #33 | Acurácia: 0.9320937991142273 |
# Cliente #82 | Acurácia: 0.9657106995582581 |
# Cliente #7 | Acurácia: 0.9691656827926636 |
# Cliente #47 | Acurácia: 0.957716703414917 |
# Cliente #85 | Acurácia: 0.9533783793449402 |
# Cliente #93 | Acurácia: 0.9415448904037476 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8515999913215637
# ----------------------------------------
#
# Rodada 25/100
# Clientes selecionados: [57 68 95 37 27 90 91 72 41 19]
# Cliente #57 | Acurácia: 0.965589165687561 |
# Cliente #68 | Acurácia: 0.9603864550590515 |
# Cliente #95 | Acurácia: 0.9591690301895142 |
# Cliente #37 | Acurácia: 0.9608938694000244 |
# Cliente #27 | Acurácia: 0.9632075428962708 |
# Cliente #90 | Acurácia: 0.9448384642601013 |
# Cliente #91 | Acurácia: 0.9640564918518066 |
# Cliente #72 | Acurácia: 0.9485530257225037 |
# Cliente #41 | Acurácia: 0.9357143044471741 |
# Cliente #19 | Acurácia: 0.9545454382896423 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8496999740600586
# ----------------------------------------
#
# Rodada 26/100
# Clientes selecionados: [50 40 75  5 53  2 81 20 65 15]
# Cliente #50 | Acurácia: 0.9637964963912964 |
# Cliente #40 | Acurácia: 0.9577702879905701 |
# Cliente #75 | Acurácia: 0.9518569707870483 |
# Cliente #5 | Acurácia: 0.9546874761581421 |
# Cliente #53 | Acurácia: 0.9528247117996216 |
# Cliente #2 | Acurácia: 0.9691780805587769 |
# Cliente #81 | Acurácia: 0.9617918133735657 |
# Cliente #20 | Acurácia: 0.9406286478042603 |
# Cliente #65 | Acurácia: 0.9610108137130737 |
# Cliente #15 | Acurácia: 0.960302472114563 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8546000123023987
# ----------------------------------------
#
# Rodada 27/100
# Clientes selecionados: [ 30  50  99  26   7  12  18 100  82  17]
# Cliente #30 | Acurácia: 0.953582227230072 |
# Cliente #50 | Acurácia: 0.9618395566940308 |
# Cliente #99 | Acurácia: 0.9485791325569153 |
# Cliente #26 | Acurácia: 0.9524495601654053 |
# Cliente #7 | Acurácia: 0.9691656827926636 |
# Cliente #12 | Acurácia: 0.9709821343421936 |
# Cliente #18 | Acurácia: 0.9574861526489258 |
# Cliente #100 | Acurácia: 0.9608665108680725 |
# Cliente #82 | Acurácia: 0.967581033706665 |
# Cliente #17 | Acurácia: 0.9671618342399597 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8515999913215637
# ----------------------------------------
#
# Rodada 28/100
# Clientes selecionados: [12 74 58  9 16 27 35 87 34 63]
# Cliente #12 | Acurácia: 0.96875 |
# Cliente #74 | Acurácia: 0.955249547958374 |
# Cliente #58 | Acurácia: 0.9549918174743652 |
# Cliente #9 | Acurácia: 0.9466515183448792 |
# Cliente #16 | Acurácia: 0.9391447305679321 |
# Cliente #27 | Acurácia: 0.9726415276527405 |
# Cliente #35 | Acurácia: 0.9524438381195068 |
# Cliente #87 | Acurácia: 0.9593285918235779 |
# Cliente #34 | Acurácia: 0.9369442462921143 |
# Cliente #63 | Acurácia: 0.9515570998191833 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8531000018119812
# ----------------------------------------
#
# Rodada 29/100
# Clientes selecionados: [22 68 42  8 52 33 12  5 28 37]
# Cliente #22 | Acurácia: 0.966079592704773 |
# Cliente #68 | Acurácia: 0.9603864550590515 |
# Cliente #42 | Acurácia: 0.9786396622657776 |
# Cliente #8 | Acurácia: 0.9416961073875427 |
# Cliente #52 | Acurácia: 0.9519519805908203 |
# Cliente #33 | Acurácia: 0.9393694400787354 |
# Cliente #12 | Acurácia: 0.96875 |
# Cliente #5 | Acurácia: 0.957812488079071 |
# Cliente #28 | Acurácia: 0.9447806477546692 |
# Cliente #37 | Acurácia: 0.968342661857605 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8680999875068665
# ----------------------------------------
#
# Rodada 30/100
# Clientes selecionados: [37 13 85 58 94 76 60 21 38 77]
# Cliente #37 | Acurácia: 0.9608938694000244 |
# Cliente #13 | Acurácia: 0.9519704580307007 |
# Cliente #85 | Acurácia: 0.9601351618766785 |
# Cliente #58 | Acurácia: 0.9566285014152527 |
# Cliente #94 | Acurácia: 0.9551799893379211 |
# Cliente #76 | Acurácia: 0.9386106729507446 |
# Cliente #60 | Acurácia: 0.9610894918441772 |
# Cliente #21 | Acurácia: 0.9639402031898499 |
# Cliente #38 | Acurácia: 0.9457900524139404 |
# Cliente #77 | Acurácia: 0.9512761235237122 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8682000041007996
# ----------------------------------------
#
# Rodada 31/100
# Clientes selecionados: [ 37  77  24  34  89 100  22  26  67  59]
# Cliente #37 | Acurácia: 0.9590316414833069 |
# Cliente #77 | Acurácia: 0.9559164643287659 |
# Cliente #24 | Acurácia: 0.9488372206687927 |
# Cliente #34 | Acurácia: 0.9377526044845581 |
# Cliente #89 | Acurácia: 0.9427965879440308 |
# Cliente #100 | Acurácia: 0.9545772075653076 |
# Cliente #22 | Acurácia: 0.9680365324020386 |
# Cliente #26 | Acurácia: 0.9423630833625793 |
# Cliente #67 | Acurácia: 0.965573787689209 |
# Cliente #59 | Acurácia: 0.9489177465438843 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8460000157356262
# ----------------------------------------
#
# Rodada 32/100
# Clientes selecionados: [38  6 52 81 68 97 18 85 82 84]
# Cliente #38 | Acurácia: 0.9492502808570862 |
# Cliente #6 | Acurácia: 0.9303001165390015 |
# Cliente #52 | Acurácia: 0.9579579830169678 |
# Cliente #81 | Acurácia: 0.9644268751144409 |
# Cliente #68 | Acurácia: 0.9623188376426697 |
# Cliente #97 | Acurácia: 0.9723756909370422 |
# Cliente #18 | Acurácia: 0.9500924348831177 |
# Cliente #85 | Acurácia: 0.9574324488639832 |
# Cliente #82 | Acurácia: 0.9682044982910156 |
# Cliente #84 | Acurácia: 0.9513513445854187 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8694000244140625
# ----------------------------------------
#
# Rodada 33/100
# Clientes selecionados: [75  6 84 45 91  4 65 64 12 52]
# Cliente #75 | Acurácia: 0.9546079635620117 |
# Cliente #6 | Acurácia: 0.9419167637825012 |
# Cliente #84 | Acurácia: 0.9578378200531006 |
# Cliente #45 | Acurácia: 0.9581511616706848 |
# Cliente #91 | Acurácia: 0.9679075479507446 |
# Cliente #4 | Acurácia: 0.9316608905792236 |
# Cliente #65 | Acurácia: 0.9624548554420471 |
# Cliente #64 | Acurácia: 0.9505389928817749 |
# Cliente #12 | Acurácia: 0.9821428656578064 |
# Cliente #52 | Acurácia: 0.9534534811973572 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8669999837875366
# ----------------------------------------
#
# Rodada 34/100
# Clientes selecionados: [47 85 65  5 82 51 29 70 94 57]
# Cliente #47 | Acurácia: 0.9661733508110046 |
# Cliente #85 | Acurácia: 0.962837815284729 |
# Cliente #65 | Acurácia: 0.9711191058158875 |
# Cliente #5 | Acurácia: 0.9585937261581421 |
# Cliente #82 | Acurácia: 0.9719451665878296 |
# Cliente #51 | Acurácia: 0.9540389776229858 |
# Cliente #29 | Acurácia: 0.9544626474380493 |
# Cliente #70 | Acurácia: 0.9532987475395203 |
# Cliente #94 | Acurácia: 0.9515062570571899 |
# Cliente #57 | Acurácia: 0.970802903175354 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8694999814033508
# ----------------------------------------
#
# Rodada 35/100
# Clientes selecionados: [62  9 13 23 26 30 63 93 96 54]
# Cliente #62 | Acurácia: 0.970059871673584 |
# Cliente #9 | Acurácia: 0.9511918425559998 |
# Cliente #13 | Acurácia: 0.9488916397094727 |
# Cliente #23 | Acurácia: 0.904276967048645 |
# Cliente #26 | Acurácia: 0.940922200679779 |
# Cliente #30 | Acurácia: 0.9455096125602722 |
# Cliente #63 | Acurácia: 0.9403114318847656 |
# Cliente #93 | Acurácia: 0.931106448173523 |
# Cliente #96 | Acurácia: 0.9342532753944397 |
# Cliente #54 | Acurácia: 0.9526515007019043 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8345999717712402
# ----------------------------------------
#
# Rodada 36/100
# Clientes selecionados: [71  9 89 97 38 92 94 20 19 95]
# Cliente #71 | Acurácia: 0.9649681448936462 |
# Cliente #9 | Acurácia: 0.9545970559120178 |
# Cliente #89 | Acurácia: 0.9533898234367371 |
# Cliente #97 | Acurácia: 0.9701657295227051 |
# Cliente #38 | Acurácia: 0.9538639187812805 |
# Cliente #92 | Acurácia: 0.9709732532501221 |
# Cliente #94 | Acurácia: 0.9603232741355896 |
# Cliente #20 | Acurácia: 0.9545983672142029 |
# Cliente #19 | Acurácia: 0.9486532211303711 |
# Cliente #95 | Acurácia: 0.9555873870849609 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8707000017166138
# ----------------------------------------
#
# Rodada 37/100
# Clientes selecionados: [27  4 23 57 99 66 94 96 72 58]
# Cliente #27 | Acurácia: 0.9660377502441406 |
# Cliente #4 | Acurácia: 0.9377162456512451 |
# Cliente #23 | Acurácia: 0.9287168979644775 |
# Cliente #57 | Acurácia: 0.970802903175354 |
# Cliente #99 | Acurácia: 0.949932336807251 |
# Cliente #66 | Acurácia: 0.9530651569366455 |
# Cliente #94 | Acurácia: 0.9610580205917358 |
# Cliente #96 | Acurácia: 0.9358766078948975 |
# Cliente #72 | Acurácia: 0.9517685174942017 |
# Cliente #58 | Acurácia: 0.9541735053062439 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8744999766349792
# ----------------------------------------
#
# Rodada 38/100
# Clientes selecionados: [56 38 23 29 40  1 27 67 48 28]
# Cliente #56 | Acurácia: 0.939047634601593 |
# Cliente #38 | Acurácia: 0.9515570998191833 |
# Cliente #23 | Acurácia: 0.9002036452293396 |
# Cliente #29 | Acurácia: 0.9635701179504395 |
# Cliente #40 | Acurácia: 0.9577702879905701 |
# Cliente #1 | Acurácia: 0.9596661925315857 |
# Cliente #27 | Acurácia: 0.9698113203048706 |
# Cliente #67 | Acurácia: 0.965573787689209 |
# Cliente #48 | Acurácia: 0.9605185389518738 |
# Cliente #28 | Acurácia: 0.9538577795028687 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8700000047683716
# ----------------------------------------
#
# Rodada 39/100
# Clientes selecionados: [41 59 99 81 62 65 67  2 94 56]
# Cliente #41 | Acurácia: 0.9482142925262451 |
# Cliente #59 | Acurácia: 0.9575757384300232 |
# Cliente #99 | Acurácia: 0.9512855410575867 |
# Cliente #81 | Acurácia: 0.9631093740463257 |
# Cliente #62 | Acurácia: 0.972305417060852 |
# Cliente #65 | Acurácia: 0.9696750640869141 |
# Cliente #67 | Acurácia: 0.9672130942344666 |
# Cliente #2 | Acurácia: 0.9674657583236694 |
# Cliente #94 | Acurácia: 0.9639970660209656 |
# Cliente #56 | Acurácia: 0.9428571462631226 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8693000078201294
# ----------------------------------------
#
# Rodada 40/100
# Clientes selecionados: [92 11 86 94 72 26 64 25 18 43]
# Cliente #92 | Acurácia: 0.96642005443573 |
# Cliente #11 | Acurácia: 0.9489981532096863 |
# Cliente #86 | Acurácia: 0.9500890970230103 |
# Cliente #94 | Acurácia: 0.9610580205917358 |
# Cliente #72 | Acurácia: 0.9533762335777283 |
# Cliente #26 | Acurácia: 0.9452449679374695 |
# Cliente #64 | Acurácia: 0.9575142860412598 |
# Cliente #25 | Acurácia: 0.9618181586265564 |
# Cliente #18 | Acurácia: 0.9510166645050049 |
# Cliente #43 | Acurácia: 0.9531630277633667 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8769999742507935
# ----------------------------------------
#
# Rodada 41/100
# Clientes selecionados: [ 7 84 56 40 30 10 24 77 65 87]
# Cliente #7 | Acurácia: 0.974606990814209 |
# Cliente #84 | Acurácia: 0.9578378200531006 |
# Cliente #56 | Acurácia: 0.9276190400123596 |
# Cliente #40 | Acurácia: 0.9510135054588318 |
# Cliente #30 | Acurácia: 0.9515640735626221 |
# Cliente #10 | Acurácia: 0.9517730474472046 |
# Cliente #24 | Acurácia: 0.9569767713546753 |
# Cliente #77 | Acurácia: 0.9512761235237122 |
# Cliente #65 | Acurácia: 0.9711191058158875 |
# Cliente #87 | Acurácia: 0.9606197476387024 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8722000122070312
# ----------------------------------------
#
# Rodada 42/100
# Clientes selecionados: [74 39 62 42 14 19 94 97 81 47]
# Cliente #74 | Acurácia: 0.9598393440246582 |
# Cliente #39 | Acurácia: 0.9614105224609375 |
# Cliente #62 | Acurácia: 0.9730538725852966 |
# Cliente #42 | Acurácia: 0.9741427898406982 |
# Cliente #14 | Acurácia: 0.9411764740943909 |
# Cliente #19 | Acurácia: 0.9545454382896423 |
# Cliente #94 | Acurácia: 0.9617928266525269 |
# Cliente #97 | Acurácia: 0.9779005646705627 |
# Cliente #81 | Acurácia: 0.9604743123054504 |
# Cliente #47 | Acurácia: 0.9534883499145508 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8537999987602234
# ----------------------------------------
#
# Rodada 43/100
# Clientes selecionados: [64 27 69 30 38 80 54 85 55 67]
# Cliente #64 | Acurácia: 0.9568801522254944 |
# Cliente #27 | Acurácia: 0.9660377502441406 |
# Cliente #69 | Acurácia: 0.9675392508506775 |
# Cliente #30 | Acurácia: 0.9616549015045166 |
# Cliente #38 | Acurácia: 0.9515570998191833 |
# Cliente #80 | Acurácia: 0.963151216506958 |
# Cliente #54 | Acurácia: 0.9570707082748413 |
# Cliente #85 | Acurácia: 0.9601351618766785 |
# Cliente #55 | Acurácia: 0.9517685174942017 |
# Cliente #67 | Acurácia: 0.9688524603843689 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8683000206947327
# ----------------------------------------
#
# Rodada 44/100
# Clientes selecionados: [46 51 85 87 80 19 75 17 74 68]
# Cliente #46 | Acurácia: 0.945609450340271 |
# Cliente #51 | Acurácia: 0.9526462554931641 |
# Cliente #85 | Acurácia: 0.9587838053703308 |
# Cliente #87 | Acurácia: 0.9632020592689514 |
# Cliente #80 | Acurácia: 0.9618805646896362 |
# Cliente #19 | Acurácia: 0.9562289714813232 |
# Cliente #75 | Acurácia: 0.95323246717453 |
# Cliente #17 | Acurácia: 0.9749804735183716 |
# Cliente #74 | Acurácia: 0.958118200302124 |
# Cliente #68 | Acurácia: 0.966183602809906 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8798999786376953
# ----------------------------------------
#
# Rodada 45/100
# Clientes selecionados: [60 63 43 81 66 16 33 13 51 68]
# Cliente #60 | Acurácia: 0.9584954380989075 |
# Cliente #63 | Acurácia: 0.9455017447471619 |
# Cliente #43 | Acurácia: 0.9489051103591919 |
# Cliente #81 | Acurácia: 0.9670619368553162 |
# Cliente #66 | Acurácia: 0.954023003578186 |
# Cliente #16 | Acurácia: 0.9424341917037964 |
# Cliente #33 | Acurácia: 0.9377526044845581 |
# Cliente #13 | Acurácia: 0.9476600885391235 |
# Cliente #51 | Acurácia: 0.9512534737586975 |
# Cliente #68 | Acurácia: 0.9690821170806885 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8664000034332275
# ----------------------------------------
#
# Rodada 46/100
# Clientes selecionados: [51 68 31  7 73 97 19 39 44 98]
# Cliente #51 | Acurácia: 0.9526462554931641 |
# Cliente #68 | Acurácia: 0.9671497344970703 |
# Cliente #31 | Acurácia: 0.9555143713951111 |
# Cliente #7 | Acurácia: 0.9727932214736938 |
# Cliente #73 | Acurácia: 0.953827440738678 |
# Cliente #97 | Acurácia: 0.971270740032196 |
# Cliente #19 | Acurácia: 0.9579124450683594 |
# Cliente #39 | Acurácia: 0.9640718698501587 |
# Cliente #44 | Acurácia: 0.9542281031608582 |
# Cliente #98 | Acurácia: 0.9626749753952026 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8774999976158142
# ----------------------------------------
#
# Rodada 47/100
# Clientes selecionados: [74 91 80 95 34 10 26  1 77 86]
# Cliente #74 | Acurácia: 0.9632816910743713 |
# Cliente #91 | Acurácia: 0.973042368888855 |
# Cliente #80 | Acurácia: 0.9625158905982971 |
# Cliente #95 | Acurácia: 0.9584527015686035 |
# Cliente #34 | Acurácia: 0.9498787522315979 |
# Cliente #10 | Acurácia: 0.9503546357154846 |
# Cliente #26 | Acurácia: 0.9524495601654053 |
# Cliente #1 | Acurácia: 0.9694019556045532 |
# Cliente #77 | Acurácia: 0.9651972055435181 |
# Cliente #86 | Acurácia: 0.9607843160629272 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8866000175476074
# ----------------------------------------
#
# Rodada 48/100
# Clientes selecionados: [80 89 38 58 63  9 22 30 82 61]
# Cliente #80 | Acurácia: 0.9656925201416016 |
# Cliente #89 | Acurácia: 0.9512711763381958 |
# Cliente #38 | Acurácia: 0.9480968713760376 |
# Cliente #58 | Acurácia: 0.9500818252563477 |
# Cliente #63 | Acurácia: 0.9403114318847656 |
# Cliente #9 | Acurácia: 0.9580022692680359 |
# Cliente #22 | Acurácia: 0.9673842191696167 |
# Cliente #30 | Acurácia: 0.953582227230072 |
# Cliente #82 | Acurácia: 0.9706982374191284 |
# Cliente #61 | Acurácia: 0.9675456285476685 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8709999918937683
# ----------------------------------------
#
# Rodada 49/100
# Clientes selecionados: [ 2 42 20 56 36  9 11 61 93 94]
# Cliente #2 | Acurácia: 0.9743150472640991 |
# Cliente #42 | Acurácia: 0.9763912558555603 |
# Cliente #20 | Acurácia: 0.9540162682533264 |
# Cliente #56 | Acurácia: 0.9352381229400635 |
# Cliente #36 | Acurácia: 0.9460371136665344 |
# Cliente #9 | Acurácia: 0.9523268938064575 |
# Cliente #11 | Acurácia: 0.9489981532096863 |
# Cliente #61 | Acurácia: 0.9655172228813171 |
# Cliente #93 | Acurácia: 0.9457202553749084 |
# Cliente #94 | Acurácia: 0.9573842883110046 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8804000020027161
# ----------------------------------------
#
# Rodada 50/100
# Clientes selecionados: [90 24 68 73  9 63 53 95 76 57]
# Cliente #90 | Acurácia: 0.9448384642601013 |
# Cliente #24 | Acurácia: 0.9488372206687927 |
# Cliente #68 | Acurácia: 0.9642512202262878 |
# Cliente #73 | Acurácia: 0.9507898092269897 |
# Cliente #9 | Acurácia: 0.9568672180175781 |
# Cliente #63 | Acurácia: 0.9463667869567871 |
# Cliente #53 | Acurácia: 0.9539895057678223 |
# Cliente #95 | Acurácia: 0.9584527015686035 |
# Cliente #76 | Acurácia: 0.9450727105140686 |
# Cliente #57 | Acurácia: 0.9635036587715149 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8601999878883362
# ----------------------------------------
#
# Rodada 51/100
# Clientes selecionados: [74 71 96 92 44 70  2 14 47 16]
# Cliente #74 | Acurácia: 0.9621342420578003 |
# Cliente #71 | Acurácia: 0.9649681448936462 |
# Cliente #96 | Acurácia: 0.9456169009208679 |
# Cliente #92 | Acurácia: 0.9715424180030823 |
# Cliente #44 | Acurácia: 0.9550038576126099 |
# Cliente #70 | Acurácia: 0.9629355072975159 |
# Cliente #2 | Acurácia: 0.9743150472640991 |
# Cliente #14 | Acurácia: 0.9499126672744751 |
# Cliente #47 | Acurácia: 0.9556025266647339 |
# Cliente #16 | Acurácia: 0.9473684430122375 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8752999901771545
# ----------------------------------------
#
# Rodada 52/100
# Clientes selecionados: [85 15 46  2 42 86 93 91 47 49]
# Cliente #85 | Acurácia: 0.9641891717910767 |
# Cliente #15 | Acurácia: 0.9470699429512024 |
# Cliente #46 | Acurácia: 0.9593709111213684 |
# Cliente #2 | Acurácia: 0.9726027250289917 |
# Cliente #42 | Acurácia: 0.9763912558555603 |
# Cliente #86 | Acurácia: 0.9500890970230103 |
# Cliente #93 | Acurácia: 0.9478079080581665 |
# Cliente #91 | Acurácia: 0.9698331356048584 |
# Cliente #47 | Acurácia: 0.9682875275611877 |
# Cliente #49 | Acurácia: 0.96334308385849 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8967000246047974
# ----------------------------------------
#
# Rodada 53/100
# Clientes selecionados: [42 99 38 40 71 67 86 16 79 75]
# Cliente #42 | Acurácia: 0.9724564552307129 |
# Cliente #99 | Acurácia: 0.9553450345993042 |
# Cliente #38 | Acurácia: 0.9492502808570862 |
# Cliente #40 | Acurácia: 0.9577702879905701 |
# Cliente #71 | Acurácia: 0.9700636863708496 |
# Cliente #67 | Acurácia: 0.9770491719245911 |
# Cliente #86 | Acurácia: 0.9554367065429688 |
# Cliente #16 | Acurácia: 0.9588815569877625 |
# Cliente #79 | Acurácia: 0.9638069868087769 |
# Cliente #75 | Acurácia: 0.9504814147949219 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8806999921798706
# ----------------------------------------
#
# Rodada 54/100
# Clientes selecionados: [99 80 50 49 88 30 83 82  2 96]
# Cliente #99 | Acurácia: 0.9539918899536133 |
# Cliente #80 | Acurácia: 0.9663278460502625 |
# Cliente #50 | Acurácia: 0.9628180265426636 |
# Cliente #49 | Acurácia: 0.9589442610740662 |
# Cliente #88 | Acurácia: 0.9586777091026306 |
# Cliente #30 | Acurácia: 0.9545913338661194 |
# Cliente #83 | Acurácia: 0.942514955997467 |
# Cliente #82 | Acurácia: 0.9682044982910156 |
# Cliente #2 | Acurácia: 0.9743150472640991 |
# Cliente #96 | Acurácia: 0.9521104097366333 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8835999965667725
# ----------------------------------------
#
# Rodada 55/100
# Clientes selecionados: [48 82 62 36 38 18 72 34 91 26]
# Cliente #48 | Acurácia: 0.9699469804763794 |
# Cliente #82 | Acurácia: 0.9738154411315918 |
# Cliente #62 | Acurácia: 0.9678143858909607 |
# Cliente #36 | Acurácia: 0.9426644444465637 |
# Cliente #38 | Acurácia: 0.9480968713760376 |
# Cliente #18 | Acurácia: 0.9593345522880554 |
# Cliente #72 | Acurácia: 0.9646302461624146 |
# Cliente #34 | Acurácia: 0.9417946934700012 |
# Cliente #91 | Acurácia: 0.9698331356048584 |
# Cliente #26 | Acurácia: 0.9438040256500244 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8899000287055969
# ----------------------------------------
#
# Rodada 56/100
# Clientes selecionados: [33 38 23 86 14 63 22 53 98 56]
# Cliente #33 | Acurácia: 0.9377526044845581 |
# Cliente #38 | Acurácia: 0.9527105093002319 |
# Cliente #23 | Acurácia: 0.914460301399231 |
# Cliente #86 | Acurácia: 0.9607843160629272 |
# Cliente #14 | Acurácia: 0.9458357691764832 |
# Cliente #63 | Acurácia: 0.9264705777168274 |
# Cliente #22 | Acurácia: 0.9726027250289917 |
# Cliente #53 | Acurácia: 0.9534071087837219 |
# Cliente #98 | Acurácia: 0.9564540982246399 |
# Cliente #56 | Acurácia: 0.939047634601593 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8808000087738037
# ----------------------------------------
#
# Rodada 57/100
# Clientes selecionados: [ 9  4 85 81 92 75 30 50  6 98]
# Cliente #9 | Acurácia: 0.9545970559120178 |
# Cliente #4 | Acurácia: 0.9420415163040161 |
# Cliente #85 | Acurácia: 0.9635134935379028 |
# Cliente #81 | Acurácia: 0.9617918133735657 |
# Cliente #92 | Acurácia: 0.9760956168174744 |
# Cliente #75 | Acurácia: 0.9573590159416199 |
# Cliente #30 | Acurácia: 0.9566094875335693 |
# Cliente #50 | Acurácia: 0.9628180265426636 |
# Cliente #6 | Acurácia: 0.9545014500617981 |
# Cliente #98 | Acurácia: 0.9603421688079834 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8892999887466431
# ----------------------------------------
#
# Rodada 58/100
# Clientes selecionados: [ 5 62 16 70 35 80 42  2 87 66]
# Cliente #5 | Acurácia: 0.9609375 |
# Cliente #62 | Acurácia: 0.973802387714386 |
# Cliente #16 | Acurácia: 0.9490131735801697 |
# Cliente #70 | Acurácia: 0.960711658000946 |
# Cliente #35 | Acurácia: 0.9550858736038208 |
# Cliente #80 | Acurácia: 0.9650571942329407 |
# Cliente #42 | Acurácia: 0.979763925075531 |
# Cliente #2 | Acurácia: 0.9726027250289917 |
# Cliente #87 | Acurácia: 0.9657843708992004 |
# Cliente #66 | Acurácia: 0.9578543901443481 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8909000158309937
# ----------------------------------------
#
# Rodada 59/100
# Clientes selecionados: [100  68  59  58  96  11  54  52  36  48]
# Cliente #100 | Acurácia: 0.9587700963020325 |
# Cliente #68 | Acurácia: 0.9632850289344788 |
# Cliente #59 | Acurácia: 0.9523809552192688 |
# Cliente #58 | Acurácia: 0.9590834975242615 |
# Cliente #96 | Acurácia: 0.9594155550003052 |
# Cliente #11 | Acurácia: 0.9544626474380493 |
# Cliente #54 | Acurácia: 0.9545454382896423 |
# Cliente #52 | Acurácia: 0.9609609842300415 |
# Cliente #36 | Acurácia: 0.9426644444465637 |
# Cliente #48 | Acurácia: 0.9693576693534851 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8858000040054321
# ----------------------------------------
#
# Rodada 60/100
# Clientes selecionados: [ 69  59  36  10 100  21  54  17  50   7]
# Cliente #69 | Acurácia: 0.9560209512710571 |
# Cliente #59 | Acurácia: 0.9575757384300232 |
# Cliente #36 | Acurácia: 0.9494097828865051 |
# Cliente #10 | Acurácia: 0.958865225315094 |
# Cliente #100 | Acurácia: 0.9643605947494507 |
# Cliente #21 | Acurácia: 0.9630606770515442 |
# Cliente #54 | Acurácia: 0.9545454382896423 |
# Cliente #17 | Acurácia: 0.9749804735183716 |
# Cliente #50 | Acurácia: 0.9696673154830933 |
# Cliente #7 | Acurácia: 0.9764208197593689 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8859999775886536
# ----------------------------------------
#
# Rodada 61/100
# Clientes selecionados: [66 79 41 58 34 88 14 61 64  4]
# Cliente #66 | Acurácia: 0.9559386968612671 |
# Cliente #79 | Acurácia: 0.9544236063957214 |
# Cliente #41 | Acurácia: 0.9553571343421936 |
# Cliente #58 | Acurácia: 0.9631751179695129 |
# Cliente #34 | Acurácia: 0.9498787522315979 |
# Cliente #88 | Acurácia: 0.9679751992225647 |
# Cliente #14 | Acurácia: 0.9522422552108765 |
# Cliente #61 | Acurácia: 0.9655172228813171 |
# Cliente #64 | Acurácia: 0.9594166278839111 |
# Cliente #4 | Acurácia: 0.9420415163040161 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8841000199317932
# ----------------------------------------
#
# Rodada 62/100
# Clientes selecionados: [ 77  84  71  72 100  49  43  91   1   2]
# Cliente #77 | Acurácia: 0.9582366347312927 |
# Cliente #84 | Acurácia: 0.9599999785423279 |
# Cliente #71 | Acurácia: 0.9630573391914368 |
# Cliente #72 | Acurácia: 0.9549839496612549 |
# Cliente #100 | Acurácia: 0.963661789894104 |
# Cliente #49 | Acurácia: 0.9560117125511169 |
# Cliente #43 | Acurácia: 0.9470803141593933 |
# Cliente #91 | Acurácia: 0.9717586636543274 |
# Cliente #1 | Acurácia: 0.9610570073127747 |
# Cliente #2 | Acurácia: 0.9691780805587769 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8946999907493591
# ----------------------------------------
#
# Rodada 63/100
# Clientes selecionados: [51 40 59 75 11 66 83  4  1 17]
# Cliente #51 | Acurácia: 0.9582172632217407 |
# Cliente #40 | Acurácia: 0.9662162065505981 |
# Cliente #59 | Acurácia: 0.9636363387107849 |
# Cliente #75 | Acurácia: 0.9587345123291016 |
# Cliente #11 | Acurácia: 0.9562841653823853 |
# Cliente #66 | Acurácia: 0.9664750695228577 |
# Cliente #83 | Acurácia: 0.9473053812980652 |
# Cliente #4 | Acurácia: 0.9446367025375366 |
# Cliente #1 | Acurácia: 0.9666203260421753 |
# Cliente #17 | Acurácia: 0.9757623076438904 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.892799973487854
# ----------------------------------------
#
# Rodada 64/100
# Clientes selecionados: [34 79 78 63 33 47 37 43 72 15]
# Cliente #34 | Acurácia: 0.9498787522315979 |
# Cliente #79 | Acurácia: 0.9530830979347229 |
# Cliente #78 | Acurácia: 0.9685534834861755 |
# Cliente #63 | Acurácia: 0.9558823704719543 |
# Cliente #33 | Acurácia: 0.9393694400787354 |
# Cliente #47 | Acurácia: 0.9640591740608215 |
# Cliente #37 | Acurácia: 0.9627560377120972 |
# Cliente #43 | Acurácia: 0.9568126797676086 |
# Cliente #72 | Acurácia: 0.9581993818283081 |
# Cliente #15 | Acurácia: 0.960302472114563 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8780999779701233
# ----------------------------------------
#
# Rodada 65/100
# Clientes selecionados: [32 85 70 79 50 67  4 21 88  2]
# Cliente #32 | Acurácia: 0.968120813369751 |
# Cliente #85 | Acurácia: 0.9614864587783813 |
# Cliente #70 | Acurácia: 0.9673832654953003 |
# Cliente #79 | Acurácia: 0.9624664783477783 |
# Cliente #50 | Acurácia: 0.9637964963912964 |
# Cliente #67 | Acurácia: 0.9672130942344666 |
# Cliente #4 | Acurácia: 0.9489619135856628 |
# Cliente #21 | Acurácia: 0.9674582481384277 |
# Cliente #88 | Acurácia: 0.9648760557174683 |
# Cliente #2 | Acurácia: 0.965753436088562 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8838000297546387
# ----------------------------------------
#
# Rodada 66/100
# Clientes selecionados: [27 65  3  7 62 59 82 67 12 81]
# Cliente #27 | Acurácia: 0.9735848903656006 |
# Cliente #65 | Acurácia: 0.9725631475448608 |
# Cliente #3 | Acurácia: 0.9459683895111084 |
# Cliente #7 | Acurácia: 0.978234589099884 |
# Cliente #62 | Acurácia: 0.973802387714386 |
# Cliente #59 | Acurácia: 0.9541125297546387 |
# Cliente #82 | Acurácia: 0.9706982374191284 |
# Cliente #67 | Acurácia: 0.9704918265342712 |
# Cliente #12 | Acurácia: 0.9765625 |
# Cliente #81 | Acurácia: 0.9617918133735657 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8889999985694885
# ----------------------------------------
#
# Rodada 67/100
# Clientes selecionados: [71 16 99 74 54 95  5 30 67 41]
# Cliente #71 | Acurácia: 0.9675159454345703 |
# Cliente #16 | Acurácia: 0.9572368264198303 |
# Cliente #99 | Acurácia: 0.9594045877456665 |
# Cliente #74 | Acurácia: 0.9627079963684082 |
# Cliente #54 | Acurácia: 0.9640151262283325 |
# Cliente #95 | Acurácia: 0.9606017470359802 |
# Cliente #5 | Acurácia: 0.9609375 |
# Cliente #30 | Acurácia: 0.9626639485359192 |
# Cliente #67 | Acurácia: 0.9688524603843689 |
# Cliente #41 | Acurácia: 0.949999988079071 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.899399995803833
# ----------------------------------------
#
# Rodada 68/100
# Clientes selecionados: [12 92 29  6 20 41 26 56 40 44]
# Cliente #12 | Acurácia: 0.9765625 |
# Cliente #92 | Acurácia: 0.9789413809776306 |
# Cliente #29 | Acurácia: 0.9544626474380493 |
# Cliente #6 | Acurácia: 0.9545014500617981 |
# Cliente #20 | Acurácia: 0.9534342288970947 |
# Cliente #41 | Acurácia: 0.949999988079071 |
# Cliente #26 | Acurácia: 0.9553313851356506 |
# Cliente #56 | Acurácia: 0.9333333373069763 |
# Cliente #40 | Acurácia: 0.9594594836235046 |
# Cliente #44 | Acurácia: 0.9526764750480652 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8895999789237976
# ----------------------------------------
#
# Rodada 69/100
# Clientes selecionados: [90 13 73  4 20 60 77 96 62 89]
# Cliente #90 | Acurácia: 0.9495666027069092 |
# Cliente #13 | Acurácia: 0.947044312953949 |
# Cliente #73 | Acurácia: 0.9605103135108948 |
# Cliente #4 | Acurácia: 0.9480968713760376 |
# Cliente #20 | Acurácia: 0.9522700905799866 |
# Cliente #60 | Acurácia: 0.9623864889144897 |
# Cliente #77 | Acurácia: 0.9628770351409912 |
# Cliente #96 | Acurácia: 0.9553571343421936 |
# Cliente #62 | Acurácia: 0.9708083868026733 |
# Cliente #89 | Acurácia: 0.9576271176338196 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8837000131607056
# ----------------------------------------
#
# Rodada 70/100
# Clientes selecionados: [100  42  47  87  93   1  36  65  24  28]
# Cliente #100 | Acurácia: 0.9629629850387573 |
# Cliente #42 | Acurácia: 0.9780775904655457 |
# Cliente #47 | Acurácia: 0.9640591740608215 |
# Cliente #87 | Acurácia: 0.9657843708992004 |
# Cliente #93 | Acurácia: 0.9498956203460693 |
# Cliente #1 | Acurácia: 0.9694019556045532 |
# Cliente #36 | Acurácia: 0.9527824521064758 |
# Cliente #65 | Acurácia: 0.9718411564826965 |
# Cliente #24 | Acurácia: 0.960465133190155 |
# Cliente #28 | Acurácia: 0.9561271071434021 |
# ----------------------------------------
# [#0] Transmissões nesta rodada: 10
# Acurácia: 0.8989999890327454
# ----------------------------------------
#
# Rodada 71/100
# Clientes selecionados: [ 6 88 47 78 84 73 72 95 26 87]
# Cliente #6 | Acurácia: 0.951597273349762 |
# Cliente #88 | Acurácia: 0.9659090638160706 |
# Cliente #47 | Acurácia: 0.9661733508110046 |
# Cliente #78 | Acurácia: 0.9660377502441406 |
# Cliente #84 | Acurácia: 0.9589189291000366 |
# Cliente #73 | Acurácia: 0.9592952728271484 |
# Cliente #72 | Acurácia: 0.9614148139953613 |
# Cliente #95 | Acurácia: 0.9663323760032654 |
# Cliente #26 | Acurácia: 0.9481267929077148 |
# Cliente #87 | Acurácia: 0.9677211046218872 |
# ----------------------------------------
# ...
# Cliente #69 | Acurácia: 0.9664921760559082 |
# Cliente #10 | Acurácia: 0.9531915187835693 |
# Cliente #87 | Acurácia: 0.967075526714325 |
# Cliente #71 | Acurácia: 0.96878981590271 |
# Cliente #97 | Acurácia: 0.9878453016281128 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8935999870300293
# ----------------------------------------
#
# Rodada 84/100
# Clientes selecionados: [ 3 43 19 76 78 95 96 10 22 72]
# Cliente #3 | Acurácia: 0.9600997567176819 |
# Cliente #43 | Acurácia: 0.9671533107757568 |
# Cliente #19 | Acurácia: 0.9713804721832275 |
# Cliente #76 | Acurácia: 0.9563812613487244 |
# Cliente #78 | Acurácia: 0.9654088020324707 |
# Cliente #95 | Acurácia: 0.9641833901405334 |
# Cliente #96 | Acurácia: 0.9594155550003052 |
# Cliente #10 | Acurácia: 0.9517730474472046 |
# Cliente #22 | Acurácia: 0.9706457853317261 |
# Cliente #72 | Acurácia: 0.9646302461624146 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8950999975204468
# ----------------------------------------
#
# Rodada 85/100
# Clientes selecionados: [ 4 11 10 74 90 95 29  5 17 82]
# Cliente #4 | Acurácia: 0.9619377255439758 |
# Cliente #11 | Acurácia: 0.9690346121788025 |
# Cliente #10 | Acurácia: 0.957446813583374 |
# Cliente #74 | Acurácia: 0.9667240381240845 |
# Cliente #90 | Acurácia: 0.9590228796005249 |
# Cliente #95 | Acurácia: 0.9613180756568909 |
# Cliente #29 | Acurácia: 0.9526411890983582 |
# Cliente #5 | Acurácia: 0.964062511920929 |
# Cliente #17 | Acurácia: 0.9773260354995728 |
# Cliente #82 | Acurácia: 0.971321702003479 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8968999981880188
# ----------------------------------------
#
# Rodada 86/100
# Clientes selecionados: [17 77  3 40 63 41 28 61 62 65]
# Cliente #17 | Acurácia: 0.9773260354995728 |
# Cliente #77 | Acurácia: 0.9628770351409912 |
# Cliente #3 | Acurácia: 0.9634247422218323 |
# Cliente #40 | Acurácia: 0.9662162065505981 |
# Cliente #63 | Acurácia: 0.9610726833343506 |
# Cliente #41 | Acurácia: 0.9750000238418579 |
# Cliente #28 | Acurácia: 0.9606656432151794 |
# Cliente #61 | Acurácia: 0.9736308455467224 |
# Cliente #62 | Acurácia: 0.9767963886260986 |
# Cliente #65 | Acurácia: 0.9696750640869141 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8981000185012817
# ----------------------------------------
#
# Rodada 87/100
# Clientes selecionados: [87 55 13 24 44 70 54 30 82 23]
# Cliente #87 | Acurácia: 0.9703034162521362 |
# Cliente #55 | Acurácia: 0.9678456783294678 |
# Cliente #13 | Acurácia: 0.9624384045600891 |
# Cliente #24 | Acurácia: 0.9720930457115173 |
# Cliente #44 | Acurácia: 0.9604344367980957 |
# Cliente #70 | Acurácia: 0.9584877490997314 |
# Cliente #54 | Acurácia: 0.9671717286109924 |
# Cliente #30 | Acurácia: 0.9677093625068665 |
# Cliente #82 | Acurácia: 0.973192036151886 |
# Cliente #23 | Acurácia: 0.9368635416030884 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8934000134468079
# ----------------------------------------
#
# Rodada 88/100
# Clientes selecionados: [46 21 99 23 70 34 27 45 10 12]
# Cliente #46 | Acurácia: 0.955439031124115 |
# Cliente #21 | Acurácia: 0.9718557596206665 |
# Cliente #99 | Acurácia: 0.9553450345993042 |
# Cliente #23 | Acurácia: 0.9409368634223938 |
# Cliente #70 | Acurácia: 0.9562638998031616 |
# Cliente #34 | Acurácia: 0.9660468697547913 |
# Cliente #27 | Acurácia: 0.9830188751220703 |
# Cliente #45 | Acurácia: 0.9637726545333862 |
# Cliente #10 | Acurácia: 0.9460992813110352 |
# Cliente #12 | Acurácia: 0.9810267686843872 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.895799994468689
# ----------------------------------------
#
# Rodada 89/100
# Clientes selecionados: [73 96  6  8 93 57 15 72 36 37]
# Cliente #73 | Acurácia: 0.9671931862831116 |
# Cliente #96 | Acurácia: 0.9472402334213257 |
# Cliente #6 | Acurácia: 0.9506292343139648 |
# Cliente #8 | Acurácia: 0.9646643400192261 |
# Cliente #93 | Acurácia: 0.9540709853172302 |
# Cliente #57 | Acurácia: 0.965589165687561 |
# Cliente #15 | Acurácia: 0.9773156642913818 |
# Cliente #72 | Acurácia: 0.9630225300788879 |
# Cliente #36 | Acurácia: 0.9460371136665344 |
# Cliente #37 | Acurácia: 0.9702048301696777 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8934999704360962
# ----------------------------------------
#
# Rodada 90/100
# Clientes selecionados: [86  4 92 76 57 60 40 32 19 25]
# Cliente #86 | Acurácia: 0.9607843160629272 |
# Cliente #4 | Acurácia: 0.9645328521728516 |
# Cliente #92 | Acurácia: 0.974957287311554 |
# Cliente #76 | Acurácia: 0.9579967856407166 |
# Cliente #57 | Acurácia: 0.9739311933517456 |
# Cliente #60 | Acurácia: 0.9727626442909241 |
# Cliente #40 | Acurácia: 0.9695945978164673 |
# Cliente #32 | Acurácia: 0.968120813369751 |
# Cliente #19 | Acurácia: 0.9747474789619446 |
# Cliente #25 | Acurácia: 0.9727272987365723 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8913999795913696
# ----------------------------------------
#
# Rodada 91/100
# Clientes selecionados: [ 26  87  17  80  73   7  15  52  44 100]
# Cliente #26 | Acurácia: 0.9380403161048889 |
# Cliente #87 | Acurácia: 0.9715945720672607 |
# Cliente #17 | Acurácia: 0.9734167456626892 |
# Cliente #80 | Acurácia: 0.970139741897583 |
# Cliente #73 | Acurácia: 0.966585636138916 |
# Cliente #7 | Acurácia: 0.9727932214736938 |
# Cliente #15 | Acurácia: 0.9754253029823303 |
# Cliente #52 | Acurácia: 0.9654654860496521 |
# Cliente #44 | Acurácia: 0.9604344367980957 |
# Cliente #100 | Acurácia: 0.9664570093154907 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8919000029563904
# ----------------------------------------
#
# Rodada 92/100
# Clientes selecionados: [90 28 86 35 36 24 25 23 31 68]
# Cliente #90 | Acurácia: 0.9566587805747986 |
# Cliente #28 | Acurácia: 0.9621785283088684 |
# Cliente #86 | Acurácia: 0.9536541700363159 |
# Cliente #35 | Acurácia: 0.9524438381195068 |
# Cliente #36 | Acurácia: 0.9443507790565491 |
# Cliente #24 | Acurácia: 0.9674418568611145 |
# Cliente #25 | Acurácia: 0.9618181586265564 |
# Cliente #23 | Acurácia: 0.9429734945297241 |
# Cliente #31 | Acurácia: 0.9712696671485901 |
# Cliente #68 | Acurácia: 0.9681159257888794 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.9043999910354614
# ----------------------------------------
#
# Rodada 93/100
# Clientes selecionados: [25 97 58 56 99 31 38  1 41 95]
# Cliente #25 | Acurácia: 0.9636363387107849 |
# Cliente #97 | Acurácia: 0.9812154769897461 |
# Cliente #58 | Acurácia: 0.9656301140785217 |
# Cliente #56 | Acurácia: 0.9352381229400635 |
# Cliente #99 | Acurácia: 0.9566982388496399 |
# Cliente #31 | Acurácia: 0.9638554453849792 |
# Cliente #38 | Acurácia: 0.9665513038635254 |
# Cliente #1 | Acurácia: 0.9805285334587097 |
# Cliente #41 | Acurácia: 0.9732142686843872 |
# Cliente #95 | Acurácia: 0.9648997187614441 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8984000086784363
# ----------------------------------------
#
# Rodada 94/100
# Clientes selecionados: [55 60 91 75 89 52 36 30 84 18]
# Cliente #55 | Acurácia: 0.9678456783294678 |
# Cliente #60 | Acurácia: 0.966277539730072 |
# Cliente #91 | Acurácia: 0.9781771302223206 |
# Cliente #75 | Acurácia: 0.9614855647087097 |
# Cliente #89 | Acurácia: 0.9576271176338196 |
# Cliente #52 | Acurácia: 0.966966986656189 |
# Cliente #36 | Acurácia: 0.9426644444465637 |
# Cliente #30 | Acurácia: 0.9606457948684692 |
# Cliente #84 | Acurácia: 0.9589189291000366 |
# Cliente #18 | Acurácia: 0.9676524996757507 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8902000188827515
# ----------------------------------------
#
# Rodada 95/100
# Clientes selecionados: [18 44 35 10 36 88 58 78 95 11]
# Cliente #18 | Acurácia: 0.9667282700538635 |
# Cliente #44 | Acurácia: 0.9604344367980957 |
# Cliente #35 | Acurácia: 0.959048867225647 |
# Cliente #10 | Acurácia: 0.957446813583374 |
# Cliente #36 | Acurácia: 0.9409780502319336 |
# Cliente #88 | Acurácia: 0.9669421315193176 |
# Cliente #58 | Acurácia: 0.9648118019104004 |
# Cliente #78 | Acurácia: 0.9647798538208008 |
# Cliente #95 | Acurácia: 0.9627507328987122 |
# Cliente #11 | Acurácia: 0.9672130942344666 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8955000042915344
# ----------------------------------------
#
# Rodada 96/100
# Clientes selecionados: [51 84  6 75 85 97 10 32 66 23]
# Cliente #51 | Acurácia: 0.9651810526847839 |
# Cliente #84 | Acurácia: 0.9513513445854187 |
# Cliente #6 | Acurácia: 0.9545014500617981 |
# Cliente #75 | Acurácia: 0.960110068321228 |
# Cliente #85 | Acurácia: 0.9743243455886841 |
# Cliente #97 | Acurácia: 0.9801105260848999 |
# Cliente #10 | Acurácia: 0.9560283422470093 |
# Cliente #32 | Acurácia: 0.9672818779945374 |
# Cliente #66 | Acurácia: 0.9568965435028076 |
# Cliente #23 | Acurácia: 0.9409368634223938 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8827000260353088
# ----------------------------------------
#
# Rodada 97/100
# Clientes selecionados: [ 4 36 73 57 82  1 89 95 98 48]
# Cliente #4 | Acurácia: 0.9636678099632263 |
# Cliente #36 | Acurácia: 0.9477234482765198 |
# Cliente #73 | Acurácia: 0.9720534682273865 |
# Cliente #57 | Acurácia: 0.9760167002677917 |
# Cliente #82 | Acurácia: 0.969451367855072 |
# Cliente #1 | Acurácia: 0.976356029510498 |
# Cliente #89 | Acurácia: 0.9555084705352783 |
# Cliente #95 | Acurácia: 0.9641833901405334 |
# Cliente #98 | Acurácia: 0.9618973731994629 |
# Cliente #48 | Acurácia: 0.9681791663169861 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.9103999733924866
# ----------------------------------------
#
# Rodada 98/100
# Clientes selecionados: [89 14 83  6 34 98 25 19 11 74]
# Cliente #89 | Acurácia: 0.9597457647323608 |
# Cliente #14 | Acurácia: 0.9592311978340149 |
# Cliente #83 | Acurácia: 0.9664670825004578 |
# Cliente #6 | Acurácia: 0.9545014500617981 |
# Cliente #34 | Acurácia: 0.9636216759681702 |
# Cliente #98 | Acurácia: 0.9727838039398193 |
# Cliente #25 | Acurácia: 0.9654545187950134 |
# Cliente #19 | Acurácia: 0.9696969985961914 |
# Cliente #11 | Acurácia: 0.9672130942344666 |
# Cliente #74 | Acurácia: 0.9678714871406555 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8899000287055969
# ----------------------------------------
#
# Rodada 99/100
# Clientes selecionados: [ 32  49   2 100  73  21  36  69  54  99]
# Cliente #32 | Acurácia: 0.9639261960983276 |
# Cliente #49 | Acurácia: 0.9574779868125916 |
# Cliente #2 | Acurácia: 0.9726027250289917 |
# Cliente #100 | Acurácia: 0.9650593996047974 |
# Cliente #73 | Acurácia: 0.9671931862831116 |
# Cliente #21 | Acurácia: 0.9709762334823608 |
# Cliente #36 | Acurácia: 0.9443507790565491 |
# Cliente #69 | Acurácia: 0.9643979072570801 |
# Cliente #54 | Acurácia: 0.9671717286109924 |
# Cliente #99 | Acurácia: 0.949932336807251 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.8973000049591064
# ----------------------------------------
#
# Rodada 100/100
# Clientes selecionados: [83 14 53 55 94 41 28 46 23 69]
# Cliente #83 | Acurácia: 0.9652694463729858 |
# Cliente #14 | Acurácia: 0.961560845375061 |
# Cliente #53 | Acurácia: 0.9708794355392456 |
# Cliente #55 | Acurácia: 0.971061110496521 |
# Cliente #94 | Acurácia: 0.969140350818634 |
# Cliente #41 | Acurácia: 0.9732142686843872 |
# Cliente #28 | Acurácia: 0.9629349708557129 |
# Cliente #46 | Acurácia: 0.9560943841934204 |
# Cliente #23 | Acurácia: 0.9348269104957581 |
# Cliente #69 | Acurácia: 0.972774863243103 |
# ----------------------------------------
# [#2] Transmissões nesta rodada: 10
# Acurácia: 0.9028000235557556
# ----------------------------------------
#
#
#
# ========================================
#             RESULTADOS FINAIS
#
# Centralized loss: [14.697370529174805, 5.768890380859375, 2.6914288997650146, 1.6382224559783936, 1.3420871496200562, 1.2078484296798706, 1.1184278726577759, 1.0467458963394165, 0.9459159970283508, 0.9301718473434448, 0.8475719690322876, 0.8383370041847229, 0.827687680721283, 0.8857804536819458, 0.7793758511543274, 0.7566164135932922, 0.8024710416793823, 0.7793290019035339, 0.7692119479179382, 0.7088034749031067, 0.718076229095459, 0.7142598628997803, 0.7009935975074768, 0.6820448040962219, 0.694983959197998, 0.629612922668457, 0.5952348709106445, 0.6619619131088257, 0.6892797946929932, 0.6754114627838135, 0.5917995572090149, 0.6569204330444336, 0.6392739415168762, 0.5811680555343628, 0.6783457398414612, 0.5540169477462769, 0.5591434240341187, 0.6398636102676392, 0.5681412816047668, 0.598685622215271, 0.5820294618606567, 0.5685226917266846, 0.5447189807891846, 0.5154174566268921, 0.5149274468421936, 0.5234520435333252, 0.523677408695221, 0.5103906989097595, 0.5179287791252136, 0.5992581248283386, 0.5174137353897095, 0.5248426795005798, 0.5180880427360535, 0.4996318817138672, 0.513656735420227, 0.5105065703392029, 0.47238749265670776, 0.4493120610713959, 0.49134132266044617, 0.5160701870918274, 0.47446948289871216, 0.4597960412502289, 0.48402807116508484, 0.4436737895011902, 0.5094387531280518, 0.4866110384464264, 0.5126587152481079, 0.49913886189460754, 0.4650687575340271, 0.46238160133361816, 0.48794394731521606, 0.45398497581481934, 0.5092257261276245, 0.4919775426387787, 0.5380343794822693, 0.520337700843811, 0.4545784294605255, 0.4325881898403168, 0.4386114776134491, 0.4556484818458557, 0.4452422857284546, 0.46634066104888916, 0.4406045377254486, 0.42656490206718445, 0.4509412944316864, 0.4606362283229828, 0.4668654799461365, 0.4216471314430237, 0.4316852390766144, 0.4245396852493286, 0.4563274383544922, 0.4159391224384308, 0.4382690489292145, 0.4396970272064209, 0.5016942024230957, 0.45743149518966675, 0.3918866813182831, 0.46870625019073486, 0.39908385276794434, 0.4460071325302124]
# Centralized accuracy: [0.589900016784668, 0.6710000038146973, 0.6341000199317932, 0.6122999787330627, 0.6269000172615051, 0.6430000066757202, 0.7032999992370605, 0.7006999850273132, 0.7426999807357788, 0.7648000121116638, 0.7689999938011169, 0.7617999911308289, 0.7821000218391418, 0.7480000257492065, 0.7875999808311462, 0.7961999773979187, 0.7718999981880188, 0.7574999928474426, 0.7896000146865845, 0.805400013923645, 0.802299976348877, 0.7961999773979187, 0.8082000017166138, 0.8191999793052673, 0.8163999915122986, 0.8270999789237976, 0.84579998254776, 0.8385000228881836, 0.8431000113487244, 0.8141999840736389, 0.8501999974250793, 0.840499997138977, 0.8449000120162964, 0.8561000227928162, 0.8216999769210815, 0.870199978351593, 0.8575000166893005, 0.8472999930381775, 0.857699990272522, 0.8600999712944031, 0.8513000011444092, 0.8539999723434448, 0.8575999736785889, 0.8720999956130981, 0.8646000027656555, 0.8676999807357788, 0.8733999729156494, 0.8787000179290771, 0.875, 0.8511000275611877, 0.882099986076355, 0.862500011920929, 0.8679999709129333, 0.8787999749183655, 0.8747000098228455, 0.8792999982833862, 0.8878999948501587, 0.8866000175476074, 0.8809000253677368, 0.8769000172615051, 0.8878999948501587, 0.8884999752044678, 0.8766999840736389, 0.8824999928474426, 0.8859000205993652, 0.8690999746322632, 0.8704000115394592, 0.8770999908447266, 0.8862000107765198, 0.8899000287055969, 0.885200023651123, 0.8925999999046326, 0.8802000284194946, 0.8830000162124634, 0.8754000067710876, 0.8598999977111816, 0.8895999789237976, 0.8924999833106995, 0.8865000009536743, 0.8916000127792358, 0.8991000056266785, 0.9002000093460083, 0.8935999870300293, 0.8950999975204468, 0.8968999981880188, 0.8981000185012817, 0.8934000134468079, 0.895799994468689, 0.8934999704360962, 0.8913999795913696, 0.8919000029563904, 0.9043999910354614, 0.8984000086784363, 0.8902000188827515, 0.8955000042915344, 0.8827000260353088, 0.9103999733924866, 0.8899000287055969, 0.8973000049591064, 0.9028000235557556]

# %%
plt.figure(dpi=2400)

def plotar_grafico_acuracia():
    fig, ax = plt.subplots(figsize=(3, 3))
    
    ax.set_ylabel('Acurácia', color='#000000', fontsize=12)
    ax.set_xlabel('Rodadas', color='#000000', fontsize=12)
    
    ax.set_ylim(auto=True)
    
    x1, y1 = [*range(len(acc_list[0]))], [np.mean(p) for p in zip(*acc_list)]
    ax.plot(x1, y1, linestyle = 'solid', color='#00aaff', linewidth = 1)
    y_min = [np.min(p) for p in zip(*acc_list)]
    y_max = [np.max(p) for p in zip(*acc_list)]
    ax.fill_between(x1, y_min, y_max, color='#00aaff', alpha=0.1)
    plt.savefig("acuracia_transmissao_total.jpg", dpi=2400, bbox_inches='tight')

def plotar_grafico_perda():
    fig, ax = plt.subplots(figsize=(3, 3))
    
    ax.set_ylabel('Perda', color='#000000', fontsize=12)
    ax.set_xlabel('Rodadas', color='#000000', fontsize=12)
    
    ax.set_ylim(auto=True)
    
    x1, y1 = [*range(len(loss_list[0]))], [np.mean(p) for p in zip(*loss_list)]
    ax.plot(x1, y1, linestyle = 'solid', color='#ff0000', linewidth = 1)
    y_min = [np.min(p) for p in zip(*loss_list)]
    y_max = [np.max(p) for p in zip(*loss_list)]
    ax.fill_between(x1, y_min, y_max, color='#ff0000', alpha=0.1)
    plt.savefig("loss_transmissao_total.jpg", dpi=2400, bbox_inches='tight')

def plotar_grafico_transmissoes():
    fig, ax = plt.subplots(figsize=(3, 3))
    
    ax.set_ylabel('Transmissões', color='#000000', fontsize=12)
    ax.set_xlabel('Rodadas', color='#000000', fontsize=12)
    
    ax.set_ylim(auto=True)
    
    x1, y1 = [*range(len(transmissions_list[0]))], [np.mean(p) for p in zip(*transmissions_list)]
    ax.plot(x1, y1, linestyle = 'solid', color='#44aa44', linewidth = 1)
    y_min = [np.min(p) for p in zip(*transmissions_list)]
    y_max = [np.max(p) for p in zip(*transmissions_list)]
    ax.fill_between(x1, y_min, y_max, color='#44aa44', alpha=0.1)
    plt.savefig("transmissoes_transmissao_total.jpg", dpi=2400, bbox_inches='tight')

    
def plotar_grafico_transmissoes_acumuladas():
    acc_transmissions_list = [
        [np.sum(transmission_list[0:i]) for i in range(len(transmission_list))] 
        for transmission_list in transmissions_list
    ]
    
    fig, ax = plt.subplots(figsize=(3, 3))
    
    ax.set_ylabel('Transmissões Acumuladas', color='#000000', fontsize=12)
    ax.set_xlabel('Rodadas', color='#000000', fontsize=12)
    
    ax.set_ylim(auto=True)
    
    x1, y1 = [*range(len(acc_transmissions_list[0]))], [np.mean(p) for p in zip(*acc_transmissions_list)]
    ax.plot(x1, y1, linestyle = 'solid', color='#ffa500', linewidth = 1)
    y_min = [np.min(p) for p in zip(*acc_transmissions_list)]
    y_max = [np.max(p) for p in zip(*acc_transmissions_list)]
    ax.fill_between(x1, y_min, y_max, color='#ffa500', alpha=0.1)
    plt.savefig("transmissoes_acumuladas_transmissao_total.jpg", dpi=2400, bbox_inches='tight')

    
def plotar_graficos():
    plotar_grafico_acuracia()
    plotar_grafico_perda()
    plotar_grafico_transmissoes()
    plotar_grafico_transmissoes_acumuladas()

plotar_graficos()
